# %%
# Doing all major library imports
import matplotlib.pyplot as plt
import scikitplot as skplt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import re

from sklearn import datasets, metrics
from sklearn.linear_model import LinearRegression, LogisticRegression,LogisticRegressionCV 
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from matplotlib.colors import ListedColormap
from sklearn.pipeline import Pipeline, make_pipeline

plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import scikitplot as skplt
from matplotlib.colors import ListedColormap
from sklearn.metrics import classification_report, confusion_matrix

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.options.display.float_format = '{:.2f}'.format

import wbdata as wb

# %%
df = wb.get_dataframe({"NY.GNP.PCAP.CD": "GNI", "SI.POV.DDAY": "POV"}, country="LMY", keep_levels=False)
df.head()
# Out:
#          GNI   POV
# date
# 2019     nan   nan
# 2018 4837.04   nan
# 2017 4525.01   nan
# 2016 4461.62   nan
# 2015 4554.48 11.80

# %%
df.reset_index(inplace=True)
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    date     GNI   POV
# 4  2015 4554.48 11.80
# 6  2013 4522.93 13.30
# 7  2012 4185.87 15.20
# 8  2011 3698.38 16.30
# 9  2010 3331.46 18.80

# %%
df.corr()
# Out:
#       GNI   POV
# GNI  1.00 -0.93
# POV -0.93  1.00

# %%
wb.get_country(incomelevel='LMY')
# Out:
# AFG	Afghanistan
# AGO	Angola
# ALB	Albania
# ARG	Argentina
# ARM	Armenia
# ASM	American Samoa
# AZE	Azerbaijan
# BDI	Burundi
# BEN	Benin
# BFA	Burkina Faso
# BGD	Bangladesh
# BGR	Bulgaria
# BIH	Bosnia and Herzegovina
# BLR	Belarus
# BLZ	Belize
# BOL	Bolivia
# BRA	Brazil
# BTN	Bhutan
# BWA	Botswana
# CAF	Central African Republic
# CHN	China
# CIV	Cote d'Ivoire
# CMR	Cameroon
# COD	Congo, Dem. Rep.
# COG	Congo, Rep.
# COL	Colombia
# COM	Comoros
# CPV	Cabo Verde
# CRI	Costa Rica
# CUB	Cuba
# DJI	Djibouti
# DMA	Dominica
# DOM	Dominican Republic
# DZA	Algeria
# ECU	Ecuador
# EGY	Egypt, Arab Rep.
# ERI	Eritrea
# ETH	Ethiopia
# FJI	Fiji
# FSM	Micronesia, Fed. Sts.
# GAB	Gabon
# GEO	Georgia
# GHA	Ghana
# GIN	Guinea
# GMB	Gambia, The
# GNB	Guinea-Bissau
# GNQ	Equatorial Guinea
# GRD	Grenada
# GTM	Guatemala
# GUY	Guyana
# HND	Honduras
# HTI	Haiti
# IDN	Indonesia
# IND	India
# IRN	Iran, Islamic Rep.
# IRQ	Iraq
# JAM	Jamaica
# JOR	Jordan
# KAZ	Kazakhstan
# KEN	Kenya
# KGZ	Kyrgyz Republic
# KHM	Cambodia
# KIR	Kiribati
# LAO	Lao PDR
# LBN	Lebanon
# LBR	Liberia
# LBY	Libya
# LCA	St. Lucia
# LKA	Sri Lanka
# LSO	Lesotho
# MAR	Morocco
# MDA	Moldova
# MDG	Madagascar
# MDV	Maldives
# MEX	Mexico
# MHL	Marshall Islands
# MKD	North Macedonia
# MLI	Mali
# MMR	Myanmar
# MNE	Montenegro
# MNG	Mongolia
# MOZ	Mozambique
# MRT	Mauritania
# MUS	Mauritius
# MWI	Malawi
# MYS	Malaysia
# NAM	Namibia
# NER	Niger
# NGA	Nigeria
# NIC	Nicaragua
# NPL	Nepal
# NRU	Nauru
# PAK	Pakistan
# PER	Peru
# PHL	Philippines
# PNG	Papua New Guinea
# PRK	Korea, Dem. People���s Rep.
# PRY	Paraguay
# PSE	West Bank and Gaza
# ROU	Romania
# RUS	Russian Federation
# RWA	Rwanda
# SDN	Sudan
# SEN	Senegal
# SLB	Solomon Islands
# SLE	Sierra Leone
# SLV	El Salvador
# SOM	Somalia
# SRB	Serbia
# SSD	South Sudan
# STP	Sao Tome and Principe
# SUR	Suriname
# SWZ	Eswatini
# SYR	Syrian Arab Republic
# TCD	Chad
# TGO	Togo
# THA	Thailand
# TJK	Tajikistan
# TKM	Turkmenistan
# TLS	Timor-Leste
# TON	Tonga
# TUN	Tunisia
# TUR	Turkey
# TUV	Tuvalu
# TZA	Tanzania
# UGA	Uganda
# UKR	Ukraine
# UZB	Uzbekistan
# VCT	St. Vincent and the Grenadines
# VEN	Venezuela, RB
# VNM	Vietnam
# VUT	Vanuatu
# WSM	Samoa
# XKX	Kosovo
# YEM	Yemen, Rep.
# ZAF	South Africa
# ZMB	Zambia
# ZWE	Zimbabwe

# %%
country = [
    'AFG',
'AGO',
'ALB',
'ARG',
'ARM',
'ASM',
'AZE',
'BDI',
'BEN',
'BFA',
'BGD',
'BGR',
'BIH',
'BLR',
'BLZ',
'BOL',
'BRA',
'BTN',
'BWA',
'CAF',
'CHN',
'CIV',
'CMR',
'COD',
'COG',
'COL',
'COM',
'CPV',
'CRI',
'CUB',
'DJI',
'DMA',
'DOM',
'DZA',
'ECU',
'EGY',
'ERI',
'ETH',
'FJI',
'FSM',
'GAB',
'GEO',
'GHA',
'GIN',
'GMB',
'GNB',
'GNQ',
'GRD',
'GTM',
'GUY',
'HND',
'HTI',
'IDN',
'IND',
'IRN',
'IRQ',
'JAM',
'JOR',
'KAZ',
'KEN',
'KGZ',
'KHM',
'KIR',
'LAO',
'LBN',
'LBR',
'LBY',
'LCA',
'LKA',
'LSO',
'MAR',
'MDA',
'MDG',
'MDV',
'MEX',
'MHL',
'MKD',
'MLI',
'MMR',
'MNE',
'MNG',
'MOZ',
'MRT',
'MUS',
'MWI',
'MYS',
'NAM',
'NER',
'NGA',
'NIC',
'NPL',
'NRU',
'PAK',
'PER',
'PHL',
'PNG',
'PRK',
'PRY',
'PSE',
'ROU',
'RUS',
'RWA',
'SDN',
'SEN',
'SLB',
'SLE',
'SLV',
'SOM',
'SRB',
'SSD',
'STP',
'SUR',
'SWZ',
'SYR',
'TCD',
'TGO',
'THA',
'TJK',
'TKM',
'TLS',
'TON',
'TUN',
'TUR',
'TUV',
'TZA',
'UGA',
'UKR',
'UZB',
'VCT',
'VEN',
'VNM',
'VUT',
'WSM',
'XKX',
'YEM',
'ZAF',
'ZMB',
'ZWE'
]

# %%
df = wb.get_dataframe({"NY.GNP.PCAP.CD": "GNI", "SI.POV.DDAY": "POV"}, country=country, keep_levels=False)
df.head()
# Out:
#                     GNI  POV
# country     date
# Afghanistan 2019    nan  nan
#             2018 550.00  nan
#             2017 550.00  nan
#             2016 570.00  nan
#             2015 600.00  nan

# %%
df.reset_index(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df[df.country=='India']
# Out:
#      country  date     GNI   POV
# 3188   India  2011 1360.00 21.20
# 3190   India  2009 1120.00 31.10
# 3195   India  2004  610.00 38.20
# 3206   India  1993  320.00 45.90
# 3212   India  1987  350.00 48.90
# 3216   India  1983  280.00 54.80
# 3222   India  1977  190.00 61.60

# %%
df[df.country=='India'].corr()
# Out:
#       GNI   POV
# GNI  1.00 -0.95
# POV -0.95  1.00

# %%
df[df.country=='Pakistan'].corr()
# Out:
#       GNI   POV
# GNI  1.00 -0.74
# POV -0.74  1.00

# %% [markdown]
# df = wb.get_dataframe({"NY.GNP.PCAP.CD": "GNI", "SI.POV.DDAY": "POV"}, country='LMY', keep_levels=False)
# df.reset_index(inplace=True)
# df.dropna(inplace=True)
# df

# %%
df.corr()
# Out:
#       GNI   POV
# GNI  1.00 -0.53
# POV -0.53  1.00

# %% [markdown]
# df = wb.get_dataframe({"NY.GNP.PCAP.CD": "GNIPC",
#                        "NY.GDP.PCAP.CD": "GDPPC",
#                        "NY.GNP.PCAP.PP.CD": "GNI2PC",
#                        "SI.POV.DDAY": "POV"}, country='ALL', keep_levels=False)
# df.reset_index(inplace=True)
# df.dropna(inplace=True)
# df

# %%
df.corr()
# Out:
#       GNI   POV
# GNI  1.00 -0.53
# POV -0.53  1.00

# %%
df = wb.get_dataframe({"NY.GNP.PCAP.CD": "GNIPC",
                       "NY.GDP.PCAP.CD": "GDPPC",
                       "NY.GNP.PCAP.PP.CD": "GNI2P%C",
                       "SI.POV.DDAY": "POV"}, country='LMY', keep_levels=False)
df.reset_index(inplace=True)
df.dropna(inplace=True)
print (df.corr())
df
# Out:
#          GNIPC  GDPPC  GNI2P%C   POV
# GNIPC     1.00   0.99     0.99 -0.95
# GDPPC     0.99   1.00     0.99 -0.95
# GNI2P%C   0.99   0.99     1.00 -0.98
# POV      -0.95  -0.95    -0.98  1.00
#     date   GNIPC   GDPPC  GNI2P%C   POV
# 4   2015 4554.48 4418.34  9905.69 11.80
# 6   2013 4522.93 4608.14  9027.94 13.30
# 7   2012 4185.87 4404.95  8577.00 15.20
# 8   2011 3698.38 4182.33  8082.14 16.30
# 9   2010 3331.46 3588.57  7517.87 18.80
# 11  2008 2777.01 3110.29  6825.20 21.70
# 14  2005 1716.56 1827.58  5145.01 24.80
# 17  2002 1170.49 1192.95  4054.74 30.70
# 20  1999 1104.56 1104.88  3447.98 34.60
# 23  1996 1098.78 1153.49  3116.89 35.80
# 26  1993  912.89  915.98  2726.07 41.60
# 29  1990  811.06  863.19  2447.94 44.10

# %%
df = wb.get_dataframe({"NY.GNP.PCAP.CD": "GNIPC",
                       "NY.GDP.PCAP.CD": "Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)",
                       "NY.GNP.PCAP.PP.CD": "GNI2=P()C",
                       "SI.POV.DDAY": "POV"}, country=country, keep_levels=False)
df.reset_index(inplace=True)
df.dropna(inplace=True)
print (df.corr())
df
# Out:
#                                                     GNIPC  \
# GNIPC                                                1.00
# Water productivity, total (constant 2010 US$ GD...   0.99
# GNI2=P()C                                            0.93
# POV                                                 -0.53
#
#                                                     Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)  \
# GNIPC                                                                                            0.99
# Water productivity, total (constant 2010 US$ GD...                                               1.00
# GNI2=P()C                                                                                        0.93
# POV                                                                                             -0.53
#
#                                                     GNI2=P()C   POV
# GNIPC                                                    0.93 -0.53
# Water productivity, total (constant 2010 US$ GD...       0.93 -0.53
# GNI2=P()C                                                1.00 -0.61
# POV                                                     -0.61  1.00
#                        country  date    GNIPC  \
# 71                      Angola  2008  3030.00
# 79                      Angola  2000   360.00
# 127                    Albania  2012  4360.00
# 131                    Albania  2008  4040.00
# 134                    Albania  2005  2620.00
# 137                    Albania  2002  1370.00
# 143                    Albania  1996   890.00
# 182                  Argentina  2017 13120.00
# 183                  Argentina  2016 12220.00
# 185                  Argentina  2014 12350.00
# 186                  Argentina  2013 12870.00
# 187                  Argentina  2012 11890.00
# 188                  Argentina  2011 10710.00
# 189                  Argentina  2010  9270.00
# 190                  Argentina  2009  7800.00
# 191                  Argentina  2008  7670.00
# 192                  Argentina  2007  6510.00
# 193                  Argentina  2006  5480.00
# 194                  Argentina  2005  4260.00
# 195                  Argentina  2004  3370.00
# 196                  Argentina  2003  3650.00
# 197                  Argentina  2002  4040.00
# 198                  Argentina  2001  7000.00
# 199                  Argentina  2000  7470.00
# 200                  Argentina  1999  7580.00
# 201                  Argentina  1998  8030.00
# 202                  Argentina  1997  8150.00
# 203                  Argentina  1996  7740.00
# 204                  Argentina  1995  7360.00
# 205                  Argentina  1994  7620.00
# 206                  Argentina  1993  7120.00
# 207                  Argentina  1992  6070.00
# 208                  Argentina  1991  3860.00
# 242                    Armenia  2017  3970.00
# 243                    Armenia  2016  3750.00
# 244                    Armenia  2015  4020.00
# 245                    Armenia  2014  4140.00
# 246                    Armenia  2013  4110.00
# 247                    Armenia  2012  3880.00
# 248                    Armenia  2011  3530.00
# 249                    Armenia  2010  3470.00
# 250                    Armenia  2009  3330.00
# 251                    Armenia  2008  3600.00
# 252                    Armenia  2007  2760.00
# 253                    Armenia  2006  2020.00
# 254                    Armenia  2005  1540.00
# 255                    Armenia  2004  1170.00
# 256                    Armenia  2003   960.00
# 257                    Armenia  2002   800.00
# 258                    Armenia  2001   710.00
# 260                    Armenia  1999   610.00
# 374                 Azerbaijan  2005  1270.00
# 375                 Azerbaijan  2004   940.00
# 376                 Azerbaijan  2003   810.00
# 377                 Azerbaijan  2002   710.00
# 378                 Azerbaijan  2001   660.00
# 384                 Azerbaijan  1995   400.00
# 426                    Burundi  2013   260.00
# 433                    Burundi  2006   150.00
# 441                    Burundi  1998   150.00
# 447                    Burundi  1992   210.00
# 484                      Benin  2015   860.00
# 488                      Benin  2011   800.00
# 496                      Benin  2003   440.00
# 545               Burkina Faso  2014   690.00
# 550               Burkina Faso  2009   550.00
# 556               Burkina Faso  2003   280.00
# 561               Burkina Faso  1998   250.00
# 565               Burkina Faso  1994   230.00
# 603                 Bangladesh  2016  1370.00
# 609                 Bangladesh  2010   800.00
# 614                 Bangladesh  2005   550.00
# 619                 Bangladesh  2000   440.00
# 624                 Bangladesh  1995   340.00
# 628                 Bangladesh  1991   320.00
# 665                   Bulgaria  2014  7730.00
# 666                   Bulgaria  2013  7590.00
# 667                   Bulgaria  2012  7420.00
# 668                   Bulgaria  2011  7220.00
# 669                   Bulgaria  2010  6980.00
# 670                   Bulgaria  2009  6750.00
# 671                   Bulgaria  2008  6100.00
# 672                   Bulgaria  2007  4820.00
# 673                   Bulgaria  2006  4270.00
# 687                   Bulgaria  1992  1430.00
# 728     Bosnia and Herzegovina  2011  5010.00
# 732     Bosnia and Herzegovina  2007  3920.00
# 735     Bosnia and Herzegovina  2004  2590.00
# 738     Bosnia and Herzegovina  2001  1610.00
# 782                    Belarus  2017  5300.00
# 783                    Belarus  2016  5620.00
# 784                    Belarus  2015  6720.00
# 785                    Belarus  2014  7600.00
# 786                    Belarus  2013  7010.00
# 787                    Belarus  2012  6670.00
# 788                    Belarus  2011  6330.00
# 789                    Belarus  2010  6210.00
# 790                    Belarus  2009  5660.00
# 791                    Belarus  2008  5470.00
# 792                    Belarus  2007  4310.00
# 793                    Belarus  2006  3510.00
# 794                    Belarus  2005  2820.00
# 795                    Belarus  2004  2180.00
# 796                    Belarus  2003  1630.00
# 797                    Belarus  2002  1380.00
# 798                    Belarus  2001  1300.00
# 799                    Belarus  2000  1380.00
# 800                    Belarus  1999  1400.00
# 801                    Belarus  1998  1550.00
# 860                     Belize  1999  2880.00
# 861                     Belize  1998  2780.00
# 862                     Belize  1997  2890.00
# 863                     Belize  1996  2880.00
# 865                     Belize  1994  2770.00
# 866                     Belize  1993  2790.00
# 902                    Bolivia  2017  3090.00
# 903                    Bolivia  2016  3040.00
# 904                    Bolivia  2015  2960.00
# 905                    Bolivia  2014  2830.00
# 906                    Bolivia  2013  2590.00
# 907                    Bolivia  2012  2250.00
# 908                    Bolivia  2011  1990.00
# 910                    Bolivia  2009  1620.00
# 911                    Bolivia  2008  1480.00
# 912                    Bolivia  2007  1220.00
# 913                    Bolivia  2006  1110.00
# 914                    Bolivia  2005  1020.00
# 915                    Bolivia  2004   950.00
# 917                    Bolivia  2002   920.00
# 918                    Bolivia  2001   950.00
# 919                    Bolivia  2000   980.00
# 920                    Bolivia  1999   980.00
# 922                    Bolivia  1997   950.00
# 929                    Bolivia  1990   720.00
# 960                     Brazil  1999  4120.00
# 961                     Brazil  1998  4840.00
# 962                     Brazil  1997  5020.00
# 963                     Brazil  1996  4460.00
# 964                     Brazil  1995  3760.00
# 966                     Brazil  1993  3090.00
# 967                     Brazil  1992  3170.00
# 969                     Brazil  1990  2730.00
# 1002                    Brazil  2017  8670.00
# 1003                    Brazil  2016  8930.00
# 1004                    Brazil  2015 10160.00
# 1005                    Brazil  2014 12100.00
# 1006                    Brazil  2013 12810.00
# 1007                    Brazil  2012 12360.00
# 1008                    Brazil  2011 11080.00
# 1010                    Brazil  2009  8320.00
# 1011                    Brazil  2008  7620.00
# 1012                    Brazil  2007  6190.00
# 1013                    Brazil  2006  4850.00
# 1014                    Brazil  2005  4000.00
# 1015                    Brazil  2004  3340.00
# 1016                    Brazil  2003  2980.00
# 1017                    Brazil  2002  3090.00
# 1018                    Brazil  2001  3350.00
# 1022                    Bhutan  2017  2890.00
# 1027                    Bhutan  2012  2450.00
# 1032                    Bhutan  2007  1670.00
# 1036                    Bhutan  2003   930.00
# 1084                  Botswana  2015  6960.00
# 1090                  Botswana  2009  5330.00
# 1097                  Botswana  2002  2930.00
# 1106                  Botswana  1993  3330.00
# 1151  Central African Republic  2008   420.00
# 1156  Central African Republic  2003   260.00
# 1167  Central African Republic  1992   470.00
# 1204                     China  2015  7910.00
# 1205                     China  2014  7500.00
# 1206                     China  2013  6770.00
# 1207                     China  2012  5930.00
# 1208                     China  2011  5050.00
# 1209                     China  2010  4340.00
# 1211                     China  2008  3100.00
# 1214                     China  2005  1760.00
# 1217                     China  2002  1110.00
# 1220                     China  1999   860.00
# 1223                     China  1996   650.00
# 1226                     China  1993   420.00
# 1229                     China  1990   330.00
# 1264             Cote d'Ivoire  2015  1480.00
# 1271             Cote d'Ivoire  2008  1070.00
# 1277             Cote d'Ivoire  2002   560.00
# 1281             Cote d'Ivoire  1998   760.00
# 1284             Cote d'Ivoire  1995   700.00
# 1287             Cote d'Ivoire  1992   780.00
# 1325                  Cameroon  2014  1480.00
# 1332                  Cameroon  2007  1110.00
# 1338                  Cameroon  2001   640.00
# 1343                  Cameroon  1996   740.00
# 1387          Congo, Dem. Rep.  2012   380.00
# 1395          Congo, Dem. Rep.  2004   190.00
# 1448               Congo, Rep.  2011  2120.00
# 1454               Congo, Rep.  2005   950.00
# 1502                  Colombia  2017  5930.00
# 1503                  Colombia  2016  6460.00
# 1504                  Colombia  2015  7330.00
# 1505                  Colombia  2014  8190.00
# 1506                  Colombia  2013  7910.00
# 1507                  Colombia  2012  7290.00
# 1508                  Colombia  2011  6320.00
# 1509                  Colombia  2010  5610.00
# 1510                  Colombia  2009  5130.00
# 1511                  Colombia  2008  4700.00
# 1514                  Colombia  2005  2990.00
# 1515                  Colombia  2004  2620.00
# 1516                  Colombia  2003  2370.00
# 1517                  Colombia  2002  2370.00
# 1518                  Colombia  2001  2330.00
# 1519                  Colombia  2000  2340.00
# 1520                  Colombia  1999  2330.00
# 1523                  Colombia  1996  2540.00
# 1527                  Colombia  1992  1560.00
# 1566                   Comoros  2013  1490.00
# 1575                   Comoros  2004   940.00
# 1632                Cabo Verde  2007  2820.00
# 1638                Cabo Verde  2001  1350.00
# 1682                Costa Rica  2017 11090.00
# 1683                Costa Rica  2016 10770.00
# 1684                Costa Rica  2015 10400.00
# 1685                Costa Rica  2014 10090.00
# 1686                Costa Rica  2013  9740.00
# 1687                Costa Rica  2012  9150.00
# 1688                Costa Rica  2011  8000.00
# 1689                Costa Rica  2010  7180.00
# 1690                Costa Rica  2009  6490.00
# 1691                Costa Rica  2008  6370.00
# 1692                Costa Rica  2007  5640.00
# 1693                Costa Rica  2006  5030.00
# 1694                Costa Rica  2005  4620.00
# 1695                Costa Rica  2004  4360.00
# 1696                Costa Rica  2003  4010.00
# 1697                Costa Rica  2002  3750.00
# 1698                Costa Rica  2001  3660.00
# 1699                Costa Rica  2000  3550.00
# 1700                Costa Rica  1999  3440.00
# 1701                Costa Rica  1998  3380.00
# 1702                Costa Rica  1997  3330.00
# 1703                Costa Rica  1996  3220.00
# 1704                Costa Rica  1995  3170.00
# 1705                Costa Rica  1994  2960.00
# 1706                Costa Rica  1993  2720.00
# 1707                Costa Rica  1992  2340.00
# 1708                Costa Rica  1991  1950.00
# 1709                Costa Rica  1990  1750.00
# 1923        Dominican Republic  2016  6640.00
# 1924        Dominican Republic  2015  6480.00
# 1925        Dominican Republic  2014  6310.00
# ...                        ...   ...      ...
# 5830                  Paraguay  2009  3450.00
# 5831                  Paraguay  2008  3080.00
# 5832                  Paraguay  2007  2320.00
# 5833                  Paraguay  2006  1840.00
# 5834                  Paraguay  2005  1520.00
# 5835                  Paraguay  2004  1350.00
# 5836                  Paraguay  2003  1230.00
# 5837                  Paraguay  2002  1330.00
# 5838                  Paraguay  2001  1410.00
# 5840                  Paraguay  1999  1600.00
# 5842                  Paraguay  1997  1840.00
# 5844                  Paraguay  1995  1680.00
# 5883        West Bank and Gaza  2016  3460.00
# 5888        West Bank and Gaza  2011  2720.00
# 5889        West Bank and Gaza  2010  2330.00
# 5890        West Bank and Gaza  2009  2080.00
# 5892        West Bank and Gaza  2007  1700.00
# 5893        West Bank and Gaza  2006  1570.00
# 5894        West Bank and Gaza  2005  1660.00
# 5895        West Bank and Gaza  2004  1510.00
# 5944                   Romania  2015  9520.00
# 5945                   Romania  2014  9610.00
# 5946                   Romania  2013  9250.00
# 5947                   Romania  2012  8780.00
# 5948                   Romania  2011  8620.00
# 5949                   Romania  2010  8610.00
# 5950                   Romania  2009  9190.00
# 5951                   Romania  2008  8770.00
# 5952                   Romania  2007  6510.00
# 5953                   Romania  2006  4900.00
# 5965                   Romania  1994  1270.00
# 5967                   Romania  1992  1250.00
# 6004        Russian Federation  2015 11770.00
# 6005        Russian Federation  2014 14650.00
# 6006        Russian Federation  2013 15210.00
# 6007        Russian Federation  2012 13480.00
# 6008        Russian Federation  2011 11070.00
# 6009        Russian Federation  2010  9980.00
# 6010        Russian Federation  2009  9230.00
# 6011        Russian Federation  2008  9580.00
# 6012        Russian Federation  2007  7560.00
# 6013        Russian Federation  2006  5810.00
# 6014        Russian Federation  2005  4450.00
# 6015        Russian Federation  2004  3410.00
# 6016        Russian Federation  2003  2590.00
# 6017        Russian Federation  2002  2100.00
# 6018        Russian Federation  2001  1780.00
# 6019        Russian Federation  2000  1710.00
# 6020        Russian Federation  1999  1750.00
# 6021        Russian Federation  1998  2130.00
# 6022        Russian Federation  1997  2650.00
# 6023        Russian Federation  1996  2600.00
# 6026        Russian Federation  1993  2920.00
# 6063                    Rwanda  2016   720.00
# 6066                    Rwanda  2013   700.00
# 6069                    Rwanda  2010   570.00
# 6074                    Rwanda  2005   290.00
# 6079                    Rwanda  2000   250.00
# 6130                     Sudan  2009  1180.00
# 6188                   Senegal  2011  1310.00
# 6194                   Senegal  2005  1000.00
# 6198                   Senegal  2001   630.00
# 6205                   Senegal  1994   750.00
# 6208                   Senegal  1991   910.00
# 6246           Solomon Islands  2013  1770.00
# 6254           Solomon Islands  2005   890.00
# 6308              Sierra Leone  2011   430.00
# 6316              Sierra Leone  2003   270.00
# 6362               El Salvador  2017  3600.00
# 6363               El Salvador  2016  3510.00
# 6364               El Salvador  2015  3440.00
# 6365               El Salvador  2014  3400.00
# 6366               El Salvador  2013  3350.00
# 6367               El Salvador  2012  3210.00
# 6368               El Salvador  2011  3060.00
# 6369               El Salvador  2010  2890.00
# 6370               El Salvador  2009  2820.00
# 6371               El Salvador  2008  2870.00
# 6372               El Salvador  2007  2680.00
# 6373               El Salvador  2006  2570.00
# 6374               El Salvador  2005  2420.00
# 6375               El Salvador  2004  2270.00
# 6376               El Salvador  2003  2130.00
# 6377               El Salvador  2002  2000.00
# 6378               El Salvador  2001  1950.00
# 6379               El Salvador  2000  1900.00
# 6380               El Salvador  1999  1810.00
# 6381               El Salvador  1998  1750.00
# 6383               El Salvador  1996  1590.00
# 6384               El Salvador  1995  1480.00
# 6388               El Salvador  1991   930.00
# 6484                    Serbia  2015  5960.00
# 6485                    Serbia  2014  6240.00
# 6486                    Serbia  2013  6460.00
# 6487                    Serbia  2012  6090.00
# 6609     Sao Tome and Principe  2010  1130.00
# 6680                  Suriname  1999  1950.00
# 6730                  Eswatini  2009  3320.00
# 6739                  Eswatini  2000  1670.00
# 6745                  Eswatini  1994  1570.00
# 6848                      Chad  2011   880.00
# 6856                      Chad  2003   210.00
# 6904                      Togo  2015   640.00
# 6908                      Togo  2011   610.00
# 6913                      Togo  2006   420.00
# 6960                  Thailand  1999  1980.00
# 6961                  Thailand  1998  2080.00
# 6963                  Thailand  1996  2950.00
# 6965                  Thailand  1994  2400.00
# 6967                  Thailand  1992  1880.00
# 6969                  Thailand  1990  1490.00
# 7002                  Thailand  2017  5950.00
# 7003                  Thailand  2016  5690.00
# 7004                  Thailand  2015  5710.00
# 7005                  Thailand  2014  5760.00
# 7006                  Thailand  2013  5720.00
# 7007                  Thailand  2012  5520.00
# 7008                  Thailand  2011  4950.00
# 7009                  Thailand  2010  4580.00
# 7010                  Thailand  2009  4140.00
# 7011                  Thailand  2008  3970.00
# 7012                  Thailand  2007  3530.00
# 7013                  Thailand  2006  3100.00
# 7015                  Thailand  2004  2530.00
# 7017                  Thailand  2002  1990.00
# 7019                  Thailand  2000  1980.00
# 7024                Tajikistan  2015  1250.00
# 7030                Tajikistan  2009   660.00
# 7032                Tajikistan  2007   440.00
# 7035                Tajikistan  2004   270.00
# 7036                Tajikistan  2003   210.00
# 7040                Tajikistan  1999   180.00
# 7101              Turkmenistan  1998   560.00
# 7145               Timor-Leste  2014  2960.00
# 7152               Timor-Leste  2007  1910.00
# 7204                     Tonga  2015  4520.00
# 7210                     Tonga  2009  3370.00
# 7218                     Tonga  2001  2000.00
# 7264                   Tunisia  2015  3970.00
# 7269                   Tunisia  2010  4130.00
# 7274                   Tunisia  2005  3160.00
# 7279                   Tunisia  2000  2270.00
# 7284                   Tunisia  1995  1790.00
# 7289                   Tunisia  1990  1410.00
# 7323                    Turkey  2016 11180.00
# 7324                    Turkey  2015 11960.00
# 7325                    Turkey  2014 12560.00
# 7326                    Turkey  2013 12510.00
# 7327                    Turkey  2012 11870.00
# 7328                    Turkey  2011 11230.00
# 7329                    Turkey  2010 10430.00
# 7330                    Turkey  2009  9580.00
# 7331                    Turkey  2008  9780.00
# 7332                    Turkey  2007  8880.00
# 7333                    Turkey  2006  7820.00
# 7334                    Turkey  2005  6760.00
# 7335                    Turkey  2004  5220.00
# 7336                    Turkey  2003  3910.00
# 7337                    Turkey  2002  3560.00
# 7345                    Turkey  1994  2680.00
# 7389                    Tuvalu  2010  4400.00
# 7448                  Tanzania  2011   770.00
# 7452                  Tanzania  2007   540.00
# 7459                  Tanzania  2000   410.00
# 7468                  Tanzania  1991   190.00
# 7503                    Uganda  2016   660.00
# 7507                    Uganda  2012   640.00
# 7510                    Uganda  2009   510.00
# 7514                    Uganda  2005   310.00
# 7517                    Uganda  2002   250.00
# 7520                    Uganda  1999   290.00
# 7523                    Uganda  1996   280.00
# 7527                    Uganda  1992   190.00
# 7563                   Ukraine  2016  2310.00
# 7564                   Ukraine  2015  2650.00
# 7565                   Ukraine  2014  3560.00
# 7566                   Ukraine  2013  3800.00
# 7567                   Ukraine  2012  3500.00
# 7568                   Ukraine  2011  3110.00
# 7569                   Ukraine  2010  2980.00
# 7570                   Ukraine  2009  2840.00
# 7571                   Ukraine  2008  3210.00
# 7572                   Ukraine  2007  2560.00
# 7573                   Ukraine  2006  1950.00
# 7574                   Ukraine  2005  1540.00
# 7575                   Ukraine  2004  1270.00
# 7576                   Ukraine  2003   980.00
# 7577                   Ukraine  2002   790.00
# 7583                   Ukraine  1996   860.00
# 7584                   Ukraine  1995   920.00
# 7586                   Ukraine  1993  1230.00
# 7587                   Ukraine  1992  1420.00
# 7636                Uzbekistan  2003   420.00
# 7637                Uzbekistan  2002   450.00
# 7639                Uzbekistan  2000   630.00
# 7641                Uzbekistan  1998   620.00
# 7753             Venezuela, RB  2006  6130.00
# 7754             Venezuela, RB  2005  4980.00
# 7755             Venezuela, RB  2004  4110.00
# 7756             Venezuela, RB  2003  3490.00
# 7757             Venezuela, RB  2002  3990.00
# 7758             Venezuela, RB  2001  4600.00
# 7760             Venezuela, RB  1999  3570.00
# 7761             Venezuela, RB  1998  3420.00
# 7764             Venezuela, RB  1995  3040.00
# 7767             Venezuela, RB  1992  2870.00
# 7803                   Vietnam  2016  2080.00
# 7805                   Vietnam  2014  1880.00
# 7807                   Vietnam  2012  1540.00
# 7809                   Vietnam  2010  1250.00
# 7811                   Vietnam  2008   980.00
# 7813                   Vietnam  2006   720.00
# 7815                   Vietnam  2004   580.00
# 7817                   Vietnam  2002   450.00
# 7821                   Vietnam  1998   340.00
# 7827                   Vietnam  1992   130.00
# 7869                   Vanuatu  2010  2690.00
# 7926                     Samoa  2013  3950.00
# 7931                     Samoa  2008  3070.00
# 7937                     Samoa  2002  1520.00
# 8002                    Kosovo  2017  3900.00
# 8003                    Kosovo  2016  3880.00
# 8004                    Kosovo  2015  3980.00
# 8005                    Kosovo  2014  3990.00
# 8006                    Kosovo  2013  3950.00
# 8007                    Kosovo  2012  3790.00
# 8008                    Kosovo  2011  3640.00
# 8009                    Kosovo  2010  3420.00
# 8010                    Kosovo  2009  3240.00
# 8013                    Kosovo  2006  2430.00
# 8045               Yemen, Rep.  2014  1460.00
# 8054               Yemen, Rep.  2005   700.00
# 8061               Yemen, Rep.  1998   370.00
# 8105              South Africa  2014  6750.00
# 8109              South Africa  2010  6190.00
# 8111              South Africa  2008  5980.00
# 8114              South Africa  2005  4990.00
# 8119              South Africa  2000  3070.00
# 8123              South Africa  1996  3660.00
# 8126              South Africa  1993  3380.00
# 8164                    Zambia  2015  1580.00
# 8169                    Zambia  2010  1340.00
# 8173                    Zambia  2006   720.00
# 8175                    Zambia  2004   460.00
# 8177                    Zambia  2002   360.00
# 8181                    Zambia  1998   360.00
# 8183                    Zambia  1996   400.00
# 8186                    Zambia  1993   380.00
# 8188                    Zambia  1991   390.00
# 8228                  Zimbabwe  2011   920.00
#
#       Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 71                                              4080.94
# 79                                               556.84
# 127                                             4247.61
# 131                                             4370.54
# 134                                             2673.79
# 137                                             1425.12
# 143                                             1009.98
# 182                                            14591.86
# 183                                            12790.24
# 185                                            12334.80
# 186                                            13080.25
# 187                                            13082.66
# 188                                            12848.86
# 189                                            10385.96
# 190                                             8225.14
# 191                                             9020.87
# 192                                             7245.45
# 193                                             5919.01
# 194                                             5109.85
# 195                                             4277.72
# 196                                             3349.81
# 197                                             2593.40
# 198                                             7208.37
# 199                                             7708.10
# 200                                             7774.74
# 201                                             8289.51
# 202                                             8213.13
# 203                                             7721.35
# 204                                             7408.71
# 205                                             7483.14
# 206                                             6969.12
# 207                                             6823.54
# 208                                             5735.36
# 242                                             3914.50
# 243                                             3591.83
# 244                                             3607.30
# 245                                             3986.23
# 246                                             3838.19
# 247                                             3681.86
# 248                                             3525.80
# 249                                             3218.37
# 250                                             2994.34
# 251                                             4010.86
# 252                                             3139.28
# 253                                             2158.14
# 254                                             1643.75
# 255                                             1191.92
# 256                                              930.13
# 257                                              783.24
# 258                                              694.42
# 260                                              597.43
# 374                                             1578.40
# 375                                             1045.01
# 376                                              883.64
# 377                                              763.08
# 378                                              703.68
# 384                                              397.20
# 426                                              256.98
# 433                                              167.38
# 441                                              144.49
# 447                                              190.49
# 484                                              783.96
# 488                                              825.94
# 496                                              519.29
# 545                                              703.82
# 550                                              552.75
# 556                                              332.34
# 561                                              255.72
# 565                                              193.07
# 603                                             1401.62
# 609                                              781.15
# 614                                              499.46
# 619                                              418.07
# 624                                              329.42
# 628                                              293.16
# 665                                             7864.76
# 666                                             7646.84
# 667                                             7378.02
# 668                                             7813.81
# 669                                             6843.27
# 670                                             6969.56
# 671                                             7261.75
# 672                                             5885.95
# 673                                             4490.20
# 687                                             1211.98
# 728                                             5092.55
# 732                                             4193.37
# 735                                             2815.00
# 738                                             1530.81
# 782                                             5761.75
# 783                                             5022.63
# 784                                             5949.11
# 785                                             8318.51
# 786                                             7978.87
# 787                                             6940.16
# 788                                             6519.23
# 789                                             6181.40
# 790                                             5351.36
# 791                                             6377.37
# 792                                             4735.66
# 793                                             3847.43
# 794                                             3125.81
# 795                                             2378.62
# 796                                             1819.77
# 797                                             1479.31
# 798                                             1244.37
# 799                                             1276.29
# 800                                             1210.61
# 801                                             1511.77
# 860                                             3065.98
# 861                                             2992.44
# 862                                             2952.95
# 863                                             3001.83
# 865                                             2880.13
# 866                                             2832.98
# 902                                             3351.12
# 903                                             3076.66
# 904                                             3035.97
# 905                                             3081.88
# 906                                             2908.20
# 907                                             2609.88
# 908                                             2346.34
# 910                                             1754.21
# 911                                             1715.21
# 912                                             1372.63
# 913                                             1218.87
# 914                                             1034.31
# 915                                              967.41
# 917                                              904.23
# 918                                              948.87
# 919                                              997.58
# 920                                             1003.39
# 922                                              998.52
# 929                                              709.06
# 960                                             3478.37
# 961                                             5087.15
# 962                                             5282.01
# 963                                             5166.16
# 964                                             4748.22
# 966                                             2791.21
# 967                                             2596.92
# 969                                             3100.28
# 1002                                            9880.95
# 1003                                            8712.89
# 1004                                            8814.00
# 1005                                           12112.59
# 1006                                           12300.32
# 1007                                           12370.02
# 1008                                           13245.62
# 1010                                            8597.92
# 1011                                            8831.02
# 1012                                            7348.03
# 1013                                            5886.46
# 1014                                            4790.44
# 1015                                            3637.46
# 1016                                            3070.91
# 1017                                            2829.28
# 1018                                            3156.80
# 1022                                            3390.71
# 1027                                            2599.40
# 1032                                            1798.97
# 1036                                             990.74
# 1084                                            6799.88
# 1090                                            5255.77
# 1097                                            3190.62
# 1106                                            2973.38
# 1151                                             464.56
# 1156                                             293.66
# 1167                                             477.12
# 1204                                            8033.39
# 1205                                            7651.37
# 1206                                            7050.65
# 1207                                            6316.92
# 1208                                            5618.13
# 1209                                            4550.45
# 1211                                            3468.30
# 1214                                            1753.42
# 1217                                            1148.51
# 1220                                             873.29
# 1223                                             709.41
# 1226                                             377.39
# 1229                                             317.88
# 1264                                            1426.46
# 1271                                            1235.61
# 1277                                             716.53
# 1281                                             809.01
# 1284                                             774.67
# 1287                                             870.48
# 1325                                            1540.57
# 1332                                            1194.07
# 1338                                             651.10
# 1343                                             752.53
# 1387                                             424.60
# 1395                                             194.04
# 1448                                            3282.39
# 1454                                            1680.20
# 1502                                            6375.93
# 1503                                            5871.22
# 1504                                            6175.88
# 1505                                            8114.08
# 1506                                            8212.67
# 1507                                            8042.53
# 1508                                            7324.38
# 1509                                            6326.55
# 1510                                            5195.39
# 1511                                            5461.78
# ...
# 7817                                             430.05
# 7821                                             348.32
# 7827                                             139.20
# 7869                                            2966.86
# 7926                                            4219.91
# 7931                                            3514.80
# 7937                                            1633.04
# 8002                                            3948.09
# 8003                                            3697.12
# 8004                                            3574.54
# 8005                                            4054.72
# 8006                                            3876.96
# 8007                                            3600.67
# 8008                                            3736.36
# 8009                                            3283.51
# 8010                                            3209.69
# 8013                                            2237.13
# 8045                                            1674.00
# 8054                                             832.84
# 8061                                             384.50
# 8105                                            6428.29
# 8109                                            7328.59
# 8111                                            5760.79
# 8114                                            5383.63
# 8119                                            3032.43
# 8123                                            3494.38
# 8126                                            3388.73
# 8164                                            1332.19
# 8169                                            1489.46
# 8173                                            1047.92
# 8175                                             538.59
# 8177                                             382.24
# 8181                                             358.56
# 8183                                             385.15
# 8186                                             378.13
# 8188                                             409.73
# 8228                                            1093.65
#
#       GNI2=P()C   POV
# 71      5260.00 30.10
# 79      2530.00 32.30
# 127    10450.00  1.10
# 131     8270.00  0.40
# 134     5980.00  1.10
# 137     4780.00  2.00
# 143     3050.00  1.10
# 182    20310.00  0.50
# 183    19690.00  0.70
# 185    19600.00  0.70
# 186    19930.00  0.70
# 187    19300.00  0.80
# 188    19250.00  0.90
# 189    17890.00  2.20
# 190    16240.00  2.50
# 191    17410.00  2.60
# 192    16550.00  2.60
# 193    14830.00  3.20
# 194    12340.00  3.70
# 195    11140.00  5.20
# 196    10850.00  6.80
# 197     9790.00 14.00
# 198    11180.00  9.40
# 199    11600.00  5.70
# 200    11570.00  4.80
# 201    11950.00  4.60
# 202    11550.00  4.10
# 203    10640.00  4.60
# 204    10040.00  4.10
# 205    10290.00  2.30
# 206     9650.00  2.40
# 207     8780.00  2.10
# 208     7960.00  1.10
# 242    10010.00  1.40
# 243     9000.00  1.80
# 244     9090.00  1.90
# 245     8800.00  2.30
# 246     8490.00  2.20
# 247     7950.00  1.60
# 248     7270.00  2.20
# 249     6890.00  1.90
# 250     6590.00  1.90
# 251     7700.00  1.40
# 252     6970.00  2.80
# 253     5870.00  3.20
# 254     4970.00  4.50
# 255     4160.00  7.90
# 256     3660.00 11.40
# 257     3140.00 15.10
# 258     2700.00 19.30
# 260     2200.00 16.90
# 374     6380.00  0.00
# 375     5130.00  0.00
# 376     4710.00  0.00
# 377     4230.00  0.00
# 378     3840.00  2.70
# 384     2500.00  7.30
# 426      790.00 71.80
# 433      640.00 77.70
# 441      570.00 84.10
# 447      710.00 81.10
# 484     2110.00 49.50
# 488     1820.00 53.10
# 496     1450.00 48.80
# 545     1620.00 43.70
# 550     1340.00 55.30
# 556      990.00 57.30
# 561      800.00 81.60
# 565      620.00 83.10
# 603     3910.00 14.80
# 609     2670.00 19.60
# 614     1850.00 25.70
# 619     1390.00 34.80
# 624     1120.00 35.70
# 628      920.00 44.20
# 665    17380.00  1.50
# 666    16200.00  1.70
# 667    15990.00  2.00
# 668    15180.00  2.20
# 669    14620.00  2.00
# 670    13880.00  1.20
# 671    13720.00  1.20
# 672    11870.00  1.70
# 673    11030.00  5.50
# 687     6750.00  0.00
# 728    10060.00  0.10
# 732     8430.00  0.10
# 735     6500.00  0.20
# 738     5200.00  0.30
# 782    18200.00  0.00
# 783    17270.00  0.00
# 784    17590.00  0.00
# 785    18370.00  0.00
# 786    17650.00  0.00
# 787    17410.00  0.00
# 788    16820.00  0.00
# 789    15630.00  0.00
# 790    14260.00  0.00
# 791    14220.00  0.00
# 792    12670.00  0.10
# 793    11370.00  0.10
# 794    10020.00  0.40
# 795     8820.00  0.30
# 796     7660.00  1.40
# 797     6950.00  2.10
# 798     6460.00  3.20
# 799     6010.00  7.10
# 800     5530.00 10.50
# 801     5230.00 11.60
# 860     4680.00 13.90
# 861     4440.00 14.40
# 862     4450.00 16.00
# 863     4360.00 13.30
# 865     4340.00  9.90
# 866     4380.00 10.10
# 902     7270.00  5.80
# 903     7020.00  7.10
# 904     6650.00  6.40
# 905     6250.00  5.80
# 906     5840.00  6.90
# 907     5470.00  8.20
# 908     5260.00  7.30
# 910     4850.00 10.50
# 911     4770.00 11.10
# 912     4460.00 12.40
# 913     4230.00 16.40
# 914     3970.00 19.30
# 915     3740.00 13.70
# 917     3530.00 24.70
# 918     3450.00 22.80
# 919     3380.00 28.60
# 920     3300.00 25.30
# 922     3170.00 19.30
# 929     2280.00  7.10
# 960     8170.00 13.40
# 961     8210.00 12.70
# 962     8320.00 14.00
# 963     8080.00 14.20
# 964     7980.00 13.00
# 966     7120.00 19.90
# 967     6790.00 20.90
# 969     6530.00 21.60
# 1002   15370.00  4.80
# 1003   15010.00  4.30
# 1004   15470.00  3.40
# 1005   16030.00  2.80
# 1006   15920.00  3.80
# 1007   15180.00  3.80
# 1008   14670.00  4.70
# 1010   12990.00  5.40
# 1011   13010.00  5.60
# 1012   12300.00  6.80
# 1013   11370.00  7.20
# 1014   10690.00  8.60
# 1015   10150.00  9.70
# 1016    9440.00 11.10
# 1017    9260.00 10.30
# 1018    8970.00 11.60
# 1022    9320.00  1.50
# 1027    7090.00  2.20
# 1032    5230.00  8.00
# 1036    3430.00 17.60
# 1084   16470.00 16.10
# 1090   11730.00 18.20
# 1097    7910.00 29.80
# 1106    6630.00 34.80
# 1151     840.00 66.30
# 1156     690.00 64.80
# 1167     590.00 84.30
# 1204   14400.00  0.70
# 1205   13460.00  1.40
# 1206   12260.00  1.90
# 1207   11300.00  6.50
# 1208   10260.00  7.90
# 1209    9260.00 11.20
# 1211    7660.00 14.80
# 1214    5050.00 18.50
# 1217    3520.00 31.70
# 1220    2630.00 40.20
# 1223    2040.00 41.70
# 1226    1460.00 56.60
# 1229     990.00 66.20
# 1264    3340.00 28.20
# 1271    2460.00 29.10
# 1277    2030.00 23.20
# 1281    2320.00 25.80
# 1284    1980.00 19.60
# 1287    1840.00 22.40
# 1325    3280.00 23.80
# 1332    2630.00 29.30
# 1338    1980.00 23.10
# 1343    1690.00 48.10
# 1387     680.00 76.60
# 1395     480.00 94.10
# 1448    3980.00 37.00
# 1454    2870.00 53.40
# 1502   14240.00  3.90
# 1503   14110.00  4.50
# 1504   13810.00  4.50
# 1505   13210.00  5.00
# 1506   12440.00  5.70
# 1507   11760.00  6.20
# 1508   11150.00  6.30
# 1509   10340.00  7.70
# 1510    9960.00  8.90
# 1511    9840.00 10.40
# 1514    8110.00  9.70
# 1515    7540.00 10.90
# 1516    7070.00 12.00
# 1517    6830.00 14.30
# 1518    6680.00 19.70
# 1519    6550.00 16.40
# 1520    6360.00 20.10
# 1523    6400.00 16.50
# 1527    5200.00  8.90
# 1566    2630.00 17.90
# 1575    2040.00 13.50
# 1632    5320.00  8.10
# 1638    3150.00 16.20
# 1682   16110.00  1.00
# 1683   15570.00  1.30
# 1684   14920.00  1.50
# 1685   14430.00  1.40
# 1686   13910.00  1.60
# 1687   13590.00  1.60
# 1688   12850.00  1.60
# 1689   12230.00  1.50
# 1690   11660.00  2.40
# 1691   12000.00  2.20
# 1692   11320.00  1.70
# 1693   10300.00  3.20
# 1694    9370.00  3.10
# 1695    8830.00  4.30
# 1696    8330.00  4.40
# 1697    7960.00  4.50
# 1698    7720.00  4.70
# 1699    7430.00  6.50
# 1700    7210.00  6.40
# 1701    7110.00  5.10
# 1702    6790.00  6.50
# 1703    6480.00  8.00
# 1704    6410.00  6.90
# 1705    6210.00  6.60
# 1706    5890.00  8.00
# 1707    5500.00  9.60
# 1708    5040.00 11.70
# 1709    4800.00  9.90
# 1923   14910.00  1.60
# 1924   14020.00  1.80
# 1925   13020.00  2.10
# ...         ...   ...
# 5830    8190.00  5.80
# 5831    8290.00  4.30
# 5832    7660.00  7.80
# 5833    6850.00  7.90
# 5834    6230.00  6.10
# 5835    5980.00  5.70
# 5836    5590.00  8.30
# 5837    5770.00 13.20
# 5838    5630.00  8.90
# 5840    5950.00 10.20
# 5842    6140.00 10.60
# 5844    5750.00 12.40
# 5883    5670.00  1.00
# 5888    4720.00  0.20
# 5889    4200.00  0.20
# 5890    3970.00  0.30
# 5892    3630.00  1.50
# 5893    3350.00  0.30
# 5894    3430.00  0.90
# 5895    3020.00  1.10
# 5944   21130.00  5.70
# 5945   20360.00  7.50
# 5946   19370.00  7.20
# 5947   18600.00  6.70
# 5948   17610.00  5.70
# 5949   16710.00  4.50
# 5950   16380.00  3.50
# 5951   16360.00  4.50
# 5952   13240.00  5.70
# 5953   11160.00  8.00
# 5965    4970.00 10.70
# 5967    4490.00  0.60
# 6004   23400.00  0.00
# 6005   24900.00  0.00
# 6006   25330.00  0.00
# 6007   25000.00  0.00
# 6008   23590.00  0.00
# 6009   19860.00  0.10
# 6010   18760.00  0.00
# 6011   19600.00  0.10
# 6012   16280.00  0.10
# 6013   14480.00  0.30
# 6014   11540.00  0.50
# 6015   10010.00  0.70
# 6016    8970.00  0.80
# 6017    7880.00  0.70
# 6018    7260.00  1.30
# 6019    6650.00  2.20
# 6020    5680.00  3.40
# 6021    5230.00  1.70
# 6022    5580.00  1.10
# 6023    5440.00  3.60
# 6026    6350.00  2.40
# 6063    1930.00 55.50
# 6066    1620.00 56.80
# 6069    1360.00 62.30
# 6074     940.00 68.30
# 6079     630.00 77.20
# 6130    3020.00 14.90
# 6188    2700.00 38.00
# 6194    2370.00 37.40
# 6198    1980.00 48.30
# 6205    1510.00 56.60
# 6208    1510.00 67.90
# 6246    2030.00 25.10
# 6254    1500.00 45.60
# 6308    1240.00 52.20
# 6316     860.00 60.60
# 6362    7530.00  1.90
# 6363    7290.00  2.20
# 6364    7110.00  1.90
# 6365    6900.00  3.00
# 6366    6700.00  3.20
# 6367    6500.00  4.10
# 6368    6290.00  4.50
# 6369    5970.00  5.50
# 6370    5770.00  6.40
# 6371    5930.00  6.70
# 6372    5690.00  4.50
# 6373    5460.00  6.90
# 6374    5070.00 10.40
# 6375    4810.00 10.90
# 6376    4670.00 14.80
# 6377    4570.00 14.00
# 6378    4470.00 13.50
# 6379    4370.00 12.20
# 6380    4240.00 16.30
# 6381    4170.00 20.00
# 6383    3910.00 14.10
# 6384    3860.00 12.50
# 6388    2950.00 20.70
# 6484   14230.00  5.50
# 6485   14100.00  5.70
# 6486   14060.00  6.70
# 6487   13480.00  5.50
# 6609    2510.00 32.30
# 6680    7250.00 23.40
# 6730    7580.00 42.00
# 6739    5000.00 48.40
# 6745    4010.00 81.70
# 6848    1800.00 38.40
# 6856     860.00 62.90
# 6904    1620.00 49.20
# 6908    1360.00 54.20
# 6913    1050.00 55.60
# 6960    6710.00  2.50
# 6961    6340.00  1.50
# 6963    7130.00  2.20
# 6965    6180.00  3.20
# 6967    5120.00  6.60
# 6969    4260.00  9.40
# 7002   17120.00  0.00
# 7003   16160.00  0.00
# 7004   15450.00  0.00
# 7005   14890.00  0.00
# 7006   14340.00  0.00
# 7007   14050.00  0.10
# 7008   13210.00  0.00
# 7009   12660.00  0.10
# 7010   11780.00  0.20
# 7011   11810.00  0.10
# 7012   11480.00  0.30
# 7013   10630.00  0.70
# 7015    9200.00  0.80
# 7017    7900.00  1.10
# 7019    7170.00  2.50
# 7024    3410.00  4.80
# 7030    1960.00  4.70
# 7032    1760.00 10.40
# 7035    1370.00 15.40
# 7036    1200.00 30.80
# 7040     840.00 54.40
# 7101    3450.00 51.40
# 7145    5650.00 30.70
# 7152    6010.00 47.00
# 7204    5910.00  1.00
# 7210    4810.00  1.10
# 7218    3840.00  2.80
# 7264   11240.00  0.30
# 7269    9750.00  2.00
# 7274    7440.00  3.30
# 7279    5760.00  5.90
# 7284    4270.00 11.70
# 7289    3520.00 10.60
# 7323   25870.00  0.20
# 7324   25340.00  0.30
# 7325   23760.00  0.30
# 7326   22070.00  0.30
# 7327   20460.00  0.30
# 7328   19480.00  0.30
# 7329   17280.00  0.80
# 7330   15310.00  0.90
# 7331   15890.00  0.60
# 7332   14710.00  1.40
# 7333   13470.00  1.90
# 7334   11760.00  2.60
# 7335   10710.00  2.20
# 7336    9430.00  4.20
# 7337    9150.00  2.50
# 7345    6780.00  3.20
# 7389    4680.00  3.30
# 7448    2290.00 49.10
# 7452    1910.00 59.90
# 7459    1230.00 86.00
# 7468     990.00 72.10
# 7503    1870.00 41.70
# 7507    1690.00 35.90
# 7510    1470.00 44.60
# 7514    1090.00 56.40
# 7517     930.00 65.10
# 7520     830.00 66.90
# 7523     720.00 62.60
# 7527     520.00 63.80
# 7563    8210.00  0.10
# 7564    7880.00  0.10
# 7565    8610.00  0.00
# 7566    8500.00  0.00
# 7567    8340.00  0.00
# 7568    8090.00  0.00
# 7569    7550.00  0.00
# 7570    7120.00  0.10
# 7571    8350.00  0.00
# 7572    7910.00  0.10
# 7573    7110.00  0.10
# 7574    6410.00  0.30
# 7575    5990.00  0.60
# 7576    5170.00  0.60
# 7577    4580.00  1.70
# 7583    3380.00  5.40
# 7584    3650.00  5.40
# 7586    5060.00  1.30
# 7587    5900.00  3.00
# 7636    2280.00 62.10
# 7637    2170.00 58.20
# 7639    1970.00 62.00
# 7641    1820.00 40.20
# 7753   14960.00 10.20
# 7754   13290.00 18.90
# 7755   11690.00 19.80
# 7756    9840.00 22.70
# 7757   10620.00 18.20
# 7758   11840.00 11.00
# 7760   10990.00 12.00
# 7761   11600.00 12.80
# 7764   11070.00 10.40
# 7767   10830.00  4.80
# 7803    6100.00  2.00
# 7805    5350.00  2.70
# 7807    4750.00  2.80
# 7809    4180.00  4.20
# 7811    3760.00 14.80
# 7813    3260.00 19.50
# 7815    2970.00 26.50
# 7817    2510.00 38.00
# 7821    1770.00 35.50
# 7827    1070.00 52.90
# 7869    2790.00 13.10
# 7926    5500.00  1.10
# 7931    5150.00  0.60
# 7937    3670.00  2.00
# 8002   11050.00  0.20
# 8003   10350.00  0.60
# 8004    9940.00  0.40
# 8005    9390.00  0.70
# 8006    9110.00  0.30
# 8007    8810.00  0.50
# 8008    8410.00  1.40
# 8009    7870.00  2.20
# 8010    7590.00  2.70
# 8013    6590.00  3.20
# 8045    3800.00 18.80
# 8054    3420.00  9.80
# 8061    2780.00  7.40
# 8105   12740.00 18.90
# 8109   11480.00 16.50
# 8111   11300.00 16.90
# 8114    9610.00 26.10
# 8119    7540.00 35.00
# 8123    6850.00 36.60
# 8126    6210.00 31.70
# 8164    3860.00 57.50
# 8169    3050.00 64.40
# 8173    2210.00 60.50
# 8175    1950.00 56.70
# 8177    1770.00 49.40
# 8181    1480.00 42.10
# 8183    1480.00 41.70
# 8186    1480.00 54.50
# 8188    1350.00 54.10
# 8228    1860.00 21.40
#
# [921 rows x 6 columns]

# %%
df.groupby('date').mean().corr()
# Out:
#                                                     GNIPC  \
# GNIPC                                                1.00
# Water productivity, total (constant 2010 US$ GD...   0.99
# GNI2=P()C                                            0.98
# POV                                                 -0.83
#
#                                                     Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)  \
# GNIPC                                                                                            0.99
# Water productivity, total (constant 2010 US$ GD...                                               1.00
# GNI2=P()C                                                                                        0.97
# POV                                                                                             -0.83
#
#                                                     GNI2=P()C   POV
# GNIPC                                                    0.98 -0.83
# Water productivity, total (constant 2010 US$ GD...       0.97 -0.83
# GNI2=P()C                                                1.00 -0.90
# POV                                                     -0.90  1.00

# %%
indicators = {#popular WB indicators
    'SP.POP.TOTL':'Population, total',
'SP.POP.GROW':'Population growth (annual %)',
'AG.SRF.TOTL.K2':'Surface area (sq. km)',
'SI.POV.NAHC':'Poverty headcount ratio at national poverty lines (% of population)',
'NY.GNP.ATLS.CD':'GNI, Atlas method (current US$)',
'NY.GNP.PCAP.CD':'GNI per capita, Atlas method (current US$)',
'NY.GNP.MKTP.PP.CD':'GNI, PPP (current international $)',
'NY.GNP.PCAP.PP.CD':'GNI per capita, PPP (current international $)',
'SI.DST.FRST.20':'Income share held by lowest 20%',
'SP.DYN.LE00.IN':'Life expectancy at birth, total (years)',
'SP.DYN.TFRT.IN':'Fertility rate, total (births per woman)',
'SP.ADO.TFRT':'Adolescent fertility rate (births per 1,000 women ages 15-19)',
'SP.DYN.CONU.ZS':'Contraceptive prevalence, any methods (% of women ages 15-49)',
'SH.STA.BRTC.ZS':'Births attended by skilled health staff (% of total)',
'SH.DYN.MORT':'Mortality rate, under-5 (per 1,000 live births)',
'SH.STA.MALN.ZS':'Prevalence of underweight, weight for age (% of children under 5)',
'SH.IMM.MEAS':'Immunization, measles (% of children ages 12-23 months)',
'SE.PRM.CMPT.ZS':'Primary completion rate, total (% of relevant age group)',
'SE.SEC.ENRR':'School enrollment, secondary (% gross)',
'SE.ENR.PRSC.FM.ZS':'School enrollment, primary and secondary (gross), gender parity index (GPI)',
'SH.DYN.AIDS.ZS':'Prevalence of HIV, total (% of population ages 15-49)',
'AG.LND.FRST.K2':'Forest area (sq. km)',
'ER.GDP.FWTL.M3.KD':'Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)',
'SH.H2O.SAFE.ZS':'Improved water source (% of population with access)',
'SH.STA.ACSN':'Improved sanitation facilities (% of population with access)',
'EG.USE.PCAP.KG.OE':'Energy use (kg of oil equivalent per capita)',
'EN.ATM.CO2E.PC':'CO2 emissions (metric tons per capita)',
'EG.USE.ELEC.KH.PC':'Electric power consumption (kWh per capita)',
'NY.GDP.MKTP.CD':'GDP (current US$)',
'NY.GDP.MKTP.KD.ZG':'GDP growth (annual %)',
'NY.GDP.DEFL.KD.ZG':'Inflation, GDP deflator (annual %)',
'NV.AGR.TOTL.ZS':'Agriculture, value added (% of GDP)',
'NV.IND.TOTL.ZS':'Industry, value added (% of GDP)',
'NV.SRV.TETC.ZS':'Services, etc., value added (% of GDP)',
'NE.EXP.GNFS.ZS':'Exports of goods and services (% of GDP)',
'NE.IMP.GNFS.ZS':'Imports of goods and services (% of GDP)',
'NE.GDI.TOTL.ZS':'Gross capital formation (% of GDP)',
'GC.REV.XGRT.GD.ZS':'Revenue, excluding grants (% of GDP)',
'GC.BAL.CASH.GD.ZS':'Cash surplus/deficit (% of GDP)',
'IC.REG.PROC':'Start-up procedures to register a business (number)',
'CM.MKT.LCAP.GD.ZS':'Market capitalization of listed domestic companies (% of GDP)',
'MS.MIL.XPND.GD.ZS':'Military expenditure (% of GDP)',
'IT.CEL.SETS.P2':'Mobile cellular subscriptions (per 100 people)',
'IT.NET.USER.P2':'Internet users (per 100 people)',
'IS.ROD.PAVE.ZS':'Roads, paved (% of total roads)',
'TX.VAL.TECH.MF.ZS':'High-technology exports (% of manufactured exports)',
'TG.VAL.TOTL.GD.ZS':'Merchandise trade (% of GDP)',
'TT.PRI.MRCH.XD.WD':'Net barter terms of trade index (2000 = 100)',
'DT.DOD.DECT.CD':'External debt stocks, total (DOD, current US$)',
'DT.TDS.DECT.GN.ZS':'Total debt service (% of GNI)',
'SM.POP.NETM':'Net migration',
'BM.TRF.PWKR.CD.DT':'Personal remittances, paid (current US$)',
'BX.KLT.DINV.CD.WD':'Foreign direct investment, net inflows (BoP, current US$)',
'DT.ODA.ODAT.PC.ZS':'Net ODA received per capita (current US$)',
'NY.GDP.PCAP.CD':'GDP per capita (current US$)',
'BN.KLT.DINV.CD':'Foreign direct investment, net (BoP, current US$)',
'FP.CPI.TOTL.ZG':'Inflation, consumer prices (annual %)',
'SI.POV.DDAY':'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
'SI.POV.LMIC':'Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)',
'SI.POV.UMIC':'Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)'   
}

# %% [raw]
# indicators_all = {#ALL Indicators
# 'SL.FAM.WORK.FE.ZS':'Contributing family workers, female (% of female employment) (modeled ILO estimate)',
# 'SL.FAM.WORK.MA.ZS':'Contributing family workers, male (% of male employment) (modeled ILO estimate)',
# 'SL.FAM.WORK.ZS':'Contributing family workers, total (% of total employment) (modeled ILO estimate)',
# 'SL.EMP.MPYR.FE.ZS':'Employers, female (% of female employment) (modeled ILO estimate)',
# 'SL.EMP.MPYR.MA.ZS':'Employers, male (% of male employment) (modeled ILO estimate)',
# 'SL.EMP.MPYR.ZS':'Employers, total (% of total employment) (modeled ILO estimate)',
# 'SL.AGR.EMPL.ZS':'Employment in agriculture (% of total employment) (modeled ILO estimate)',
# 'SL.AGR.EMPL.FE.ZS':'Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
# 'SL.AGR.EMPL.MA.ZS':'Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
# 'SL.IND.EMPL.ZS':'Employment in industry (% of total employment) (modeled ILO estimate)',
# 'SL.IND.EMPL.FE.ZS':'Employment in industry, female (% of female employment) (modeled ILO estimate)',
# 'SL.IND.EMPL.MA.ZS':'Employment in industry, male (% of male employment) (modeled ILO estimate)',
# 'SL.SRV.EMPL.ZS':'Employment in services (% of total employment) (modeled ILO estimate)',
# 'SL.SRV.EMPL.FE.ZS':'Employment in services, female (% of female employment) (modeled ILO estimate)',
# 'SL.SRV.EMPL.MA.ZS':'Employment in services, male (% of male employment) (modeled ILO estimate)',
# 'SL.EMP.TOTL.SP.FE.ZS':'Employment to population ratio, 15+, female (%) (modeled ILO estimate)',
# 'SL.EMP.TOTL.SP.MA.ZS':'Employment to population ratio, 15+, male (%) (modeled ILO estimate)',
# 'SL.EMP.TOTL.SP.ZS':'Employment to population ratio, 15+, total (%) (modeled ILO estimate)',
# 'SL.EMP.1524.SP.FE.ZS':'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
# 'SL.EMP.1524.SP.MA.ZS':'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
# 'SL.EMP.1524.SP.ZS':'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
# 'SL.GDP.PCAP.EM.KD':'GDP per person employed (constant 2011 PPP $)',
# 'SL.TLF.ACTI.1524.FE.ZS':'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
# 'SL.TLF.ACTI.1524.MA.ZS':'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
# 'SL.TLF.ACTI.1524.ZS':'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
# 'SL.TLF.CACT.FE.ZS':'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
# 'SL.TLF.ACTI.FE.ZS':'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
# 'SL.TLF.CACT.MA.ZS':'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
# 'SL.TLF.ACTI.MA.ZS':'Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
# 'SL.TLF.CACT.ZS':'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
# 'SL.TLF.ACTI.ZS':'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
# 'SL.TLF.TOTL.FE.ZS':'Labor force, female (% of total labor force)',
# 'SL.TLF.TOTL.IN':'Labor force, total',
# 'SE.SEC.AGES':'Lower secondary school starting age (years)',
# 'SE.PRM.DURS':'Primary education, duration (years)',
# 'SE.PRM.AGES':'Primary school starting age (years)',
# 'SL.TLF.CACT.FM.ZS':'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
# 'SE.SEC.DURS':'Secondary education, duration (years)',
# 'SL.EMP.SELF.FE.ZS':'Self-employed, female (% of female employment) (modeled ILO estimate)',
# 'SL.EMP.SELF.MA.ZS':'Self-employed, male (% of male employment) (modeled ILO estimate)',
# 'SL.EMP.SELF.ZS':'Self-employed, total (% of total employment) (modeled ILO estimate)',
# 'SL.UEM.TOTL.FE.ZS':'Unemployment, female (% of female labor force) (modeled ILO estimate)',
# 'SL.UEM.TOTL.MA.ZS':'Unemployment, male (% of male labor force) (modeled ILO estimate)',
# 'SL.UEM.TOTL.ZS':'Unemployment, total (% of total labor force) (modeled ILO estimate)',
# 'SL.UEM.1524.FE.ZS':'Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
# 'SL.UEM.1524.MA.ZS':'Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
# 'SL.UEM.1524.ZS':'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
# 'SL.EMP.VULN.FE.ZS':'Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
# 'SL.EMP.VULN.MA.ZS':'Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
# 'SL.EMP.VULN.ZS':'Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
# 'SL.EMP.WORK.FE.ZS':'Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
# 'SL.EMP.WORK.MA.ZS':'Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
# 'SL.EMP.WORK.ZS':'Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
# 'SP.POP.DPND':'Age dependency ratio (% of working-age population)',
# 'SP.POP.DPND.OL':'Age dependency ratio, old (% of working-age population)',
# 'SP.POP.DPND.YG':'Age dependency ratio, young (% of working-age population)',
# 'TX.VAL.AGRI.ZS.UN':'Agricultural raw materials exports (% of merchandise exports)',
# 'TM.VAL.AGRI.ZS.UN':'Agricultural raw materials imports (% of merchandise imports)',
# 'NV.AGR.TOTL.ZS':'Agriculture, forestry, and fishing, value added (% of GDP)',
# 'NV.AGR.TOTL.KD.ZG':'Agriculture, forestry, and fishing, value added (annual % growth)',
# 'NV.AGR.TOTL.KD':'Agriculture, forestry, and fishing, value added (constant 2010 US$)',
# 'NV.AGR.TOTL.KN':'Agriculture, forestry, and fishing, value added (constant LCU)',
# 'NV.AGR.TOTL.CN':'Agriculture, forestry, and fishing, value added (current LCU)',
# 'NV.AGR.TOTL.CD':'Agriculture, forestry, and fishing, value added (current US$)',
# 'NV.AGR.EMPL.KD':'Agriculture, forestry, and fishing, value added per worker (constant 2010 US$)',
# 'IS.AIR.GOOD.MT.K1':'Air transport, freight (million ton-km)',
# 'IS.AIR.PSGR':'Air transport, passengers carried',
# 'IS.AIR.DPRT':'Air transport, registered carrier departures worldwide',
# 'MS.MIL.MPRT.KD':'Arms imports (SIPRI trend indicator values)',
# 'VC.BTL.DETH':'Battle-related deaths (number of people)',
# 'FM.LBL.BMNY.GD.ZS':'Broad money (% of GDP)',
# 'FM.LBL.BMNY.CN':'Broad money (current LCU)',
# 'FM.LBL.BMNY.ZG':'Broad money growth (annual %)',
# 'FM.LBL.BMNY.IR.ZS':'Broad money to total reserves ratio',
# 'NE.GDI.STKB.KN':'Changes in inventories (constant LCU)',
# 'NE.GDI.STKB.CN':'Changes in inventories (current LCU)',
# 'NE.GDI.STKB.CD':'Changes in inventories (current US$)',
# 'BM.GSR.ROYL.CD':'Charges for the use of intellectual property, payments (BoP, current US$)',
# 'BX.GSR.ROYL.CD':'Charges for the use of intellectual property, receipts (BoP, current US$)',
# 'FM.AST.CGOV.ZG.M3':'Claims on central government (annual growth as % of broad money)',
# 'FS.AST.CGOV.GD.ZS':'Claims on central government, etc. (% GDP)',
# 'FM.AST.PRVT.ZG.M3':'Claims on private sector (annual growth as % of broad money)',
# 'DT.NFL.PCBO.CD':'Commercial banks and other lending (PPG + PNG) (NFL, current US$)',
# 'TX.VAL.SERV.CD.WT':'Commercial service exports (current US$)',
# 'TM.VAL.SERV.CD.WT':'Commercial service imports (current US$)',
# 'BX.GSR.CMCP.ZS':'Communications, computer, etc. (% of service exports, BoP)',
# 'BM.GSR.CMCP.ZS':'Communications, computer, etc. (% of service imports, BoP)',
# 'TX.VAL.OTHR.ZS.WT':'Computer, communications and other services (% of commercial service exports)',
# 'TM.VAL.OTHR.ZS.WT':'Computer, communications and other services (% of commercial service imports)',
# 'FP.CPI.TOTL':'Consumer price index (2010 = 100)',
# 'BN.CAB.XOKA.GD.ZS':'Current account balance (% of GDP)',
# 'BN.CAB.XOKA.CD':'Current account balance (BoP, current US$)',
# 'DT.TDS.DPPF.XP.ZS':'Debt service (PPG and IMF only, % of exports of goods, services and primary income)',
# 'DT.TDS.DPPG.CD':'Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)',
# 'DT.TDS.DECT.CD':'Debt service on external debt, total (TDS, current US$)',
# 'PA.NUS.ATLS':'DEC alternative conversion factor (LCU per US$)',
# 'NY.GDP.DISC.KN':'Discrepancy in expenditure estimate of GDP (constant LCU)',
# 'NY.GDP.DISC.CN':'Discrepancy in expenditure estimate of GDP (current LCU)',
# 'FS.AST.PRVT.GD.ZS':'Domestic credit to private sector (% of GDP)',
# 'FD.AST.PRVT.GD.ZS':'Domestic credit to private sector by banks (% of GDP)',
# 'TX.UVI.MRCH.XD.WD':'Export unit value index (2000 = 100)',
# 'TX.VAL.MRCH.XD.WD':'Export value index (2000 = 100)',
# 'TX.QTY.MRCH.XD.WD':'Export volume index (2000 = 100)',
# 'NY.EXP.CAPM.KN':'Exports as a capacity to import (constant LCU)',
# 'NE.EXP.GNFS.ZS':'Exports of goods and services (% of GDP)',
# 'NE.EXP.GNFS.KD.ZG':'Exports of goods and services (annual % growth)',
# 'BX.GSR.GNFS.CD':'Exports of goods and services (BoP, current US$)',
# 'NE.EXP.GNFS.KD':'Exports of goods and services (constant 2010 US$)',
# 'NE.EXP.GNFS.KN':'Exports of goods and services (constant LCU)',
# 'NE.EXP.GNFS.CN':'Exports of goods and services (current LCU)',
# 'NE.EXP.GNFS.CD':'Exports of goods and services (current US$)',
# 'BX.GSR.TOTL.CD':'Exports of goods, services and primary income (BoP, current US$)',
# 'NE.RSB.GNFS.ZS':'External balance on goods and services (% of GDP)',
# 'NE.RSB.GNFS.KN':'External balance on goods and services (constant LCU)',
# 'NE.RSB.GNFS.CN':'External balance on goods and services (current LCU)',
# 'NE.RSB.GNFS.CD':'External balance on goods and services (current US$)',
# 'DT.DOD.DECT.GN.ZS':'External debt stocks (% of GNI)',
# 'DT.DOD.DLXF.CD':'External debt stocks, long-term (DOD, current US$)',
# 'DT.DOD.DPNG.CD':'External debt stocks, private nonguaranteed (PNG) (DOD, current US$)',
# 'DT.DOD.DPPG.CD':'External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)',
# 'DT.DOD.DSTC.CD':'External debt stocks, short-term (DOD, current US$)',
# 'DT.DOD.DECT.CD':'External debt stocks, total (DOD, current US$)',
# 'NE.CON.TOTL.ZS':'Final consumption expenditure (% of GDP)',
# 'NE.CON.TOTL.KD.ZG':'Final consumption expenditure (annual % growth)',
# 'NE.CON.TOTL.KD':'Final consumption expenditure (constant 2010 US$)',
# 'NE.CON.TOTL.KN':'Final consumption expenditure (constant LCU)',
# 'NE.CON.TOTL.CN':'Final consumption expenditure (current LCU)',
# 'NE.CON.TOTL.CD':'Final consumption expenditure (current US$)',
# 'IT.MLT.MAIN':'Fixed telephone subscriptions',
# 'IT.MLT.MAIN.P2':'Fixed telephone subscriptions (per 100 people)',
# 'TX.VAL.FOOD.ZS.UN':'Food exports (% of merchandise exports)',
# 'TM.VAL.FOOD.ZS.UN':'Food imports (% of merchandise imports)',
# 'BN.KLT.DINV.CD':'Foreign direct investment, net (BoP, current US$)',
# 'BX.KLT.DINV.WD.GD.ZS':'Foreign direct investment, net inflows (% of GDP)',
# 'BX.KLT.DINV.CD.WD':'Foreign direct investment, net inflows (BoP, current US$)',
# 'BM.KLT.DINV.WD.GD.ZS':'Foreign direct investment, net outflows (% of GDP)',
# 'BM.KLT.DINV.CD.WD':'Foreign direct investment, net outflows (BoP, current US$)',
# 'TX.VAL.FUEL.ZS.UN':'Fuel exports (% of merchandise exports)',
# 'TM.VAL.FUEL.ZS.UN':'Fuel imports (% of merchandise imports)',
# 'NY.GDP.MKTP.KD':'GDP (constant 2010 US$)',
# 'NY.GDP.MKTP.KN':'GDP (constant LCU)',
# 'NY.GDP.MKTP.CN':'GDP (current LCU)',
# 'NY.GDP.MKTP.CD':'GDP (current US$)',
# 'NY.GDP.DEFL.ZS':'GDP deflator (base year varies by country)',
# 'NY.GDP.DEFL.ZS.AD':'GDP deflator: linked series (base year varies by country)',
# 'NY.GDP.MKTP.KD.ZG':'GDP growth (annual %)',
# 'NY.GDP.PCAP.KD':'GDP per capita (constant 2010 US$)',
# 'NY.GDP.PCAP.KN':'GDP per capita (constant LCU)',
# 'NY.GDP.PCAP.CN':'GDP per capita (current LCU)',
# 'NY.GDP.PCAP.CD':'GDP per capita (current US$)',
# 'NY.GDP.PCAP.KD.ZG':'GDP per capita growth (annual %)',
# 'NY.GDP.PCAP.PP.KD':'GDP per capita, PPP (constant 2011 international $)',
# 'NY.GDP.PCAP.PP.CD':'GDP per capita, PPP (current international $)',
# 'NY.GDP.MKTP.PP.KD':'GDP, PPP (constant 2011 international $)',
# 'NY.GDP.MKTP.PP.CD':'GDP, PPP (current international $)',
# 'NY.GDP.MKTP.CN.AD':'GDP: linked series (current LCU)',
# 'NE.CON.GOVT.ZS':'General government final consumption expenditure (% of GDP)',
# 'NE.CON.GOVT.KD.ZG':'General government final consumption expenditure (annual % growth)',
# 'NE.CON.GOVT.KD':'General government final consumption expenditure (constant 2010 US$)',
# 'NE.CON.GOVT.KN':'General government final consumption expenditure (constant LCU)',
# 'NE.CON.GOVT.CN':'General government final consumption expenditure (current LCU)',
# 'NE.CON.GOVT.CD':'General government final consumption expenditure (current US$)',
# 'NY.GNP.MKTP.KD':'GNI (constant 2010 US$)',
# 'NY.GNP.MKTP.KN':'GNI (constant LCU)',
# 'NY.GNP.MKTP.CN':'GNI (current LCU)',
# 'NY.GNP.MKTP.CD':'GNI (current US$)',
# 'NY.GNP.MKTP.KD.ZG':'GNI growth (annual %)',
# 'NY.GNP.PCAP.KD':'GNI per capita (constant 2010 US$)',
# 'NY.GNP.PCAP.KN':'GNI per capita (constant LCU)',
# 'NY.GNP.PCAP.CN':'GNI per capita (current LCU)',
# 'NY.GNP.PCAP.KD.ZG':'GNI per capita growth (annual %)',
# 'NY.GNP.PCAP.CD':'GNI per capita, Atlas method (current US$)',
# 'NY.GNP.PCAP.PP.KD':'GNI per capita, PPP (constant 2011 international $)',
# 'NY.GNP.PCAP.PP.CD':'GNI per capita, PPP (current international $)',
# 'NY.GNP.ATLS.CD':'GNI, Atlas method (current US$)',
# 'NY.GNP.MKTP.PP.KD':'GNI, PPP (constant 2011 international $)',
# 'NY.GNP.MKTP.PP.CD':'GNI, PPP (current international $)',
# 'BX.GSR.MRCH.CD':'Goods exports (BoP, current US$)',
# 'BM.GSR.MRCH.CD':'Goods imports (BoP, current US$)',
# 'NE.GDI.TOTL.ZS':'Gross capital formation (% of GDP)',
# 'NE.GDI.TOTL.KD.ZG':'Gross capital formation (annual % growth)',
# 'NE.GDI.TOTL.KD':'Gross capital formation (constant 2010 US$)',
# 'NE.GDI.TOTL.KN':'Gross capital formation (constant LCU)',
# 'NE.GDI.TOTL.CN':'Gross capital formation (current LCU)',
# 'NE.GDI.TOTL.CD':'Gross capital formation (current US$)',
# 'NY.GDY.TOTL.KN':'Gross domestic income (constant LCU)',
# 'NY.GDS.TOTL.ZS':'Gross domestic savings (% of GDP)',
# 'NY.GDS.TOTL.CN':'Gross domestic savings (current LCU)',
# 'NY.GDS.TOTL.CD':'Gross domestic savings (current US$)',
# 'NE.GDI.FTOT.ZS':'Gross fixed capital formation (% of GDP)',
# 'NE.GDI.FTOT.KD.ZG':'Gross fixed capital formation (annual % growth)',
# 'NE.GDI.FTOT.KD':'Gross fixed capital formation (constant 2010 US$)',
# 'NE.GDI.FTOT.KN':'Gross fixed capital formation (constant LCU)',
# 'NE.GDI.FTOT.CN':'Gross fixed capital formation (current LCU)',
# 'NE.GDI.FTOT.CD':'Gross fixed capital formation (current US$)',
# 'NE.DAB.TOTL.ZS':'Gross national expenditure (% of GDP)',
# 'NE.DAB.TOTL.KD':'Gross national expenditure (constant 2010 US$)',
# 'NE.DAB.TOTL.KN':'Gross national expenditure (constant LCU)',
# 'NE.DAB.TOTL.CN':'Gross national expenditure (current LCU)',
# 'NE.DAB.TOTL.CD':'Gross national expenditure (current US$)',
# 'NE.DAB.DEFL.ZS':'Gross national expenditure deflator (base year varies by country)',
# 'NY.GNS.ICTR.ZS':'Gross savings (% of GDP)',
# 'NY.GNS.ICTR.GN.ZS':'Gross savings (% of GNI)',
# 'NY.GNS.ICTR.CN':'Gross savings (current LCU)',
# 'NY.GNS.ICTR.CD':'Gross savings (current US$)',
# 'NY.GDP.FCST.KD':'Gross value added at basic prices (GVA) (constant 2010 US$)',
# 'NY.GDP.FCST.KN':'Gross value added at basic prices (GVA) (constant LCU)',
# 'NY.GDP.FCST.CN':'Gross value added at basic prices (GVA) (current LCU)',
# 'NY.GDP.FCST.CD':'Gross value added at basic prices (GVA) (current US$)',
# 'NE.CON.PRVT.ZS':'Households and NPISHs final consumption expenditure (% of GDP)',
# 'NE.CON.PRVT.KD.ZG':'Households and NPISHs Final consumption expenditure (annual % growth)',
# 'NE.CON.PRVT.KD':'Households and NPISHs Final consumption expenditure (constant 2010 US$)',
# 'NE.CON.PRVT.KN':'Households and NPISHs Final consumption expenditure (constant LCU)',
# 'NE.CON.PRVT.CN':'Households and NPISHs Final consumption expenditure (current LCU)',
# 'NE.CON.PRVT.CD':'Households and NPISHs Final consumption expenditure (current US$)',
# 'NE.CON.PRVT.PC.KD':'Households and NPISHs Final consumption expenditure per capita (constant 2010 US$)',
# 'NE.CON.PRVT.PC.KD.ZG':'Households and NPISHs Final consumption expenditure per capita growth (annual %)',
# 'NE.CON.PRVT.PP.KD':'Households and NPISHs Final consumption expenditure, PPP (constant 2011 international $)',
# 'NE.CON.PRVT.PP.CD':'Households and NPISHs Final consumption expenditure, PPP (current international $)',
# 'DT.DOD.MWBG.CD':'IBRD loans and IDA credits (DOD, current US$)',
# 'DT.NFL.NIFC.CD':'IFC, private nonguaranteed (NFL, current US$)',
# 'DT.TDS.DIMF.CD':'IMF repurchases and charges (TDS, current US$)',
# 'SH.IMM.IDPT':'Immunization, DPT (% of children ages 12-23 months)',
# 'SH.IMM.MEAS':'Immunization, measles (% of children ages 12-23 months)',
# 'TM.UVI.MRCH.XD.WD':'Import unit value index (2000 = 100)',
# 'TM.VAL.MRCH.XD.WD':'Import value index (2000 = 100)',
# 'TM.QTY.MRCH.XD.WD':'Import volume index (2000 = 100)',
# 'NE.IMP.GNFS.ZS':'Imports of goods and services (% of GDP)',
# 'NE.IMP.GNFS.KD.ZG':'Imports of goods and services (annual % growth)',
# 'BM.GSR.GNFS.CD':'Imports of goods and services (BoP, current US$)',
# 'NE.IMP.GNFS.KD':'Imports of goods and services (constant 2010 US$)',
# 'NE.IMP.GNFS.KN':'Imports of goods and services (constant LCU)',
# 'NE.IMP.GNFS.CN':'Imports of goods and services (current LCU)',
# 'NE.IMP.GNFS.CD':'Imports of goods and services (current US$)',
# 'BM.GSR.TOTL.CD':'Imports of goods, services and primary income (BoP, current US$)',
# 'NV.IND.TOTL.ZS':'Industry (including construction), value added (% of GDP)',
# 'NV.IND.TOTL.KD.ZG':'Industry (including construction), value added (annual % growth)',
# 'NV.IND.TOTL.KD':'Industry (including construction), value added (constant 2010 US$)',
# 'NV.IND.TOTL.KN':'Industry (including construction), value added (constant LCU)',
# 'NV.IND.TOTL.CN':'Industry (including construction), value added (current LCU)',
# 'NV.IND.TOTL.CD':'Industry (including construction), value added (current US$)',
# 'NV.IND.EMPL.KD':'Industry (including construction), value added per worker (constant 2010 US$)',
# 'FP.CPI.TOTL.ZG':'Inflation, consumer prices (annual %)',
# 'NY.GDP.DEFL.KD.ZG':'Inflation, GDP deflator (annual %)',
# 'NY.GDP.DEFL.KD.ZG.AD':'Inflation, GDP deflator: linked series (annual %)',
# 'TM.VAL.INSF.ZS.WT':'Insurance and financial services (% of commercial service imports)',
# 'BX.GSR.INSF.ZS':'Insurance and financial services (% of service exports, BoP)',
# 'BM.GSR.INSF.ZS':'Insurance and financial services (% of service imports, BoP)',
# 'IE.PPI.ENGY.CD':'Investment in energy with private participation (current US$)',
# 'IE.PPI.TRAN.CD':'Investment in transport with private participation (current US$)',
# 'AG.LND.TOTL.K2':'Land area (sq. km)',
# 'FR.INR.LEND':'Lending interest rate (%)',
# 'CM.MKT.LDOM.NO':'Listed domestic companies, total',
# 'TX.VAL.MANF.ZS.UN':'Manufactures exports (% of merchandise exports)',
# 'TM.VAL.MANF.ZS.UN':'Manufactures imports (% of merchandise imports)',
# 'NV.IND.MANF.ZS':'Manufacturing, value added (% of GDP)',
# 'NV.IND.MANF.KD.ZG':'Manufacturing, value added (annual % growth)',
# 'NV.IND.MANF.KD':'Manufacturing, value added (constant 2010 US$)',
# 'NV.IND.MANF.KN':'Manufacturing, value added (constant LCU)',
# 'NV.IND.MANF.CN':'Manufacturing, value added (current LCU)',
# 'NV.IND.MANF.CD':'Manufacturing, value added (current US$)',
# 'TX.VAL.MRCH.CD.WT':'Merchandise exports (current US$)',
# 'TM.VAL.MRCH.CD.WT':'Merchandise imports (current US$)',
# 'TG.VAL.TOTL.GD.ZS':'Merchandise trade (% of GDP)',
# 'MS.MIL.XPND.GD.ZS':'Military expenditure (% of GDP)',
# 'MS.MIL.XPND.ZS':'Military expenditure (% of general government expenditure)',
# 'MS.MIL.XPND.CN':'Military expenditure (current LCU)',
# 'MS.MIL.XPND.CD':'Military expenditure (current USD)',
# 'IT.CEL.SETS':'Mobile cellular subscriptions',
# 'IT.CEL.SETS.P2':'Mobile cellular subscriptions (per 100 people)',
# 'SP.DYN.IMRT.IN':'Mortality rate, infant (per 1,000 live births)',
# 'SH.DYN.NMRT':'Mortality rate, neonatal (per 1,000 live births)',
# 'SH.DYN.MORT':'Mortality rate, under-5 (per 1,000 live births)',
# 'DT.TDS.MLAT.PG.ZS':'Multilateral debt service (% of public and publicly guaranteed debt service)',
# 'DT.TDS.MLAT.CD':'Multilateral debt service (TDS, current US$)',
# 'TT.PRI.MRCH.XD.WD':'Net barter terms of trade index (2000 = 100)',
# 'BN.KAC.EOMS.CD':'Net errors and omissions (BoP, current US$)',
# 'BN.FIN.TOTL.CD':'Net financial account (BoP, current US$)',
# 'DT.NFL.BLAT.CD':'Net financial flows, bilateral (NFL, current US$)',
# 'DT.NFL.MIBR.CD':'Net financial flows, IBRD (NFL, current US$)',
# 'DT.NFL.MIDA.CD':'Net financial flows, IDA (NFL, current US$)',
# 'DT.NFL.IMFC.CD':'Net financial flows, IMF concessional (NFL, current US$)',
# 'DT.NFL.IMFN.CD':'Net financial flows, IMF nonconcessional (NFL, current US$)',
# 'DT.NFL.MLAT.CD':'Net financial flows, multilateral (NFL, current US$)',
# 'DT.NFL.MOTH.CD':'Net financial flows, others (NFL, current US$)',
# 'DT.NFL.RDBC.CD':'Net financial flows, RDB concessional (NFL, current US$)',
# 'DT.NFL.RDBN.CD':'Net financial flows, RDB nonconcessional (NFL, current US$)',
# 'DT.NFL.DPNG.CD':'Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
# 'BN.GSR.FCTY.CD':'Net primary income (BoP, current US$)',
# 'NY.GSR.NFCY.CN':'Net primary income (Net income from abroad) (current LCU)',
# 'NY.GSR.NFCY.CD':'Net primary income (Net income from abroad) (current US$)',
# 'BN.TRF.CURR.CD':'Net secondary income (BoP, current US$)',
# 'NY.TRF.NCTR.CN':'Net secondary income (Net current transfers from abroad) (current LCU)',
# 'NY.TRF.NCTR.CD':'Net secondary income (Net current transfers from abroad) (current US$)',
# 'BN.GSR.MRCH.CD':'Net trade in goods (BoP, current US$)',
# 'BN.GSR.GNFS.CD':'Net trade in goods and services (BoP, current US$)',
# 'SH.VAC.TTNS.ZS':'Newborns protected against tetanus (%)',
# 'SH.DTH.IMRT':'Number of infant deaths',
# 'SH.DTH.NMRT':'Number of neonatal deaths',
# 'SH.DTH.MORT':'Number of under-five deaths',
# 'PA.NUS.FCRF':'Official exchange rate (LCU per US$, period average)',
# 'TX.VAL.MMTL.ZS.UN':'Ores and metals exports (% of merchandise exports)',
# 'TM.VAL.MMTL.ZS.UN':'Ores and metals imports (% of merchandise imports)',
# 'BM.TRF.PWKR.CD.DT':'Personal remittances, paid (current US$)',
# 'BX.TRF.PWKR.DT.GD.ZS':'Personal remittances, received (% of GDP)',
# 'BX.TRF.PWKR.CD.DT':'Personal remittances, received (current US$)',
# 'BX.TRF.PWKR.CD':'Personal transfers, receipts (BoP, current US$)',
# 'DT.NFL.PNGB.CD':'PNG, bonds (NFL, current US$)',
# 'DT.NFL.PNGC.CD':'PNG, commercial banks and other creditors (NFL, current US$)',
# 'SP.POP.0004.FE.5Y':'Population ages 00-04, female (% of female population)',
# 'SP.POP.0004.MA.5Y':'Population ages 00-04, male (% of male population)',
# 'SP.POP.0014.TO.ZS':'Population ages 0-14 (% of total population)',
# 'SP.POP.0014.FE.IN':'Population ages 0-14, female',
# 'SP.POP.0014.FE.ZS':'Population ages 0-14, female (% of female population)',
# 'SP.POP.0014.MA.IN':'Population ages 0-14, male',
# 'SP.POP.0014.MA.ZS':'Population ages 0-14, male (% of male population)',
# 'SP.POP.0014.TO':'Population ages 0-14, total',
# 'SP.POP.0509.FE.5Y':'Population ages 05-09, female (% of female population)',
# 'SP.POP.0509.MA.5Y':'Population ages 05-09, male (% of male population)',
# 'SP.POP.1014.FE.5Y':'Population ages 10-14, female (% of female population)',
# 'SP.POP.1014.MA.5Y':'Population ages 10-14, male (% of male population)',
# 'SP.POP.1519.FE.5Y':'Population ages 15-19, female (% of female population)',
# 'SP.POP.1519.MA.5Y':'Population ages 15-19, male (% of male population)',
# 'SP.POP.1564.TO.ZS':'Population ages 15-64 (% of total population)',
# 'SP.POP.1564.FE.IN':'Population ages 15-64, female',
# 'SP.POP.1564.FE.ZS':'Population ages 15-64, female (% of female population)',
# 'SP.POP.1564.MA.IN':'Population ages 15-64, male',
# 'SP.POP.1564.MA.ZS':'Population ages 15-64, male (% of male population)',
# 'SP.POP.1564.TO':'Population ages 15-64, total',
# 'SP.POP.2024.FE.5Y':'Population ages 20-24, female (% of female population)',
# 'SP.POP.2024.MA.5Y':'Population ages 20-24, male (% of male population)',
# 'SP.POP.2529.FE.5Y':'Population ages 25-29, female (% of female population)',
# 'SP.POP.2529.MA.5Y':'Population ages 25-29, male (% of male population)',
# 'SP.POP.3034.FE.5Y':'Population ages 30-34, female (% of female population)',
# 'SP.POP.3034.MA.5Y':'Population ages 30-34, male (% of male population)',
# 'SP.POP.3539.FE.5Y':'Population ages 35-39, female (% of female population)',
# 'SP.POP.3539.MA.5Y':'Population ages 35-39, male (% of male population)',
# 'SP.POP.4044.FE.5Y':'Population ages 40-44, female (% of female population)',
# 'SP.POP.4044.MA.5Y':'Population ages 40-44, male (% of male population)',
# 'SP.POP.4549.FE.5Y':'Population ages 45-49, female (% of female population)',
# 'SP.POP.4549.MA.5Y':'Population ages 45-49, male (% of male population)',
# 'SP.POP.5054.FE.5Y':'Population ages 50-54, female (% of female population)',
# 'SP.POP.5054.MA.5Y':'Population ages 50-54, male (% of male population)',
# 'SP.POP.5559.FE.5Y':'Population ages 55-59, female (% of female population)',
# 'SP.POP.5559.MA.5Y':'Population ages 55-59, male (% of male population)',
# 'SP.POP.6064.FE.5Y':'Population ages 60-64, female (% of female population)',
# 'SP.POP.6064.MA.5Y':'Population ages 60-64, male (% of male population)',
# 'SP.POP.65UP.TO.ZS':'Population ages 65 and above (% of total population)',
# 'SP.POP.65UP.FE.IN':'Population ages 65 and above, female',
# 'SP.POP.65UP.FE.ZS':'Population ages 65 and above, female (% of female population)',
# 'SP.POP.65UP.MA.IN':'Population ages 65 and above, male',
# 'SP.POP.65UP.MA.ZS':'Population ages 65 and above, male (% of male population)',
# 'SP.POP.65UP.TO':'Population ages 65 and above, total',
# 'SP.POP.6569.FE.5Y':'Population ages 65-69, female (% of female population)',
# 'SP.POP.6569.MA.5Y':'Population ages 65-69, male (% of male population)',
# 'SP.POP.7074.FE.5Y':'Population ages 70-74, female (% of female population)',
# 'SP.POP.7074.MA.5Y':'Population ages 70-74, male (% of male population)',
# 'SP.POP.7579.FE.5Y':'Population ages 75-79, female (% of female population)',
# 'SP.POP.7579.MA.5Y':'Population ages 75-79, male (% of male population)',
# 'SP.POP.80UP.FE.5Y':'Population ages 80 and above, female (% of female population)',
# 'SP.POP.80UP.MA.5Y':'Population ages 80 and above, male (% of male population)',
# 'EN.POP.DNST':'Population density (people per sq. km of land area)',
# 'SP.POP.GROW':'Population growth (annual %)',
# 'EN.URB.LCTY':'Population in largest city',
# 'EN.URB.LCTY.UR.ZS':'Population in the largest city (% of urban population)',
# 'EN.URB.MCTY':'Population in urban agglomerations of more than 1 million',
# 'EN.URB.MCTY.TL.ZS':'Population in urban agglomerations of more than 1 million (% of total population)',
# 'SP.POP.TOTL.FE.IN':'Population, female',
# 'SP.POP.TOTL.FE.ZS':'Population, female (% of total population)',
# 'SP.POP.TOTL.MA.IN':'Population, male',
# 'SP.POP.TOTL.MA.ZS':'Population, male (% of total population)',
# 'SP.POP.TOTL':'Population, total',
# 'BX.PEF.TOTL.CD.WD':'Portfolio equity, net inflows (BoP, current US$)',
# 'DT.NFL.BOND.CD':'Portfolio investment, bonds (PPG + PNG) (NFL, current US$)',
# 'BN.KLT.PTXL.CD':'Portfolio investment, net (BoP, current US$)',
# 'DT.NFL.PBND.CD':'PPG, bonds (NFL, current US$)',
# 'DT.NFL.PCBK.CD':'PPG, commercial banks (NFL, current US$)',
# 'DT.DOD.MIBR.CD':'PPG, IBRD (DOD, current US$)',
# 'DT.DOD.MIDA.CD':'PPG, IDA (DOD, current US$)',
# 'DT.NFL.OFFT.CD':'PPG, official creditors (NFL, current US$)',
# 'DT.NFL.PROP.CD':'PPG, other private creditors (NFL, current US$)',
# 'DT.NFL.PRVT.CD':'PPG, private creditors (NFL, current US$)',
# 'PA.NUS.PPP':'PPP conversion factor, GDP (LCU per international $)',
# 'PA.NUS.PRVT.PP':'PPP conversion factor, private consumption (LCU per international $)',
# 'SE.PRE.DURS':'Preprimary education, duration (years)',
# 'PA.NUS.PPPC.RF':'Price level ratio of PPP conversion factor (GDP) to market exchange rate',
# 'BM.GSR.FCTY.CD':'Primary income payments (BoP, current US$)',
# 'BX.GSR.FCTY.CD':'Primary income receipts (BoP, current US$)',
# 'SG.GEN.PARL.ZS':'Proportion of seats held by women in national parliaments (%)',
# 'DT.TDS.DPPG.XP.ZS':'Public and publicly guaranteed debt service (% of exports of goods, services and primary income)',
# 'DT.TDS.DPPG.GN.ZS':'Public and publicly guaranteed debt service (% of GNI)',
# 'IE.PPN.ENGY.CD':'Public private partnerships investment in energy (current US$)',
# 'IE.PPN.TRAN.CD':'Public private partnerships investment in transport (current US$)',
# 'FR.INR.RINR':'Real interest rate (%)',
# 'SM.POP.REFG':'Refugee population by country or territory of asylum',
# 'SM.POP.REFG.OR':'Refugee population by country or territory of origin',
# 'BN.RES.INCL.CD':'Reserves and related items (BoP, current US$)',
# 'SP.RUR.TOTL':'Rural population',
# 'SP.RUR.TOTL.ZS':'Rural population (% of total population)',
# 'SP.RUR.TOTL.ZG':'Rural population growth (annual %)',
# 'CM.MKT.INDX.ZG':'S&P Global Equity Indices (annual % change)',
# 'SE.TER.ENRR':'School enrollment, tertiary (% gross)',
# 'BX.TRF.CURR.CD':'Secondary income receipts (BoP, current US$)',
# 'BM.TRF.PRVT.CD':'Secondary income, other sectors, payments (BoP, current US$)',
# 'BX.GSR.NFSV.CD':'Service exports (BoP, current US$)',
# 'BM.GSR.NFSV.CD':'Service imports (BoP, current US$)',
# 'NV.SRV.TOTL.ZS':'Services, value added (% of GDP)',
# 'NV.SRV.TOTL.KD.ZG':'Services, value added (annual % growth)',
# 'NV.SRV.TOTL.KD':'Services, value added (constant 2010 US$)',
# 'NV.SRV.TOTL.KN':'Services, value added (constant LCU)',
# 'NV.SRV.TOTL.CN':'Services, value added (current LCU)',
# 'NV.SRV.EMPL.KD':'Services, value added per worker (constant 2010 US$)',
# 'DT.DOD.DSTC.XP.ZS':'Short-term debt (% of exports of goods, services and primary income)',
# 'DT.DOD.DSTC.ZS':'Short-term debt (% of total external debt)',
# 'DT.DOD.DSTC.IR.ZS':'Short-term debt (% of total reserves)',
# 'AG.SRF.TOTL.K2':'Surface area (sq. km)',
# 'NY.TAX.NIND.KN':'Taxes less subsidies on products (constant LCU)',
# 'NY.TAX.NIND.CN':'Taxes less subsidies on products (current LCU)',
# 'NY.TAX.NIND.CD':'Taxes less subsidies on products (current US$)',
# 'NY.TTF.GNFS.KN':'Terms of trade adjustment (constant LCU)',
# 'DT.TDS.DECT.EX.ZS':'Total debt service (% of exports of goods, services and primary income)',
# 'DT.TDS.DECT.GN.ZS':'Total debt service (% of GNI)',
# 'FI.RES.TOTL.DT.ZS':'Total reserves (% of total external debt)',
# 'FI.RES.TOTL.CD':'Total reserves (includes gold, current US$)',
# 'FI.RES.TOTL.MO':'Total reserves in months of imports',
# 'FI.RES.XGLD.CD':'Total reserves minus gold (current US$)',
# 'NE.TRD.GNFS.ZS':'Trade (% of GDP)',
# 'BG.GSR.NFSV.GD.ZS':'Trade in services (% of GDP)',
# 'TX.VAL.TRAN.ZS.WT':'Transport services (% of commercial service exports)',
# 'TM.VAL.TRAN.ZS.WT':'Transport services (% of commercial service imports)',
# 'BX.GSR.TRAN.ZS':'Transport services (% of service exports, BoP)',
# 'BM.GSR.TRAN.ZS':'Transport services (% of service imports, BoP)',
# 'TX.VAL.TRVL.ZS.WT':'Travel services (% of commercial service exports)',
# 'TM.VAL.TRVL.ZS.WT':'Travel services (% of commercial service imports)',
# 'BX.GSR.TRVL.ZS':'Travel services (% of service exports, BoP)',
# 'BM.GSR.TRVL.ZS':'Travel services (% of service imports, BoP)',
# 'SP.URB.TOTL':'Urban population',
# 'SP.URB.TOTL.IN.ZS':'Urban population (% of total population)',
# 'SP.URB.GROW':'Urban population growth (annual %)',
# 'DT.DOD.DIMF.CD':'Use of IMF credit (DOD, current US$)',
# 'FP.WPI.TOTL':'Wholesale price index (2010 = 100)',
# 'EG.ELC.ACCS.ZS':'Access to electricity (% of population)',
# 'EG.ELC.ACCS.RU.ZS':'Access to electricity, rural (% of rural population)',
# 'EG.ELC.ACCS.UR.ZS':'Access to electricity, urban (% of urban population)',
# 'NY.ADJ.NNTY.KD.ZG':'Adjusted net national income (annual % growth)',
# 'NY.ADJ.NNTY.KD':'Adjusted net national income (constant 2010 US$)',
# 'NY.ADJ.NNTY.CD':'Adjusted net national income (current US$)',
# 'NY.ADJ.NNTY.PC.KD.ZG':'Adjusted net national income per capita (annual % growth)',
# 'NY.ADJ.NNTY.PC.KD':'Adjusted net national income per capita (constant 2010 US$)',
# 'NY.ADJ.NNTY.PC.CD':'Adjusted net national income per capita (current US$)',
# 'NY.ADJ.SVNX.GN.ZS':'Adjusted net savings, excluding particulate emission damage (% of GNI)',
# 'NY.ADJ.SVNX.CD':'Adjusted net savings, excluding particulate emission damage (current US$)',
# 'NY.ADJ.SVNG.GN.ZS':'Adjusted net savings, including particulate emission damage (% of GNI)',
# 'NY.ADJ.SVNG.CD':'Adjusted net savings, including particulate emission damage (current US$)',
# 'NY.ADJ.DCO2.GN.ZS':'Adjusted savings: carbon dioxide damage (% of GNI)',
# 'NY.ADJ.DCO2.CD':'Adjusted savings: carbon dioxide damage (current US$)',
# 'NY.ADJ.DKAP.GN.ZS':'Adjusted savings: consumption of fixed capital (% of GNI)',
# 'NY.ADJ.DKAP.CD':'Adjusted savings: consumption of fixed capital (current US$)',
# 'NY.ADJ.AEDU.GN.ZS':'Adjusted savings: education expenditure (% of GNI)',
# 'NY.ADJ.AEDU.CD':'Adjusted savings: education expenditure (current US$)',
# 'NY.ADJ.DNGY.GN.ZS':'Adjusted savings: energy depletion (% of GNI)',
# 'NY.ADJ.DNGY.CD':'Adjusted savings: energy depletion (current US$)',
# 'NY.ADJ.ICTR.GN.ZS':'Adjusted savings: gross savings (% of GNI)',
# 'NY.ADJ.DMIN.GN.ZS':'Adjusted savings: mineral depletion (% of GNI)',
# 'NY.ADJ.DMIN.CD':'Adjusted savings: mineral depletion (current US$)',
# 'NY.ADJ.DRES.GN.ZS':'Adjusted savings: natural resources depletion (% of GNI)',
# 'NY.ADJ.DFOR.GN.ZS':'Adjusted savings: net forest depletion (% of GNI)',
# 'NY.ADJ.DFOR.CD':'Adjusted savings: net forest depletion (current US$)',
# 'NY.ADJ.NNAT.GN.ZS':'Adjusted savings: net national savings (% of GNI)',
# 'NY.ADJ.NNAT.CD':'Adjusted savings: net national savings (current US$)',
# 'NY.ADJ.DPEM.GN.ZS':'Adjusted savings: particulate emission damage (% of GNI)',
# 'NY.ADJ.DPEM.CD':'Adjusted savings: particulate emission damage (current US$)',
# 'SP.ADO.TFRT':'Adolescent fertility rate (births per 1,000 women ages 15-19)',
# 'MS.MIL.TOTL.TF.ZS':'Armed forces personnel (% of total labor force)',
# 'MS.MIL.TOTL.P1':'Armed forces personnel, total',
# 'MS.MIL.XPRT.KD':'Arms exports (SIPRI trend indicator values)',
# 'SP.DYN.CBRT.IN':'Birth rate, crude (per 1,000 people)',
# 'AG.PRD.CREL.MT':'Cereal production (metric tons)',
# 'AG.YLD.CREL.KG':'Cereal yield (kg per hectare)',
# 'NY.GDP.COAL.RT.ZS':'Coal rents (% of GDP)',
# 'GC.XPN.COMP.ZS':'Compensation of employees (% of expense)',
# 'GC.XPN.COMP.CN':'Compensation of employees (current LCU)',
# 'IS.SHP.GOOD.TU':'Container port traffic (TEU: 20 foot equivalent units)',
# 'GC.TAX.IMPT.ZS':'Customs and other import duties (% of tax revenue)',
# 'GC.TAX.IMPT.CN':'Customs and other import duties (current LCU)',
# 'SP.DYN.CDRT.IN':'Death rate, crude (per 1,000 people)',
# 'FS.AST.DOMS.GD.ZS':'Domestic credit provided by financial sector (% of GDP)',
# 'GC.XPN.TOTL.GD.ZS':'Expense (% of GDP)',
# 'GC.XPN.TOTL.CN':'Expense (current LCU)',
# 'SP.DYN.TFRT.IN':'Fertility rate, total (births per woman)',
# 'IT.NET.BBND':'Fixed broadband subscriptions',
# 'IT.NET.BBND.P2':'Fixed broadband subscriptions (per 100 people)',
# 'NY.GDP.FRST.RT.ZS':'Forest rents (% of GDP)',
# 'GC.XPN.GSRV.ZS':'Goods and services expense (% of expense)',
# 'GC.XPN.GSRV.CN':'Goods and services expense (current LCU)',
# 'GC.REV.GOTR.ZS':'Grants and other revenue (% of revenue)',
# 'GC.REV.GOTR.CN':'Grants and other revenue (current LCU)',
# 'BX.GRT.EXTA.CD.WD':'Grants, excluding technical cooperation (BoP, current US$)',
# 'NE.GDI.FPRV.ZS':'Gross fixed capital formation, private sector (% of GDP)',
# 'NE.GDI.FPRV.CN':'Gross fixed capital formation, private sector (current LCU)',
# 'TX.VAL.ICTG.ZS.UN':'ICT goods exports (% of total goods exports)',
# 'TM.VAL.ICTG.ZS.UN':'ICT goods imports (% total goods imports)',
# 'BX.GSR.CCIS.ZS':'ICT service exports (% of service exports, BoP)',
# 'BX.GSR.CCIS.CD':'ICT service exports (BoP, current US$)',
# 'SH.TBS.INCD':'Incidence of tuberculosis (per 100,000 people)',
# 'IT.NET.USER.ZS':'Individuals using the Internet (% of population)',
# 'IP.IDS.NRCT':'Industrial design applications, nonresident, by count',
# 'IP.IDS.RSCT':'Industrial design applications, resident, by count',
# 'TX.VAL.INSF.ZS.WT':'Insurance and financial services (% of commercial service exports)',
# 'GC.XPN.INTP.ZS':'Interest payments (% of expense)',
# 'GC.XPN.INTP.RV.ZS':'Interest payments (% of revenue)',
# 'GC.XPN.INTP.CN':'Interest payments (current LCU)',
# 'ST.INT.XPND.MP.ZS':'International tourism, expenditures (% of total imports)',
# 'ST.INT.XPND.CD':'International tourism, expenditures (current US$)',
# 'ST.INT.TVLX.CD':'International tourism, expenditures for travel items (current US$)',
# 'ST.INT.ARVL':'International tourism, number of arrivals',
# 'ST.INT.DPRT':'International tourism, number of departures',
# 'ST.INT.RCPT.XP.ZS':'International tourism, receipts (% of total exports)',
# 'ST.INT.RCPT.CD':'International tourism, receipts (current US$)',
# 'ST.INT.TVLR.CD':'International tourism, receipts for travel items (current US$)',
# 'AG.LND.CREL.HA':'Land under cereal production (hectares)',
# 'SP.DYN.LE00.FE.IN':'Life expectancy at birth, female (years)',
# 'SP.DYN.LE00.MA.IN':'Life expectancy at birth, male (years)',
# 'SP.DYN.LE00.IN':'Life expectancy at birth, total (years)',
# 'SH.MMR.RISK.ZS':'Lifetime risk of maternal death (%)',
# 'SH.MMR.RISK':'Lifetime risk of maternal death (1 in: rate varies by country)',
# 'SH.STA.MMRT':'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
# 'TX.MNF.TECH.ZS.UN':'Medium and high-tech exports (% manufactured exports)',
# 'NV.MNF.TECH.ZS.UN':'Medium and high-tech Industry (including construction) (% manufacturing value added)',
# 'TX.VAL.MRCH.WL.CD':'Merchandise exports by the reporting economy (current US$)',
# 'TX.VAL.MRCH.RS.ZS':'Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
# 'TX.VAL.MRCH.AL.ZS':'Merchandise exports to economies in the Arab World (% of total merchandise exports)',
# 'TX.VAL.MRCH.HI.ZS':'Merchandise exports to high-income economies (% of total merchandise exports)',
# 'TX.VAL.MRCH.R1.ZS':'Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
# 'TX.VAL.MRCH.R2.ZS':'Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
# 'TX.VAL.MRCH.R3.ZS':'Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
# 'TX.VAL.MRCH.R4.ZS':'Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
# 'TX.VAL.MRCH.R5.ZS':'Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
# 'TX.VAL.MRCH.R6.ZS':'Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
# 'TX.VAL.MRCH.OR.ZS':'Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
# 'TX.VAL.MRCH.WR.ZS':'Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
# 'TM.VAL.MRCH.WL.CD':'Merchandise imports by the reporting economy (current US$)',
# 'TM.VAL.MRCH.RS.ZS':'Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
# 'TM.VAL.MRCH.AL.ZS':'Merchandise imports from economies in the Arab World (% of total merchandise imports)',
# 'TM.VAL.MRCH.HI.ZS':'Merchandise imports from high-income economies (% of total merchandise imports)',
# 'TM.VAL.MRCH.R1.ZS':'Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
# 'TM.VAL.MRCH.R2.ZS':'Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
# 'TM.VAL.MRCH.R3.ZS':'Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
# 'TM.VAL.MRCH.R4.ZS':'Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
# 'TM.VAL.MRCH.R5.ZS':'Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
# 'TM.VAL.MRCH.R6.ZS':'Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
# 'TM.VAL.MRCH.OR.ZS':'Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
# 'TM.VAL.MRCH.WR.ZS':'Merchandise imports from low- and middle-income economies within region (% of total merchandise imports)',
# 'NY.GDP.MINR.RT.ZS':'Mineral rents (% of GDP)',
# 'SP.DYN.AMRT.FE':'Mortality rate, adult, female (per 1,000 female adults)',
# 'SP.DYN.AMRT.MA':'Mortality rate, adult, male (per 1,000 male adults)',
# 'NY.GDP.NGAS.RT.ZS':'Natural gas rents (% of GDP)',
# 'GC.AST.TOTL.GD.ZS':'Net acquisition of financial assets (% of GDP)',
# 'GC.AST.TOTL.CN':'Net acquisition of financial assets (current LCU)',
# 'DC.DAC.AUSL.CD':'Net bilateral aid flows from DAC donors, Australia (current US$)',
# 'DC.DAC.AUTL.CD':'Net bilateral aid flows from DAC donors, Austria (current US$)',
# 'DC.DAC.BELL.CD':'Net bilateral aid flows from DAC donors, Belgium (current US$)',
# 'DC.DAC.CANL.CD':'Net bilateral aid flows from DAC donors, Canada (current US$)',
# 'DC.DAC.DNKL.CD':'Net bilateral aid flows from DAC donors, Denmark (current US$)',
# 'DC.DAC.CECL.CD':'Net bilateral aid flows from DAC donors, European Union institutions (current US$)',
# 'DC.DAC.FINL.CD':'Net bilateral aid flows from DAC donors, Finland (current US$)',
# 'DC.DAC.FRAL.CD':'Net bilateral aid flows from DAC donors, France (current US$)',
# 'DC.DAC.DEUL.CD':'Net bilateral aid flows from DAC donors, Germany (current US$)',
# 'DC.DAC.GRCL.CD':'Net bilateral aid flows from DAC donors, Greece (current US$)',
# 'DC.DAC.IRLL.CD':'Net bilateral aid flows from DAC donors, Ireland (current US$)',
# 'DC.DAC.ITAL.CD':'Net bilateral aid flows from DAC donors, Italy (current US$)',
# 'DC.DAC.JPNL.CD':'Net bilateral aid flows from DAC donors, Japan (current US$)',
# 'DC.DAC.KORL.CD':'Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)',
# 'DC.DAC.LUXL.CD':'Net bilateral aid flows from DAC donors, Luxembourg (current US$)',
# 'DC.DAC.NLDL.CD':'Net bilateral aid flows from DAC donors, Netherlands (current US$)',
# 'DC.DAC.NZLL.CD':'Net bilateral aid flows from DAC donors, New Zealand (current US$)',
# 'DC.DAC.NORL.CD':'Net bilateral aid flows from DAC donors, Norway (current US$)',
# 'DC.DAC.ESPL.CD':'Net bilateral aid flows from DAC donors, Spain (current US$)',
# 'DC.DAC.SWEL.CD':'Net bilateral aid flows from DAC donors, Sweden (current US$)',
# 'DC.DAC.CHEL.CD':'Net bilateral aid flows from DAC donors, Switzerland (current US$)',
# 'DC.DAC.TOTL.CD':'Net bilateral aid flows from DAC donors, Total (current US$)',
# 'DC.DAC.GBRL.CD':'Net bilateral aid flows from DAC donors, United Kingdom (current US$)',
# 'DC.DAC.USAL.CD':'Net bilateral aid flows from DAC donors, United States (current US$)',
# 'FM.AST.DOMS.CN':'Net domestic credit (current LCU)',
# 'GC.LBL.TOTL.GD.ZS':'Net incurrence of liabilities, total (% of GDP)',
# 'GC.LBL.TOTL.CN':'Net incurrence of liabilities, total (current LCU)',
# 'GC.NLD.TOTL.GD.ZS':'Net lending (+) / net borrowing (-) (% of GDP)',
# 'GC.NLD.TOTL.CN':'Net lending (+) / net borrowing (-) (current LCU)',
# 'DT.ODA.ODAT.XP.ZS':'Net ODA received (% of central government expense)',
# 'DT.ODA.ODAT.GN.ZS':'Net ODA received (% of GNI)',
# 'DT.ODA.ODAT.GI.ZS':'Net ODA received (% of gross capital formation)',
# 'DT.ODA.ODAT.MP.ZS':'Net ODA received (% of imports of goods, services and primary income)',
# 'DT.ODA.ODAT.PC.ZS':'Net ODA received per capita (current US$)',
# 'DT.ODA.ALLD.KD':'Net official development assistance and official aid received (constant 2015 US$)',
# 'DT.ODA.ALLD.CD':'Net official development assistance and official aid received (current US$)',
# 'DT.ODA.ODAT.KD':'Net official development assistance received (constant 2015 US$)',
# 'DT.ODA.ODAT.CD':'Net official development assistance received (current US$)',
# 'DT.NFL.IFAD.CD':'Net official flows from UN agencies, IFAD (current US$)',
# 'DT.NFL.UNDP.CD':'Net official flows from UN agencies, UNDP (current US$)',
# 'DT.NFL.UNFP.CD':'Net official flows from UN agencies, UNFPA (current US$)',
# 'DT.NFL.UNCF.CD':'Net official flows from UN agencies, UNICEF (current US$)',
# 'SH.MMR.DTHS':'Number of maternal deaths',
# 'NY.GDP.PETR.RT.ZS':'Oil rents (% of GDP)',
# 'GC.TAX.OTHR.RV.ZS':'Other taxes (% of revenue)',
# 'GC.TAX.OTHR.CN':'Other taxes (current LCU)',
# 'IP.PAT.NRES':'Patent applications, nonresidents',
# 'IP.PAT.RESD':'Patent applications, residents',
# 'SH.STA.ODFC.ZS':'People practicing open defecation (% of population)',
# 'SH.STA.ODFC.RU.ZS':'People practicing open defecation, rural (% of rural population)',
# 'SH.STA.ODFC.UR.ZS':'People practicing open defecation, urban (% of urban population)',
# 'SH.H2O.BASW.ZS':'People using at least basic drinking water services (% of population)',
# 'SH.H2O.BASW.RU.ZS':'People using at least basic drinking water services, rural (% of rural population)',
# 'SH.H2O.BASW.UR.ZS':'People using at least basic drinking water services, urban (% of urban population)',
# 'SH.STA.BASS.ZS':'People using at least basic sanitation services (% of population)',
# 'SH.STA.BASS.RU.ZS':'People using at least basic sanitation services, rural (% of rural population)',
# 'SH.STA.BASS.UR.ZS':'People using at least basic sanitation services, urban (% of urban population)',
# 'SH.H2O.SMDW.RU.ZS':'People using safely managed drinking water services, rural (% of rural population)',
# 'SH.STA.SMSS.RU.ZS':'People using safely managed sanitation services, rural (% of rural population)',
# 'SN.ITK.DEFC.ZS':'Prevalence of undernourishment (% of population)',
# 'IS.RRS.TOTL.KM':'Rail lines (total route-km)',
# 'IS.RRS.GOOD.MT.K6':'Railways, goods transported (million ton-km)',
# 'IS.RRS.PASG.KM':'Railways, passengers carried (million passenger-km)',
# 'GC.REV.XGRT.GD.ZS':'Revenue, excluding grants (% of GDP)',
# 'GC.REV.XGRT.CN':'Revenue, excluding grants (current LCU)',
# 'SE.SEC.ENRR':'School enrollment, secondary (% gross)',
# 'SE.ENR.SECO.FM.ZS':'School enrollment, secondary (gross), gender parity index (GPI)',
# 'SE.SEC.ENRR.FE':'School enrollment, secondary, female (% gross)',
# 'SE.SEC.ENRR.MA':'School enrollment, secondary, male (% gross)',
# 'SE.SEC.ENRL':'Secondary education, pupils',
# 'SE.SEC.ENRL.FE.ZS':'Secondary education, pupils (% female)',
# 'NV.SRV.TOTL.CD':'Services, value added (current US$)',
# 'GC.REV.SOCL.ZS':'Social contributions (% of revenue)',
# 'GC.REV.SOCL.CN':'Social contributions (current LCU)',
# 'SP.DYN.TO65.FE.ZS':'Survival to age 65, female (% of cohort)',
# 'SP.DYN.TO65.MA.ZS':'Survival to age 65, male (% of cohort)',
# 'GC.TAX.TOTL.GD.ZS':'Tax revenue (% of GDP)',
# 'GC.TAX.TOTL.CN':'Tax revenue (current LCU)',
# 'GC.TAX.GSRV.RV.ZS':'Taxes on goods and services (% of revenue)',
# 'GC.TAX.GSRV.VA.ZS':'Taxes on goods and services (% value added of industry and services)',
# 'GC.TAX.GSRV.CN':'Taxes on goods and services (current LCU)',
# 'GC.TAX.YPKG.RV.ZS':'Taxes on income, profits and capital gains (% of revenue)',
# 'GC.TAX.YPKG.ZS':'Taxes on income, profits and capital gains (% of total taxes)',
# 'GC.TAX.YPKG.CN':'Taxes on income, profits and capital gains (current LCU)',
# 'GC.TAX.INTT.RV.ZS':'Taxes on international trade (% of revenue)',
# 'GC.TAX.INTT.CN':'Taxes on international trade (current LCU)',
# 'BX.GRT.TECH.CD.WD':'Technical cooperation grants (BoP, current US$)',
# 'NY.GDP.TOTL.RT.ZS':'Total natural resources rents (% of GDP)',
# 'IP.TMK.NRES':'Trademark applications, direct nonresident',
# 'IP.TMK.RESD':'Trademark applications, direct resident',
# 'IP.TMK.TOTL':'Trademark applications, total',
# 'SH.TBS.DTEC.ZS':'Tuberculosis case detection rate (%, all forms)',
# 'EG.CFT.ACCS.ZS':'Access to clean fuels and technologies for cooking (% of population)',
# 'AG.LND.AGRI.ZS':'Agricultural land (% of land area)',
# 'AG.LND.AGRI.K2':'Agricultural land (sq. km)',
# 'ER.FSH.AQUA.MT':'Aquaculture production (metric tons)',
# 'AG.LND.ARBL.ZS':'Arable land (% of land area)',
# 'AG.LND.ARBL.HA.PC':'Arable land (hectares per person)',
# 'AG.LND.ARBL.HA':'Arable land (hectares)',
# 'TM.TAX.MRCH.BC.ZS':'Binding coverage, all products (%)',
# 'ER.FSH.CAPT.MT':'Capture fisheries production (metric tons)',
# 'NV.MNF.CHEM.ZS.UN':'Chemicals (% of value added in manufacturing)',
# 'IC.REG.COST.PC.ZS':'Cost of business start-up procedures (% of GNI per capita)',
# 'AG.PRD.CROP.XD':'Crop production index (2004-2006 = 100)',
# 'SH.XPD.CHEX.GD.ZS':'Current health expenditure (% of GDP)',
# 'SH.XPD.CHEX.PC.CD':'Current health expenditure per capita (current US$)',
# 'SH.XPD.CHEX.PP.CD':'Current health expenditure per capita, PPP (current international $)',
# 'SH.XPD.GHED.CH.ZS':'Domestic general government health expenditure (% of current health expenditure)',
# 'SH.XPD.GHED.GD.ZS':'Domestic general government health expenditure (% of GDP)',
# 'SH.XPD.GHED.GE.ZS':'Domestic general government health expenditure (% of general government expenditure)',
# 'SH.XPD.GHED.PC.CD':'Domestic general government health expenditure per capita (current US$)',
# 'SH.XPD.GHED.PP.CD':'Domestic general government health expenditure per capita, PPP (current international $)',
# 'SH.XPD.PVTD.CH.ZS':'Domestic private health expenditure (% of current health expenditure)',
# 'SH.XPD.PVTD.PC.CD':'Domestic private health expenditure per capita (current US$)',
# 'SH.XPD.PVTD.PP.CD':'Domestic private health expenditure per capita, PPP (current international $)',
# 'SH.XPD.EHEX.CH.ZS':'External health expenditure (% of current health expenditure)',
# 'SH.XPD.EHEX.PC.CD':'External health expenditure per capita (current US$)',
# 'SH.XPD.EHEX.PP.CD':'External health expenditure per capita, PPP (current international $)',
# 'AG.PRD.FOOD.XD':'Food production index (2004-2006 = 100)',
# 'NV.MNF.FBTO.ZS.UN':'Food, beverages and tobacco (% of value added in manufacturing)',
# 'AG.LND.FRST.ZS':'Forest area (% of land area)',
# 'AG.LND.FRST.K2':'Forest area (sq. km)',
# 'SE.PRM.GINT.FE.ZS':'Gross intake ratio in first grade of primary education, female (% of relevant age group)',
# 'SE.PRM.GINT.MA.ZS':'Gross intake ratio in first grade of primary education, male (% of relevant age group)',
# 'SE.PRM.GINT.ZS':'Gross intake ratio in first grade of primary education, total (% of relevant age group)',
# 'VC.IHR.PSRC.P5':'Intentional homicides (per 100,000 people)',
# 'VC.IHR.PSRC.FE.P5':'Intentional homicides, female (per 100,000 female)',
# 'VC.IHR.PSRC.MA.P5':'Intentional homicides, male (per 100,000 male)',
# 'AG.PRD.LVSK.XD':'Livestock production index (2004-2006 = 100)',
# 'NV.MNF.MTRN.ZS.UN':'Machinery and transport equipment (% of value added in manufacturing)',
# 'DC.DAC.PRTL.CD':'Net bilateral aid flows from DAC donors, Portugal (current US$)',
# 'NV.MNF.OTHR.ZS.UN':'Other manufacturing (% of value added in manufacturing)',
# 'SH.XPD.OOPC.CH.ZS':'Out-of-pocket expenditure (% of current health expenditure)',
# 'SH.XPD.OOPC.PC.CD':'Out-of-pocket expenditure per capita (current US$)',
# 'SH.XPD.OOPC.PP.CD':'Out-of-pocket expenditure per capita, PPP (current international $)',
# 'AG.LND.CROP.ZS':'Permanent cropland (% of land area)',
# 'SH.MED.PHYS.ZS':'Physicians (per 1,000 people)',
# 'SH.ANM.CHLD.ZS':'Prevalence of anemia among children (% of children under 5)',
# 'SH.ANM.NPRG.ZS':'Prevalence of anemia among non-pregnant women (% of women ages 15-49)',
# 'SH.PRG.ANEM':'Prevalence of anemia among pregnant women (%)',
# 'SH.ANM.ALLW.ZS':'Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
# 'SE.PRE.ENRR':'School enrollment, preprimary (% gross)',
# 'SE.PRE.ENRR.FE':'School enrollment, preprimary, female (% gross)',
# 'SE.PRE.ENRR.MA':'School enrollment, preprimary, male (% gross)',
# 'SE.ENR.TERT.FM.ZS':'School enrollment, tertiary (gross), gender parity index (GPI)',
# 'SE.TER.ENRR.FE':'School enrollment, tertiary, female (% gross)',
# 'SE.TER.ENRR.MA':'School enrollment, tertiary, male (% gross)',
# 'TM.TAX.MRCH.IP.ZS':'Share of tariff lines with international peaks, all products (%)',
# 'TM.TAX.MRCH.SR.ZS':'Share of tariff lines with specific rates, all products (%)',
# 'TM.TAX.MRCH.SM.AR.ZS':'Tariff rate, applied, simple mean, all products (%)',
# 'TM.TAX.MRCH.WM.AR.ZS':'Tariff rate, applied, weighted mean, all products (%)',
# 'TM.TAX.MRCH.SM.FN.ZS':'Tariff rate, most favored nation, simple mean, all products (%)',
# 'TM.TAX.MRCH.WM.FN.ZS':'Tariff rate, most favored nation, weighted mean, all products (%)',
# 'NV.MNF.TXTL.ZS.UN':'Textiles and clothing (% of value added in manufacturing)',
# 'ER.FSH.PROD.MT':'Total fisheries production (metric tons)',
# 'SH.TBS.CURE.ZS':'Tuberculosis treatment success rate (% of new cases)',
# 'SN.ITK.VITA.ZS':'Vitamin A supplementation coverage rate (% of children ages 6-59 months)',
# 'TM.TAX.MANF.BC.ZS':'Binding coverage, manufactured products (%)',
# 'TM.TAX.TCOM.BC.ZS':'Binding coverage, primary products (%)',
# 'TM.TAX.MRCH.BR.ZS':'Bound rate, simple mean, all products (%)',
# 'TM.TAX.MANF.BR.ZS':'Bound rate, simple mean, manufactured products (%)',
# 'TM.TAX.TCOM.BR.ZS':'Bound rate, simple mean, primary products (%)',
# 'EG.ELC.COAL.ZS':'Electricity production from coal sources (% of total)',
# 'EG.ELC.HYRO.ZS':'Electricity production from hydroelectric sources (% of total)',
# 'EG.ELC.NGAS.ZS':'Electricity production from natural gas sources (% of total)',
# 'EG.ELC.PETR.ZS':'Electricity production from oil sources (% of total)',
# 'EG.ELC.FOSL.ZS':'Electricity production from oil, gas and coal sources (% of total)',
# 'EG.ELC.RNWX.ZS':'Electricity production from renewable sources, excluding hydroelectric (% of total)',
# 'EG.ELC.RNWX.KH':'Electricity production from renewable sources, excluding hydroelectric (kWh)',
# 'EG.EGY.PRIM.PP.KD':'Energy intensity level of primary energy (MJ/$2011 PPP GDP)',
# 'CM.MKT.LCAP.GD.ZS':'Market capitalization of listed domestic companies (% of GDP)',
# 'CM.MKT.LCAP.CD':'Market capitalization of listed domestic companies (current US$)',
# 'FM.AST.NFRG.CN':'Net foreign assets (current LCU)',
# 'DT.NFL.WFPG.CD':'Net official flows from UN agencies, WFP (current US$)',
# 'GC.XPN.OTHR.ZS':'Other expense (% of expense)',
# 'GC.XPN.OTHR.CN':'Other expense (current LCU)',
# 'EG.ELC.RNEW.ZS':'Renewable electricity output (% of total electricity output)',
# 'EG.FEC.RNEW.ZS':'Renewable energy consumption (% of total final energy consumption)',
# 'TM.TAX.MANF.IP.ZS':'Share of tariff lines with international peaks, manufactured products (%)',
# 'TM.TAX.TCOM.IP.ZS':'Share of tariff lines with international peaks, primary products (%)',
# 'TM.TAX.MANF.SR.ZS':'Share of tariff lines with specific rates, manufactured products (%)',
# 'TM.TAX.TCOM.SR.ZS':'Share of tariff lines with specific rates, primary products (%)',
# 'CM.MKT.TRAD.GD.ZS':'Stocks traded, total value (% of GDP)',
# 'CM.MKT.TRAD.CD':'Stocks traded, total value (current US$)',
# 'CM.MKT.TRNR':'Stocks traded, turnover ratio of domestic shares (%)',
# 'GC.XPN.TRFT.ZS':'Subsidies and other transfers (% of expense)',
# 'GC.XPN.TRFT.CN':'Subsidies and other transfers (current LCU)',
# 'TM.TAX.MANF.SM.AR.ZS':'Tariff rate, applied, simple mean, manufactured products (%)',
# 'TM.TAX.TCOM.SM.AR.ZS':'Tariff rate, applied, simple mean, primary products (%)',
# 'TM.TAX.MANF.WM.AR.ZS':'Tariff rate, applied, weighted mean, manufactured products (%)',
# 'TM.TAX.TCOM.WM.AR.ZS':'Tariff rate, applied, weighted mean, primary products (%)',
# 'TM.TAX.MANF.SM.FN.ZS':'Tariff rate, most favored nation, simple mean, manufactured products (%)',
# 'TM.TAX.TCOM.SM.FN.ZS':'Tariff rate, most favored nation, simple mean, primary products (%)',
# 'TM.TAX.MANF.WM.FN.ZS':'Tariff rate, most favored nation, weighted mean, manufactured products (%)',
# 'TM.TAX.TCOM.WM.FN.ZS':'Tariff rate, most favored nation, weighted mean, primary products (%)',
# 'GC.TAX.EXPT.ZS':'Taxes on exports (% of tax revenue)',
# 'GC.TAX.EXPT.CN':'Taxes on exports (current LCU)',
# 'EG.USE.COMM.CL.ZS':'Alternative and nuclear energy (% of total energy use)',
# 'IC.BUS.DISC.XQ':'Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
# 'EN.ATM.CO2E.KD.GD':'CO2 emissions (kg per 2010 US$ of GDP)',
# 'EN.ATM.CO2E.PP.GD.KD':'CO2 emissions (kg per 2011 PPP $ of GDP)',
# 'EN.ATM.CO2E.PP.GD':'CO2 emissions (kg per PPP $ of GDP)',
# 'EN.ATM.CO2E.KT':'CO2 emissions (kt)',
# 'EN.ATM.CO2E.PC':'CO2 emissions (metric tons per capita)',
# 'EN.CO2.ETOT.ZS':'CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
# 'EN.ATM.CO2E.GF.ZS':'CO2 emissions from gaseous fuel consumption (% of total)',
# 'EN.ATM.CO2E.GF.KT':'CO2 emissions from gaseous fuel consumption (kt)',
# 'EN.ATM.CO2E.LF.ZS':'CO2 emissions from liquid fuel consumption (% of total)',
# 'EN.ATM.CO2E.LF.KT':'CO2 emissions from liquid fuel consumption (kt)',
# 'EN.CO2.MANF.ZS':'CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
# 'EN.CO2.OTHX.ZS':'CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
# 'EN.CO2.BLDG.ZS':'CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)',
# 'EN.ATM.CO2E.SF.ZS':'CO2 emissions from solid fuel consumption (% of total)',
# 'EN.ATM.CO2E.SF.KT':'CO2 emissions from solid fuel consumption (kt)',
# 'EN.CO2.TRAN.ZS':'CO2 emissions from transport (% of total fuel combustion)',
# 'EN.ATM.CO2E.EG.ZS':'CO2 intensity (kg per kg of oil equivalent energy use)',
# 'EG.USE.CRNW.ZS':'Combustible renewables and waste (% of total energy)',
# 'FB.CBK.BRCH.P5':'Commercial bank branches (per 100,000 adults)',
# 'EG.USE.ELEC.KH.PC':'Electric power consumption (kWh per capita)',
# 'EG.ELC.LOSS.ZS':'Electric power transmission and distribution losses (% of output)',
# 'EG.ELC.NUCL.ZS':'Electricity production from nuclear sources (% of total)',
# 'EG.IMP.CONS.ZS':'Energy imports, net (% of energy use)',
# 'EG.USE.PCAP.KG.OE':'Energy use (kg of oil equivalent per capita)',
# 'EG.USE.COMM.GD.PP.KD':'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP)',
# 'AG.CON.FERT.PT.ZS':'Fertilizer consumption (% of fertilizer production)',
# 'AG.CON.FERT.ZS':'Fertilizer consumption (kilograms per hectare of arable land)',
# 'EG.USE.COMM.FO.ZS':'Fossil fuel energy consumption (% of total)',
# 'EG.GDP.PUSE.KO.PP.KD':'GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent)',
# 'EG.GDP.PUSE.KO.PP':'GDP per unit of energy use (PPP $ per kg of oil equivalent)',
# 'SH.IMM.HEPB':'Immunization, HepB3 (% of one-year-old children)',
# 'ST.INT.TRNX.CD':'International tourism, expenditures for passenger transport items (current US$)',
# 'ST.INT.TRNR.CD':'International tourism, receipts for passenger transport items (current US$)',
# 'IS.SHP.GCNW.XQ':'Liner shipping connectivity index (maximum value in 2004 = 100)',
# 'IQ.SCI.MTHD':'Methodology assessment of statistical capacity (scale 0 - 100)',
# 'SH.MED.NUMW.P3':'Nurses and midwives (per 1,000 people)',
# 'IQ.SCI.PRDC':'Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
# 'SE.PRM.ENRL':'Primary education, pupils',
# 'SE.PRM.ENRL.FE.ZS':'Primary education, pupils (% female)',
# 'SE.PRM.ENRR':'School enrollment, primary (% gross)',
# 'SE.ENR.PRIM.FM.ZS':'School enrollment, primary (gross), gender parity index (GPI)',
# 'SE.ENR.PRSC.FM.ZS':'School enrollment, primary and secondary (gross), gender parity index (GPI)',
# 'SE.PRM.ENRR.FE':'School enrollment, primary, female (% gross)',
# 'SE.PRM.ENRR.MA':'School enrollment, primary, male (% gross)',
# 'IQ.SCI.SRCE':'Source data assessment of statistical capacity (scale 0 - 100)',
# 'IQ.SCI.OVRL':'Statistical Capacity score (Overall average)',
# 'FB.ATM.TOTL.P5':'Automated teller machines (ATMs) (per 100,000 adults)',
# 'GC.DOD.TOTL.GD.ZS':'Central government debt, total (% of GDP)',
# 'GC.DOD.TOTL.CN':'Central government debt, total (current LCU)',
# 'GC.NFN.TOTL.GD.ZS':'Net investment in nonfinancial assets (% of GDP)',
# 'GC.NFN.TOTL.CN':'Net investment in nonfinancial assets (current LCU)',
# 'DT.NFL.UNCR.CD':'Net official flows from UN agencies, UNHCR (current US$)',
# 'IP.JRN.ARTC.SC':'Scientific and technical journal articles',
# 'SE.SEC.ENRL.GC':'Secondary education, general pupils',
# 'SE.SEC.ENRL.GC.FE.ZS':'Secondary education, general pupils (% female)',
# 'SE.SEC.ENRL.VO':'Secondary education, vocational pupils',
# 'SE.SEC.ENRL.VO.FE.ZS':'Secondary education, vocational pupils (% female)',
# 'IP.TMK.NRCT':'Trademark applications, nonresident, by count',
# 'IP.TMK.RSCT':'Trademark applications, resident, by count',
# 'AG.LND.IRIG.AG.ZS':'Agricultural irrigated land (% of total agricultural land)',
# 'EN.ATM.METH.ZG':'Methane emissions (% change from 1990)',
# 'EN.ATM.METH.KT.CE':'Methane emissions (kt of CO2 equivalent)',
# 'DC.DAC.CZEL.CD':'Net bilateral aid flows from DAC donors, Czech Republic (current US$)',
# 'DC.DAC.POLL.CD':'Net bilateral aid flows from DAC donors, Poland (current US$)',
# 'DT.NFL.UNAI.CD':'Net official flows from UN agencies, UNAIDS (current US$)',
# 'EN.ATM.NOXE.ZG':'Nitrous oxide emissions (% change from 1990)',
# 'EN.ATM.NOXE.KT.CE':'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
# 'EN.ATM.GHGO.ZG':'Other greenhouse gas emissions (% change from 1990)',
# 'EN.ATM.GHGO.KT.CE':'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
# 'SE.SEC.ENRL.TC.ZS':'Pupil-teacher ratio, secondary',
# 'SE.PRM.REPT.FE.ZS':'Repeaters, primary, female (% of female enrollment)',
# 'SE.PRM.REPT.MA.ZS':'Repeaters, primary, male (% of male enrollment)',
# 'SE.PRM.REPT.ZS':'Repeaters, primary, total (% of total enrollment)',
# 'GB.XPD.RSDV.GD.ZS':'Research and development expenditure (% of GDP)',
# 'SE.SEC.TCHR':'Secondary education, teachers',
# 'SE.SEC.TCHR.FE.ZS':'Secondary education, teachers (% female)',
# 'SE.SEC.TCHR.FE':'Secondary education, teachers, female',
# 'EN.ATM.GHGT.ZG':'Total greenhouse gas emissions (% change from 1990)',
# 'EN.ATM.GHGT.KT.CE':'Total greenhouse gas emissions (kt of CO2 equivalent)',
# 'SE.PRM.CMPT.FE.ZS':'Primary completion rate, female (% of relevant age group)',
# 'SE.PRM.CMPT.MA.ZS':'Primary completion rate, male (% of relevant age group)',
# 'SE.PRM.CMPT.ZS':'Primary completion rate, total (% of relevant age group)',
# 'SE.SEC.ENRL.LO.TC.ZS':'Pupil-teacher ratio, lower secondary',
# 'SE.SEC.ENRL.UP.TC.ZS':'Pupil-teacher ratio, upper secondary',
# 'SP.POP.BRTH.MF':'Sex ratio at birth (male births per female births)',
# 'SE.PRM.TENR':'Adjusted net enrollment rate, primary (% of primary school age children)',
# 'SE.PRM.TENR.FE':'Adjusted net enrollment rate, primary, female (% of primary school age children)',
# 'SE.PRM.TENR.MA':'Adjusted net enrollment rate, primary, male (% of primary school age children)',
# 'IQ.WEF.CUST.XQ':'Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient)',
# 'SE.PRM.UNER.ZS':'Children out of school (% of primary school age)',
# 'SE.PRM.UNER.FE.ZS':'Children out of school, female (% of female primary school age)',
# 'SE.PRM.UNER.MA.ZS':'Children out of school, male (% of male primary school age)',
# 'SE.PRM.UNER':'Children out of school, primary',
# 'SE.PRM.UNER.FE':'Children out of school, primary, female',
# 'SE.PRM.UNER.MA':'Children out of school, primary, male',
# 'SE.XPD.SECO.PC.ZS':'Government expenditure per student, secondary (% of GDP per capita)',
# 'VC.IDP.NWDS':'Internally displaced persons, new displacement associated with disasters (number of cases)',
# 'IC.BUS.NDNS.ZS':'New business density (new registrations per 1,000 people ages 15-64)',
# 'IC.BUS.NREG':'New businesses registered (number)',
# 'SE.PRM.OENR.ZS':'Over-age students, primary (% of enrollment)',
# 'SE.PRM.OENR.FE.ZS':'Over-age students, primary, female (% of female enrollment)',
# 'SE.PRM.OENR.MA.ZS':'Over-age students, primary, male (% of male enrollment)',
# 'SE.TER.ENRL.TC.ZS':'Pupil-teacher ratio, tertiary',
# 'IQ.WEF.PORT.XQ':'Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficient by international standards)',
# 'SE.PRM.NENR':'School enrollment, primary (% net)',
# 'SE.PRM.NENR.FE':'School enrollment, primary, female (% net)',
# 'SE.PRM.NENR.MA':'School enrollment, primary, male (% net)',
# 'SE.TER.TCHR.FE.ZS':'Tertiary education, academic staff (% female)',
# 'SH.MED.CMHW.P3':'Community health workers (per 1,000 people)',
# 'SE.COM.DURS':'Compulsory education, duration (years)',
# 'SE.XPD.PRIM.ZS':'Expenditure on primary education (% of government expenditure on education)',
# 'SE.XPD.SECO.ZS':'Expenditure on secondary education (% of government expenditure on education)',
# 'SE.XPD.TERT.ZS':'Expenditure on tertiary education (% of government expenditure on education)',
# 'SE.XPD.TOTL.GD.ZS':'Government expenditure on education, total (% of GDP)',
# 'SE.XPD.TOTL.GB.ZS':'Government expenditure on education, total (% of government expenditure)',
# 'SE.XPD.TERT.PC.ZS':'Government expenditure per student, tertiary (% of GDP per capita)',
# 'TX.VAL.TECH.MF.ZS':'High-technology exports (% of manufactured exports)',
# 'TX.VAL.TECH.CD':'High-technology exports (current US$)',
# 'VC.IDP.NWCV':'Internally displaced persons, new displacement associated with conflict and violence (number of cases)',
# 'VC.IDP.TOCV':'Internally displaced persons, total displaced by conflict and violence (number of people)',
# 'IE.PPI.WATR.CD':'Investment in water and sanitation with private participation (current US$)',
# 'SG.LAW.EQRM.WK':'Law mandates equal remuneration for females and males for work of equal value (1=yes; 0=no)',
# 'SG.LEG.DVAW':'Legislation exists on domestic violence (1=yes; 0=no)',
# 'SE.SEC.CMPT.LO.FE.ZS':'Lower secondary completion rate, female (% of relevant age group)',
# 'SE.SEC.CMPT.LO.MA.ZS':'Lower secondary completion rate, male (% of relevant age group)',
# 'SE.SEC.CMPT.LO.ZS':'Lower secondary completion rate, total (% of relevant age group)',
# 'BN.TRF.KOGT.CD':'Net capital account (BoP, current US$)',
# 'EN.ATM.PM25.MC.M3':'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
# 'EN.ATM.PM25.MC.ZS':'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
# 'EN.ATM.PM25.MC.T1.ZS':'PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)',
# 'EN.ATM.PM25.MC.T2.ZS':'PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)',
# 'EN.ATM.PM25.MC.T3.ZS':'PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
# 'SE.PRM.TCHR':'Primary education, teachers',
# 'GF.XPD.BUDG.ZS':'Primary government expenditures as a proportion of original approved budget (%)',
# 'IE.PPN.WATR.CD':'Public private partnerships investment in water and sanitation (current US$)',
# 'SE.PRM.ENRL.TC.ZS':'Pupil-teacher ratio, primary',
# 'EN.ATM.METH.AG.ZS':'Agricultural methane emissions (% of total)',
# 'EN.ATM.METH.AG.KT.CE':'Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
# 'EN.ATM.NOXE.AG.ZS':'Agricultural nitrous oxide emissions (% of total)',
# 'EN.ATM.NOXE.AG.KT.CE':'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
# 'IQ.CPA.HRES.XQ':'CPIA building human resources rating (1=low to 6=high)',
# 'IQ.CPA.BREG.XQ':'CPIA business regulatory environment rating (1=low to 6=high)',
# 'IQ.CPA.DEBT.XQ':'CPIA debt policy rating (1=low to 6=high)',
# 'IQ.CPA.ECON.XQ':'CPIA economic management cluster average (1=low to 6=high)',
# 'IQ.CPA.REVN.XQ':'CPIA efficiency of revenue mobilization rating (1=low to 6=high)',
# 'IQ.CPA.PRES.XQ':'CPIA equity of public resource use rating (1=low to 6=high)',
# 'IQ.CPA.FINS.XQ':'CPIA financial sector rating (1=low to 6=high)',
# 'IQ.CPA.FISP.XQ':'CPIA fiscal policy rating (1=low to 6=high)',
# 'IQ.CPA.GNDR.XQ':'CPIA gender equality rating (1=low to 6=high)',
# 'IQ.CPA.MACR.XQ':'CPIA macroeconomic management rating (1=low to 6=high)',
# 'IQ.CPA.SOCI.XQ':'CPIA policies for social inclusion/equity cluster average (1=low to 6=high)',
# 'IQ.CPA.ENVR.XQ':'CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)',
# 'IQ.CPA.PROP.XQ':'CPIA property rights and rule-based governance rating (1=low to 6=high)',
# 'IQ.CPA.PUBS.XQ':'CPIA public sector management and institutions cluster average (1=low to 6=high)',
# 'IQ.CPA.FINQ.XQ':'CPIA quality of budgetary and financial management rating (1=low to 6=high)',
# 'IQ.CPA.PADM.XQ':'CPIA quality of public administration rating (1=low to 6=high)',
# 'IQ.CPA.PROT.XQ':'CPIA social protection rating (1=low to 6=high)',
# 'IQ.CPA.STRC.XQ':'CPIA structural policies cluster average (1=low to 6=high)',
# 'IQ.CPA.TRAD.XQ':'CPIA trade rating (1=low to 6=high)',
# 'IQ.CPA.TRAN.XQ':'CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)',
# 'EN.ATM.METH.EG.ZS':'Energy related methane emissions (% of total)',
# 'IQ.CPA.IRAI.XQ':'IDA resource allocation index (1=low to 6=high)',
# 'SH.MLR.INCD.P3':'Incidence of malaria (per 1,000 population at risk)',
# 'EN.ATM.METH.EG.KT.CE':'Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
# 'DT.NFL.UNTA.CD':'Net official flows from UN agencies, UNTA (current US$)',
# 'EN.ATM.NOXE.EG.ZS':'Nitrous oxide emissions in energy sector (% of total)',
# 'EN.ATM.NOXE.EG.KT.CE':'Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
# 'SE.PRM.TCHR.FE.ZS':'Primary education, teachers (% female)',
# 'EP.PMP.DESL.CD':'Pump price for diesel fuel (US$ per liter)',
# 'EP.PMP.SGAS.CD':'Pump price for gasoline (US$ per liter)',
# 'IT.NET.SECR':'Secure Internet servers',
# 'IT.NET.SECR.P6':'Secure Internet servers (per 1 million people)',
# 'SH.PRV.SMOK.FE':'Smoking prevalence, females (% of adults)',
# 'SH.PRV.SMOK.MA':'Smoking prevalence, males (% of adults)',
# 'SH.PRV.SMOK':'Smoking prevalence, total (ages 15+)',
# 'FB.AST.NPER.ZS':'Bank nonperforming loans to total gross loans (%)',
# 'SE.XPD.PRIM.PC.ZS':'Government expenditure per student, primary (% of GDP per capita)',
# 'SE.SEC.PROG.ZS':'Progression to secondary school (%)',
# 'SE.SEC.PROG.FE.ZS':'Progression to secondary school, female (%)',
# 'SE.SEC.PROG.MA.ZS':'Progression to secondary school, male (%)',
# 'SE.PRM.PRIV.ZS':'School enrollment, primary, private (% of total primary)',
# 'SE.SEC.PRIV.ZS':'School enrollment, secondary, private (% of total secondary)',
# 'SI.RMT.COST.IB.ZS':'Average transaction cost of sending remittances to a specific country (%)',
# 'FB.BNK.CAPA.ZS':'Bank capital to assets ratio (%)',
# 'SP.DYN.CONU.ZS':'Contraceptive prevalence, any methods (% of women ages 15-49)',
# 'IC.REG.COST.PC.FE.ZS':'Cost of business start-up procedures, female (% of GNI per capita)',
# 'IC.REG.COST.PC.MA.ZS':'Cost of business start-up procedures, male (% of GNI per capita)',
# 'IC.CRD.INFO.XQ':'Depth of credit information index (0=low to 8=high)',
# 'IC.TAX.LABR.CP.ZS':'Labor tax and contributions (% of commercial profits)',
# 'DT.NFL.WHOL.CD':'Net official flows from UN agencies, WHO (current US$)',
# 'IC.TAX.OTHR.CP.ZS':'Other taxes payable by businesses (% of commercial profits)',
# 'IC.CRD.PRVT.ZS':'Private credit bureau coverage (% of adults)',
# 'IC.WRH.PROC':'Procedures to build a warehouse (number)',
# 'IC.PRP.PROC':'Procedures to register property (number)',
# 'IC.TAX.PRFT.CP.ZS':'Profit tax (% of commercial profits)',
# 'IC.CRD.PUBL.ZS':'Public credit registry coverage (% of adults)',
# 'SH.SGR.CRSK.ZS':'Risk of catastrophic expenditure for surgical care (% of people at risk)',
# 'SH.SGR.IRSK.ZS':'Risk of impoverishing expenditure for surgical care (% of people at risk)',
# 'IC.REG.PROC':'Start-up procedures to register a business (number)',
# 'IC.REG.PROC.FE':'Start-up procedures to register a business, female (number)',
# 'IC.REG.PROC.MA':'Start-up procedures to register a business, male (number)',
# 'IC.LGL.CRED.XQ':'Strength of legal rights index (0=weak to 12=strong)',
# 'IC.TAX.PAYM':'Tax payments (number)',
# 'IC.WRH.DURS':'Time required to build a warehouse (days)',
# 'IC.LGL.DURS':'Time required to enforce a contract (days)',
# 'IC.ELC.TIME':'Time required to get electricity (days)',
# 'IC.PRP.DURS':'Time required to register property (days)',
# 'IC.REG.DURS':'Time required to start a business (days)',
# 'IC.REG.DURS.FE':'Time required to start a business, female (days)',
# 'IC.REG.DURS.MA':'Time required to start a business, male (days)',
# 'IC.TAX.DURS':'Time to prepare and pay taxes (hours)',
# 'IC.ISV.DURS':'Time to resolve insolvency (years)',
# 'IC.TAX.TOTL.CP.ZS':'Total tax and contribution rate (% of profit)',
# 'SP.DYN.CONM.ZS':'Contraceptive prevalence, modern methods (% of women ages 15-49)',
# 'IC.EXP.CSBC.CD':'Cost to export, border compliance (US$)',
# 'IC.EXP.CSDC.CD':'Cost to export, documentary compliance (US$)',
# 'IC.IMP.CSBC.CD':'Cost to import, border compliance (US$)',
# 'IC.IMP.CSDC.CD':'Cost to import, documentary compliance (US$)',
# 'SL.TLF.ACTI.1524.FE.NE.ZS':'Labor force participation rate for ages 15-24, female (%) (national estimate)',
# 'SL.TLF.ACTI.1524.MA.NE.ZS':'Labor force participation rate for ages 15-24, male (%) (national estimate)',
# 'SL.TLF.ACTI.1524.NE.ZS':'Labor force participation rate for ages 15-24, total (%) (national estimate)',
# 'SL.TLF.CACT.FE.NE.ZS':'Labor force participation rate, female (% of female population ages 15+) (national estimate)',
# 'SL.TLF.CACT.MA.NE.ZS':'Labor force participation rate, male (% of male population ages 15+) (national estimate)',
# 'SL.TLF.CACT.NE.ZS':'Labor force participation rate, total (% of total population ages 15+) (national estimate)',
# 'DC.DAC.SVKL.CD':'Net bilateral aid flows from DAC donors, Slovak Republic (current US$)',
# 'DC.DAC.SVNL.CD':'Net bilateral aid flows from DAC donors, Slovenia (current US$)',
# 'DT.NFL.ILOG.CD':'Net official flows from UN agencies, ILO (current US$)',
# 'SE.PRM.PRS5.ZS':'Persistence to grade 5, total (% of cohort)',
# 'SE.PRM.PRSL.ZS':'Persistence to last grade of primary, total (% of cohort)',
# 'SE.PRE.ENRL.TC.ZS':'Pupil-teacher ratio, preprimary',
# 'SL.TLF.CACT.FM.NE.ZS':'Ratio of female to male labor force participation rate (%) (national estimate)',
# 'SL.UEM.NEET.FE.ZS':'Share of youth not in education, employment or training, female (% of female youth population)',
# 'SL.UEM.NEET.MA.ZS':'Share of youth not in education, employment or training, male (% of male youth population)',
# 'SL.UEM.NEET.ZS':'Share of youth not in education, employment or training, total (% of youth population)',
# 'IC.EXP.TMBC':'Time to export, border compliance (hours)',
# 'IC.EXP.TMDC':'Time to export, documentary compliance (hours)',
# 'IC.IMP.TMBC':'Time to import, border compliance (hours)',
# 'IC.IMP.TMDC':'Time to import, documentary compliance (hours)',
# 'SH.STA.BRTC.ZS':'Births attended by skilled health staff (% of total)',
# 'SL.TLF.0714.FE.ZS':'Children in employment, female (% of female children ages 7-14)',
# 'SL.TLF.0714.MA.ZS':'Children in employment, male (% of male children ages 7-14)',
# 'SL.TLF.0714.SW.ZS':'Children in employment, study and work (% of children in employment, ages 7-14)',
# 'SL.TLF.0714.ZS':'Children in employment, total (% of children ages 7-14)',
# 'SL.TLF.0714.WK.ZS':'Children in employment, work only (% of children in employment, ages 7-14)',
# 'SH.FPL.SATM.ZS':'Demand for family planning satisfied by modern methods (% of married women with demand for family planning)',
# 'IC.BUS.DFRN.XQ':'Ease of doing business score (0 = lowest performance to 100 = best performance)',
# 'SL.EMP.TOTL.SP.FE.NE.ZS':'Employment to population ratio, 15+, female (%) (national estimate)',
# 'SL.EMP.TOTL.SP.MA.NE.ZS':'Employment to population ratio, 15+, male (%) (national estimate)',
# 'SL.EMP.TOTL.SP.NE.ZS':'Employment to population ratio, 15+, total (%) (national estimate)',
# 'SL.EMP.1524.SP.FE.NE.ZS':'Employment to population ratio, ages 15-24, female (%) (national estimate)',
# 'SL.EMP.1524.SP.MA.NE.ZS':'Employment to population ratio, ages 15-24, male (%) (national estimate)',
# 'SL.EMP.1524.SP.NE.ZS':'Employment to population ratio, ages 15-24, total (%) (national estimate)',
# 'SL.TLF.ADVN.ZS':'Labor force with advanced education (% of total working-age population with advanced education)',
# 'SL.TLF.ADVN.FE.ZS':'Labor force with advanced education, female (% of female working-age population with advanced education)',
# 'SL.TLF.ADVN.MA.ZS':'Labor force with advanced education, male (% of male working-age population with advanced education)',
# 'SL.TLF.BASC.ZS':'Labor force with basic education (% of total working-age population with basic education)',
# 'SL.TLF.BASC.FE.ZS':'Labor force with basic education, female (% of female working-age population with basic education)',
# 'SL.TLF.BASC.MA.ZS':'Labor force with basic education, male (% of male working-age population with basic education)',
# 'SL.TLF.INTM.ZS':'Labor force with intermediate education (% of total working-age population with intermediate education)',
# 'SL.TLF.INTM.FE.ZS':'Labor force with intermediate education, female (% of female working-age population with intermediate education)',
# 'SL.TLF.INTM.MA.ZS':'Labor force with intermediate education, male (% of male working-age population with intermediate education)',
# 'SG.LAW.NODC.HR':'Law mandates nondiscrimination based on gender in hiring (1=yes; 0=no)',
# 'SG.LAW.LEVE.PU':'Law mandates paid or unpaid maternity leave (1=yes; 0=no)',
# 'LP.EXP.DURS.MD':'Lead time to export, median case (days)',
# 'LP.IMP.DURS.MD':'Lead time to import, median case (days)',
# 'LP.LPI.TRAC.XQ':'Logistics performance index: Ability to track and trace consignments (1=low to 5=high)',
# 'LP.LPI.LOGS.XQ':'Logistics performance index: Competence and quality of logistics services (1=low to 5=high)',
# 'LP.LPI.ITRN.XQ':'Logistics performance index: Ease of arranging competitively priced shipments (1=low to 5=high)',
# 'LP.LPI.CUST.XQ':'Logistics performance index: Efficiency of customs clearance process (1=low to 5=high)',
# 'LP.LPI.TIME.XQ':'Logistics performance index: Frequency with which shipments reach consignee within scheduled or expected time (1=low to 5=high)',
# 'LP.LPI.OVRL.XQ':'Logistics performance index: Overall (1=low to 5=high)',
# 'LP.LPI.INFR.XQ':'Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)',
# 'SH.STA.MMRT.NE':'Maternal mortality ratio (national estimate, per 100,000 live births)',
# 'SH.DYN.NCOM.ZS':'Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
# 'SH.DYN.NCOM.FE.ZS':'Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)',
# 'SH.DYN.NCOM.MA.ZS':'Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)',
# 'SH.STA.POIS.P5':'Mortality rate attributed to unintentional poisoning (per 100,000 population)',
# 'SH.STA.POIS.P5.FE':'Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)',
# 'SH.STA.POIS.P5.MA':'Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)',
# 'SG.MMR.LEVE.EP':'Mothers are guaranteed an equivalent position after maternity leave (1=yes; 0=no)',
# 'SG.NOD.CONS':'Nondiscrimination clause mentions gender in the constitution (1=yes; 0=no)',
# 'SG.JOB.NOPN.EQ':'Nonpregnant and nonnursing women can do the same jobs as men (1=yes; 0=no)',
# 'SE.PRM.PRS5.FE.ZS':'Persistence to grade 5, female (% of cohort)',
# 'SE.PRM.PRS5.MA.ZS':'Persistence to grade 5, male (% of cohort)',
# 'SE.PRM.PRSL.FE.ZS':'Persistence to last grade of primary, female (% of cohort)',
# 'SE.PRM.PRSL.MA.ZS':'Persistence to last grade of primary, male (% of cohort)',
# 'EN.POP.SLUM.UR.ZS':'Population living in slums (% of urban population)',
# 'SH.STA.SUIC.P5':'Suicide mortality rate (per 100,000 population)',
# 'SH.STA.SUIC.FE.P5':'Suicide mortality rate, female (per 100,000 female population)',
# 'SH.STA.SUIC.MA.P5':'Suicide mortality rate, male (per 100,000 male population)',
# 'SL.UEM.ADVN.ZS':'Unemployment with advanced education (% of total labor force with advanced education)',
# 'SL.UEM.ADVN.FE.ZS':'Unemployment with advanced education, female (% of female labor force with advanced education)',
# 'SL.UEM.ADVN.MA.ZS':'Unemployment with advanced education, male (% of male labor force with advanced education)',
# 'SL.UEM.BASC.ZS':'Unemployment with basic education (% of total labor force with basic education)',
# 'SL.UEM.BASC.FE.ZS':'Unemployment with basic education, female (% of female labor force with basic education)',
# 'SL.UEM.BASC.MA.ZS':'Unemployment with basic education, male (% of male labor force with basic education)',
# 'SL.UEM.INTM.ZS':'Unemployment with intermediate education (% of total labor force with intermediate education)',
# 'SL.UEM.INTM.FE.ZS':'Unemployment with intermediate education, female (% of female labor force with intermediate education)',
# 'SL.UEM.INTM.MA.ZS':'Unemployment with intermediate education, male (% of male labor force with intermediate education)',
# 'SL.UEM.TOTL.FE.NE.ZS':'Unemployment, female (% of female labor force) (national estimate)',
# 'SL.UEM.TOTL.MA.NE.ZS':'Unemployment, male (% of male labor force) (national estimate)',
# 'SL.UEM.TOTL.NE.ZS':'Unemployment, total (% of total labor force) (national estimate)',
# 'SL.UEM.1524.FE.NE.ZS':'Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
# 'SL.UEM.1524.MA.NE.ZS':'Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
# 'SL.UEM.1524.NE.ZS':'Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
# 'AG.LND.PRCP.MM':'Average precipitation in depth (mm per year)',
# 'SH.DTH.COMM.ZS':'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
# 'SH.DTH.INJR.ZS':'Cause of death, by injury (% of total)',
# 'SH.DTH.NCOM.ZS':'Cause of death, by non-communicable diseases (% of total)',
# 'SL.AGR.0714.ZS':'Child employment in agriculture (% of economically active children ages 7-14)',
# 'SL.AGR.0714.FE.ZS':'Child employment in agriculture, female (% of female economically active children ages 7-14)',
# 'SL.AGR.0714.MA.ZS':'Child employment in agriculture, male (% of male economically active children ages 7-14)',
# 'SL.MNF.0714.ZS':'Child employment in manufacturing (% of economically active children ages 7-14)',
# 'SL.MNF.0714.FE.ZS':'Child employment in manufacturing, female (% of female economically active children ages 7-14)',
# 'SL.MNF.0714.MA.ZS':'Child employment in manufacturing, male (% of male economically active children ages 7-14)',
# 'SL.SRV.0714.ZS':'Child employment in services (% of economically active children ages 7-14)',
# 'SL.SRV.0714.FE.ZS':'Child employment in services, female (% of female economically active children ages 7-14)',
# 'SL.SRV.0714.MA.ZS':'Child employment in services, male (% of male economically active children ages 7-14)',
# 'SP.REG.BRTH.ZS':'Completeness of birth registration (%)',
# 'SE.XPD.CPRM.ZS':'Current education expenditure, primary (% of total expenditure in primary public institutions)',
# 'SE.XPD.CSEC.ZS':'Current education expenditure, secondary (% of total expenditure in secondary public institutions)',
# 'SE.XPD.CTER.ZS':'Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)',
# 'SE.XPD.CTOT.ZS':'Current education expenditure, total (% of total expenditure in public institutions)',
# 'EN.ATM.HFCG.KT.CE':'HFC gas emissions (thousand metric tons of CO2 equivalent)',
# 'SH.MED.BEDS.ZS':'Hospital beds (per 1,000 people)',
# 'SM.POP.TOTL.ZS':'International migrant stock (% of population)',
# 'SM.POP.TOTL':'International migrant stock, total',
# 'SE.ADT.LITR.FE.ZS':'Literacy rate, adult female (% of females ages 15 and above)',
# 'SE.ADT.LITR.MA.ZS':'Literacy rate, adult male (% of males ages 15 and above)',
# 'SE.ADT.LITR.ZS':'Literacy rate, adult total (% of people ages 15 and above)',
# 'SE.ADT.1524.LT.FM.ZS':'Literacy rate, youth (ages 15-24), gender parity index (GPI)',
# 'SE.ADT.1524.LT.FE.ZS':'Literacy rate, youth female (% of females ages 15-24)',
# 'SE.ADT.1524.LT.MA.ZS':'Literacy rate, youth male (% of males ages 15-24)',
# 'SE.ADT.1524.LT.ZS':'Literacy rate, youth total (% of people ages 15-24)',
# 'SP.DYN.IMRT.FE.IN':'Mortality rate, infant, female (per 1,000 live births)',
# 'SP.DYN.IMRT.MA.IN':'Mortality rate, infant, male (per 1,000 live births)',
# 'SH.DYN.MORT.FE':'Mortality rate, under-5, female (per 1,000 live births)',
# 'SH.DYN.MORT.MA':'Mortality rate, under-5, male (per 1,000 live births)',
# 'SM.POP.NETM':'Net migration',
# 'SH.DTH.0514':'Number of deaths ages 5-14 years',
# 'SH.STA.HYGN.ZS':'People with basic handwashing facilities including soap and water (% of population)',
# 'SH.STA.HYGN.RU.ZS':'People with basic handwashing facilities including soap and water, rural (% of rural population)',
# 'SH.STA.HYGN.UR.ZS':'People with basic handwashing facilities including soap and water, urban (% of urban population)',
# 'EN.ATM.PFCG.KT.CE':'PFC gas emissions (thousand metric tons of CO2 equivalent)',
# 'SH.STA.ANVC.ZS':'Pregnant women receiving prenatal care (%)',
# 'SH.DYN.0514':'Probability of dying at age 5-14 years (per 1,000 children age 5)',
# 'ER.H2O.INTR.PC':'Renewable internal freshwater resources per capita (cubic meters)',
# 'ER.H2O.INTR.K3':'Renewable internal freshwater resources, total (billion cubic meters)',
# 'SP.POP.SCIE.RD.P6':'Researchers in R&D (per million people)',
# 'EN.ATM.SF6G.KT.CE':'SF6 gas emissions (thousand metric tons of CO2 equivalent)',
# 'SP.POP.TECH.RD.P6':'Technicians in R&D (per million people)',
# 'SP.UWT.TFRT':'Unmet need for contraception (% of married women ages 15-49)',
# 'FX.OWN.TOTL.ZS':'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)',
# 'FX.OWN.TOTL.FE.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)',
# 'FX.OWN.TOTL.MA.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)',
# 'FX.OWN.TOTL.OL.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+)',
# 'FX.OWN.TOTL.40.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, poorest 40% (% of population ages 15+)',
# 'FX.OWN.TOTL.PL.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, primary education or less (% of population ages 15+)',
# 'FX.OWN.TOTL.60.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, richest 60% (% of population ages 15+)',
# 'FX.OWN.TOTL.SO.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, secondary education or more (% of population ages 15+)',
# 'FX.OWN.TOTL.YG.ZS':'Account ownership at a financial institution or with a mobile-money-service provider, young adults (% of population ages 15-24)',
# 'ER.H2O.FWTL.ZS':'Annual freshwater withdrawals, total (% of internal resources)',
# 'SH.STA.ARIC.ZS':'ARI treatment (% of children under 5 taken to a health provider)',
# 'SH.MLR.TRET.ZS':'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
# 'SP.REG.BRTH.FE.ZS':'Completeness of birth registration, female (%)',
# 'SP.REG.BRTH.MA.ZS':'Completeness of birth registration, male (%)',
# 'SP.REG.BRTH.RU.ZS':'Completeness of birth registration, rural (%)',
# 'SP.REG.BRTH.UR.ZS':'Completeness of birth registration, urban (%)',
# 'per_allsp.cov_pop_tot':'Coverage of social protection and labor programs (% of population)',
# 'per_sa_allsa.cov_pop_tot':'Coverage of social safety net programs (% of population)',
# 'per_sa_allsa.cov_q2_tot':'Coverage of social safety net programs in 2nd quintile (% of population)',
# 'per_sa_allsa.cov_q3_tot':'Coverage of social safety net programs in 3rd quintile (% of population)',
# 'per_sa_allsa.cov_q4_tot':'Coverage of social safety net programs in 4th quintile (% of population)',
# 'per_sa_allsa.cov_q1_tot':'Coverage of social safety net programs in poorest quintile (% of population)',
# 'per_sa_allsa.cov_q5_tot':'Coverage of social safety net programs in richest quintile (% of population)',
# 'SH.STA.ORTH':'Diarrhea treatment (% of children under 5 who received ORS packet)',
# 'SH.STA.BFED.ZS':'Exclusive breastfeeding (% of children under 6 months)',
# 'SL.EMP.SMGT.FE.ZS':'Female share of employment in senior and middle management (%)',
# 'SI.POV.GINI':'GINI index (World Bank estimate)',
# 'SI.DST.04TH.20':'Income share held by fourth 20%',
# 'SI.DST.10TH.10':'Income share held by highest 10%',
# 'SI.DST.05TH.20':'Income share held by highest 20%',
# 'SI.DST.FRST.10':'Income share held by lowest 10%',
# 'SI.DST.FRST.20':'Income share held by lowest 20%',
# 'SI.DST.02ND.20':'Income share held by second 20%',
# 'SI.DST.03RD.20':'Income share held by third 20%',
# 'SH.UHC.NOP1.ZG':'Increase in poverty gap at $1.90 ($ 2011 PPP) poverty line due to out-of-pocket health care expenditure (% of poverty line)',
# 'SH.UHC.NOP1.CG':'Increase in poverty gap at $1.90 ($ 2011 PPP) poverty line due to out-of-pocket health care expenditure (USD)',
# 'SH.UHC.NOP2.ZG':'Increase in poverty gap at $3.10 ($ 2011 PPP) poverty line due to out-of-pocket health care expenditure (% of poverty line)',
# 'SH.UHC.NOP2.CG':'Increase in poverty gap at $3.10 ($ 2011 PPP) poverty line due to out-of-pocket health care expenditure (USD)',
# 'SL.ISV.IFRM.ZS':'Informal employment (% of total non-agricultural employment)',
# 'SL.ISV.IFRM.FE.ZS':'Informal employment, female (% of total non-agricultural employment)',
# 'SL.ISV.IFRM.MA.ZS':'Informal employment, male (% of total non-agricultural employment)',
# 'ER.MRN.PTMR.ZS':'Marine protected areas (% of territorial waters)',
# 'SH.UHC.NOP1.TO':'Number of people pushed below the $1.90 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure',
# 'SH.UHC.NOP2.TO':'Number of people pushed below the $3.10 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure',
# 'SH.UHC.OOPC.10.TO':'Number of people spending more than 10% of household consumption or income on out-of-pocket health care expenditure',
# 'SH.UHC.OOPC.25.TO':'Number of people spending more than 25% of household consumption or income on out-of-pocket health care expenditure',
# 'SI.POV.GAPS':'Poverty gap at $1.90 a day (2011 PPP) (%)',
# 'SI.POV.LMIC.GP':'Poverty gap at $3.20 a day (2011 PPP) (%)',
# 'SI.POV.UMIC.GP':'Poverty gap at $5.50 a day (2011 PPP) (%)',
# 'SI.POV.NAGP':'Poverty gap at national poverty lines (%)',
# 'SI.POV.DDAY':'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
# 'SI.POV.LMIC':'Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)',
# 'SI.POV.UMIC':'Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)',
# 'SI.POV.NAHC':'Poverty headcount ratio at national poverty lines (% of population)',
# 'SH.SVR.WAST.ZS':'Prevalence of severe wasting, weight for height (% of children under 5)',
# 'SH.STA.STNT.ZS':'Prevalence of stunting, height for age (% of children under 5)',
# 'SH.STA.MALN.ZS':'Prevalence of underweight, weight for age (% of children under 5)',
# 'SH.STA.WAST.ZS':'Prevalence of wasting, weight for height (% of children under 5)',
# 'SH.UHC.NOP1.ZS':'Proportion of population pushed below the $1.90 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure (%)',
# 'SH.UHC.NOP2.ZS':'Proportion of population pushed below the $3.10 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure (%)',
# 'SH.UHC.OOPC.10.ZS':'Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
# 'SH.UHC.OOPC.25.ZS':'Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)',
# 'SI.POV.RUGP':'Rural poverty gap at national poverty lines (%)',
# 'SI.POV.RUHC':'Rural poverty headcount ratio at national poverty lines (% of rural population)',
# 'ER.PTD.TOTL.ZS':'Terrestrial and marine protected areas (% of total territorial area)',
# 'ER.LND.PTLD.ZS':'Terrestrial protected areas (% of total land area)',
# 'SI.POV.URGP':'Urban poverty gap at national poverty lines (%)',
# 'SI.POV.URHC':'Urban poverty headcount ratio at national poverty lines (% of urban population)',
# 'ER.H2O.FWAG.ZS':'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
# 'ER.H2O.FWDM.ZS':'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
# 'ER.H2O.FWIN.ZS':'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
# 'ER.H2O.FWTL.K3':'Annual freshwater withdrawals, total (billion cubic meters)',
# 'IC.CUS.DURS.EX':'Average time to clear exports through customs (days)',
# 'SI.RMT.COST.OB.ZS':'Average transaction cost of sending remittances from a specific country (%)',
# 'SL.SLF.0714.ZS':'Children in employment, self-employed (% of children in employment, ages 7-14)',
# 'SL.SLF.0714.FE.ZS':'Children in employment, self-employed, female (% of female children in employment, ages 7-14)',
# 'SL.SLF.0714.MA.ZS':'Children in employment, self-employed, male (% of male children in employment, ages 7-14)',
# 'SL.TLF.0714.SW.FE.ZS':'Children in employment, study and work, female (% of female children in employment, ages 7-14)',
# 'SL.TLF.0714.SW.MA.ZS':'Children in employment, study and work, male (% of male children in employment, ages 7-14)',
# 'SL.FAM.0714.ZS':'Children in employment, unpaid family workers (% of children in employment, ages 7-14)',
# 'SL.FAM.0714.FE.ZS':'Children in employment, unpaid family workers, female (% of female children in employment, ages 7-14)',
# 'SL.FAM.0714.MA.ZS':'Children in employment, unpaid family workers, male (% of male children in employment, ages 7-14)',
# 'SL.WAG.0714.ZS':'Children in employment, wage workers (% of children in employment, ages 7-14)',
# 'SL.WAG.0714.FE.ZS':'Children in employment, wage workers, female (% of female children in employment, ages 7-14)',
# 'SL.WAG.0714.MA.ZS':'Children in employment, wage workers, male (% of male children in employment, ages 7-14)',
# 'SL.TLF.0714.WK.FE.ZS':'Children in employment, work only, female (% of female children in employment, ages 7-14)',
# 'SL.TLF.0714.WK.MA.ZS':'Children in employment, work only, male (% of male children in employment, ages 7-14)',
# 'SN.ITK.SALT.ZS':'Consumption of iodized salt (% of households)',
# 'per_lm_alllm.cov_pop_tot':'Coverage of unemployment benefits and ALMP (% of population)',
# 'per_lm_alllm.cov_q2_tot':'Coverage of unemployment benefits and ALMP in 2nd quintile (% of population)',
# 'per_lm_alllm.cov_q3_tot':'Coverage of unemployment benefits and ALMP in 3rd quintile (% of population)',
# 'per_lm_alllm.cov_q4_tot':'Coverage of unemployment benefits and ALMP in 4th quintile (% of population)',
# 'per_lm_alllm.cov_q1_tot':'Coverage of unemployment benefits and ALMP in poorest quintile (% of population)',
# 'per_lm_alllm.cov_q5_tot':'Coverage of unemployment benefits and ALMP in richest quintile (% of population)',
# 'SH.STA.ORCF.ZS':'Diarrhea treatment (% of children under 5 receiving oral rehydration and continued feeding)',
# 'IC.TAX.GIFT.ZS':'Firms expected to give gifts in meetings with tax officials (% of firms)',
# 'IC.FRM.TRNG.ZS':'Firms offering formal training (% of firms)',
# 'IC.FRM.BNKS.ZS':'Firms using banks to finance investment (% of firms)',
# 'IC.FRM.BKWC.ZS':'Firms using banks to finance working capital (% of firms)',
# 'IC.FRM.FEMO.ZS':'Firms with female participation in ownership (% of firms)',
# 'IC.FRM.CORR.ZS':'Informal payments to public officials (% of firms)',
# 'AG.LND.EL5M.ZS':'Land area where elevation is below 5 meters (% of total land area)',
# 'SG.LAW.CHMR':'Law prohibits or invalidates child or early marriage (1=yes; 0=no)',
# 'SH.STA.TRAF.P5':'Mortality caused by road traffic injury (per 100,000 people)',
# 'DC.DAC.ISLL.CD':'Net bilateral aid flows from DAC donors, Iceland (current US$)',
# 'SE.PRM.NINT.ZS':'Net intake rate in grade 1 (% of official school-age population)',
# 'SE.PRM.NINT.FE.ZS':'Net intake rate in grade 1, female (% of official school-age population)',
# 'SE.PRM.NINT.MA.ZS':'Net intake rate in grade 1, male (% of official school-age population)',
# 'EN.POP.EL5M.ZS':'Population living in areas where elevation is below 5 meters (% of total population)',
# 'SH.STA.OWGH.ZS':'Prevalence of overweight, weight for height (% of children under 5)',
# 'SH.SVR.WAST.FE.ZS':'Prevalence of severe wasting, weight for height, female (% of children under 5)',
# 'SH.SVR.WAST.MA.ZS':'Prevalence of severe wasting, weight for height, male (% of children under 5)',
# 'SH.STA.STNT.FE.ZS':'Prevalence of stunting, height for age, female (% of children under 5)',
# 'SH.STA.STNT.MA.ZS':'Prevalence of stunting, height for age, male (% of children under 5)',
# 'SH.STA.MALN.FE.ZS':'Prevalence of underweight, weight for age, female (% of children under 5)',
# 'SH.STA.MALN.MA.ZS':'Prevalence of underweight, weight for age, male (% of children under 5)',
# 'SH.STA.WAST.FE.ZS':'Prevalence of wasting, weight for height, female (% of children under 5)',
# 'SH.STA.WAST.MA.ZS':'Prevalence of wasting, weight for height, male (% of children under 5)',
# 'AG.LND.TOTL.RU.K2':'Rural land area (sq. km)',
# 'AG.LND.EL5M.RU.ZS':'Rural land area where elevation is below 5 meters (% of total land area)',
# 'AG.LND.EL5M.RU.K2':'Rural land area where elevation is below 5 meters (sq. km)',
# 'EN.POP.EL5M.RU.ZS':'Rural population living in areas where elevation is below 5 meters (% of total population)',
# 'SP.MTR.1519.ZS':'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)',
# 'IC.GOV.DURS.ZS':'Time spent dealing with the requirements of government regulations (% of senior management time)',
# 'IC.ELC.DURS':'Time to obtain an electrical connection (days)',
# 'SH.ALC.PCAP.LI':'Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
# 'SH.ALC.PCAP.FE.LI':'Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
# 'SH.ALC.PCAP.MA.LI':'Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)',
# 'SE.SEC.TCAQ.LO.ZS':'Trained teachers in lower secondary education (% of total teachers)',
# 'SE.SEC.TCAQ.LO.FE.ZS':'Trained teachers in lower secondary education, female (% of female teachers)',
# 'SE.PRM.TCAQ.ZS':'Trained teachers in primary education (% of total teachers)',
# 'SE.PRM.TCAQ.FE.ZS':'Trained teachers in primary education, female (% of female teachers)',
# 'SE.PRM.TCAQ.MA.ZS':'Trained teachers in primary education, male (% of male teachers)',
# 'AG.LND.TOTL.UR.K2':'Urban land area (sq. km)',
# 'AG.LND.EL5M.UR.ZS':'Urban land area where elevation is below 5 meters (% of total land area)',
# 'AG.LND.EL5M.UR.K2':'Urban land area where elevation is below 5 meters (sq. km)',
# 'EN.POP.EL5M.UR.ZS':'Urban population living in areas where elevation is below 5 meters (% of total population)',
# 'SP.DYN.WFRT':'Wanted fertility rate (births per woman)',
# 'ER.GDP.FWTL.M3.KD':'Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)',
# 'SG.VAW.REAS.ZS':'Women who believe a husband is justified in beating his wife (any of five reasons) (%)',
# 'SG.VAW.ARGU.ZS':'Women who believe a husband is justified in beating his wife when she argues with him (%)',
# 'SG.VAW.BURN.ZS':'Women who believe a husband is justified in beating his wife when she burns the food (%)',
# 'SG.VAW.GOES.ZS':'Women who believe a husband is justified in beating his wife when she goes out without telling him (%)',
# 'SG.VAW.NEGL.ZS':'Women who believe a husband is justified in beating his wife when she neglects the children (%)',
# 'SG.VAW.REFU.ZS':'Women who believe a husband is justified in beating his wife when she refuses sex with him (%)',
# 'SP.M15.2024.FE.ZS':'Women who were first married by age 15 (% of women ages 20-24)',
# 'SP.M18.2024.FE.ZS':'Women who were first married by age 18 (% of women ages 20-24)',
# 'PA.NUS.PPP.05':'2005 PPP conversion factor, GDP (LCU per international $)',
# 'PA.NUS.PRVT.PP.05':'2005 PPP conversion factor, private consumption (LCU per international $)',
# 'per_si_allsi.adq_pop_tot':'Adequacy of social insurance programs (% of total welfare of beneficiary households)',
# 'per_allsp.adq_pop_tot':'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)',
# 'per_sa_allsa.adq_pop_tot':'Adequacy of social safety net programs (% of total welfare of beneficiary households)',
# 'SE.SEC.UNER.LO.ZS':'Adolescents out of school (% of lower secondary school age)',
# 'SE.SEC.UNER.LO.FE.ZS':'Adolescents out of school, female (% of female lower secondary school age)',
# 'SE.SEC.UNER.LO.MA.ZS':'Adolescents out of school, male (% of male lower secondary school age)',
# 'AG.AGR.TRAC.NO':'Agricultural machinery, tractors',
# 'AG.LND.TRAC.ZS':'Agricultural machinery, tractors per 100 sq. km of arable land',
# 'IC.TAX.METG':'Average number of visits or required meetings with tax officials (for affected firms)',
# 'per_si_allsi.ben_q1_tot':'Benefit incidence of social insurance programs to poorest quintile (% of total social insurance benefits)',
# 'per_allsp.ben_q1_tot':'Benefit incidence of social protection and labor programs to poorest quintile (% of total SPL benefits)',
# 'per_sa_allsa.ben_q1_tot':'Benefit incidence of social safety net programs to poorest quintile (% of total safety net benefits)',
# 'EN.BIR.THRD.NO':'Bird species, threatened',
# 'IC.FRM.BRIB.ZS':'Bribery incidence (% of firms experiencing at least one bribe payment request)',
# 'SP.REG.DTHS.ZS':'Completeness of death registration with cause-of-death information (%)',
# 'SH.CON.1524.FE.ZS':'Condom use, population ages 15-24, female (% of females ages 15-24)',
# 'SH.CON.1524.MA.ZS':'Condom use, population ages 15-24, male (% of males ages 15-24)',
# 'per_si_allsi.cov_pop_tot':'Coverage of social insurance programs (% of population)',
# 'per_si_allsi.cov_q2_tot':'Coverage of social insurance programs in 2nd quintile (% of population)',
# 'per_si_allsi.cov_q3_tot':'Coverage of social insurance programs in 3rd quintile (% of population)',
# 'per_si_allsi.cov_q4_tot':'Coverage of social insurance programs in 4th quintile (% of population)',
# 'per_si_allsi.cov_q1_tot':'Coverage of social insurance programs in poorest quintile (% of population)',
# 'per_si_allsi.cov_q5_tot':'Coverage of social insurance programs in richest quintile (% of population)',
# 'SH.STA.DIAB.ZS':'Diabetes prevalence (% of population ages 20 to 79)',
# 'EN.CLC.DRSK.XQ':'Disaster risk reduction progress score (1-5 scale; 5=best)',
# 'EN.CLC.MDAT.ZS':'Droughts, floods, extreme temperatures (% of population, average 1990-2009)',
# 'IC.BUS.EASE.XQ':'Ease of doing business index (1=most business-friendly regulations)',
# 'SE.TER.CUAT.BA.FE.ZS':'Educational attainment, at least Bachelors or equivalent, population 25+, female (%) (cumulative)',
# 'SE.TER.CUAT.BA.MA.ZS':'Educational attainment, at least Bachelors or equivalent, population 25+, male (%) (cumulative)',
# 'SE.TER.CUAT.BA.ZS':'Educational attainment, at least Bachelors or equivalent, population 25+, total (%) (cumulative)',
# 'SE.SEC.CUAT.LO.FE.ZS':'Educational attainment, at least completed lower secondary, population 25+, female (%) (cumulative)',
# 'SE.SEC.CUAT.LO.MA.ZS':'Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)',
# 'SE.SEC.CUAT.LO.ZS':'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)',
# 'SE.SEC.CUAT.PO.FE.ZS':'Educational attainment, at least completed post-secondary, population 25+, female (%) (cumulative)',
# 'SE.SEC.CUAT.PO.MA.ZS':'Educational attainment, at least completed post-secondary, population 25+, male (%) (cumulative)',
# 'SE.SEC.CUAT.PO.ZS':'Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)',
# 'SE.PRM.CUAT.FE.ZS':'Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)',
# 'SE.PRM.CUAT.MA.ZS':'Educational attainment, at least completed primary, population 25+ years, male (%) (cumulative)',
# 'SE.PRM.CUAT.ZS':'Educational attainment, at least completed primary, population 25+ years, total (%) (cumulative)',
# 'SE.TER.CUAT.ST.FE.ZS':'Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)',
# 'SE.TER.CUAT.ST.MA.ZS':'Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)',
# 'SE.TER.CUAT.ST.ZS':'Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)',
# 'SE.SEC.CUAT.UP.FE.ZS':'Educational attainment, at least completed upper secondary, population 25+, female (%) (cumulative)',
# 'SE.SEC.CUAT.UP.MA.ZS':'Educational attainment, at least completed upper secondary, population 25+, male (%) (cumulative)',
# 'SE.SEC.CUAT.UP.ZS':'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)',
# 'SP.HOU.FEMA.ZS':'Female headed households (% of households with a female head)',
# 'IC.FRM.CMPU.ZS':'Firms competing against unregistered firms (% of firms)',
# 'IC.ELC.OUTG.ZS':'Firms experiencing electrical outages (% of firms)',
# 'IC.FRM.THEV.ZS':'Firms experiencing losses due to theft and vandalism (% of firms)',
# 'IC.FRM.FREG.ZS':'Firms formally registered when operations started (% of firms)',
# 'IC.FRM.INFM.ZS':'Firms that do not report all sales for tax purposes (% of firms)',
# 'IC.FRM.RSDV.ZS':'Firms that spend on R&D (% of firms)',
# 'IC.FRM.METG.ZS':'Firms visited or required meetings with tax officials (% of firms)',
# 'IC.FRM.FEMM.ZS':'Firms with female top manager (% of firms)',
# 'EN.FSH.THRD.NO':'Fish species, threatened',
# 'HD.HCI.OVRL':'Human capital index (HCI) (scale 0-1)',
# 'HD.HCI.OVRL.FE':'Human capital index (HCI), female (scale 0-1)',
# 'HD.HCI.OVRL.LB.FE':'Human capital index (HCI), female, lower bound (scale 0-1)',
# 'HD.HCI.OVRL.UB.FE':'Human capital index (HCI), female, upper bound (scale 0-1)',
# 'HD.HCI.OVRL.LB':'Human capital index (HCI), lower bound (scale 0-1)',
# 'HD.HCI.OVRL.MA':'Human capital index (HCI), male (scale 0-1)',
# 'HD.HCI.OVRL.LB.MA':'Human capital index (HCI), male, lower bound (scale 0-1)',
# 'HD.HCI.OVRL.UB.MA':'Human capital index (HCI), male, upper bound (scale 0-1)',
# 'HD.HCI.OVRL.UB':'Human capital index (HCI), upper bound (scale 0-1)',
# 'ER.H2O.FWST.ZS':'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
# 'IC.FRM.CRIM.ZS':'Losses due to theft and vandalism (% of annual sales of affected firms)',
# 'SH.STA.BRTW.ZS':'Low-birthweight babies (% of births)',
# 'EN.MAM.THRD.NO':'Mammal species, threatened',
# 'SH.STA.AIRP.P5':'Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)',
# 'SH.STA.AIRP.FE.P5':'Mortality rate attributed to household and ambient air pollution, age-standardized, female (per 100,000 female population)',
# 'SH.STA.AIRP.MA.P5':'Mortality rate attributed to household and ambient air pollution, age-standardized, male (per 100,000 male population)',
# 'SH.STA.WASH.P5':'Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)',
# 'DT.NFL.FAOG.CD':'Net official flows from UN agencies, FAO (current US$)',
# 'EN.HPT.THRD.NO':'Plant species (higher), threatened',
# 'IC.ELC.OUTG':'Power outages in firms in a typical month (number)',
# 'DT.DOD.PVLX.EX.ZS':'Present value of external debt (% of exports of goods, services and primary income)',
# 'DT.DOD.PVLX.GN.ZS':'Present value of external debt (% of GNI)',
# 'DT.DOD.PVLX.CD':'Present value of external debt (current US$)',
# 'SH.STA.OWGH.FE.ZS':'Prevalence of overweight, weight for height, female (% of children under 5)',
# 'SH.STA.OWGH.MA.ZS':'Prevalence of overweight, weight for height, male (% of children under 5)',
# 'SG.VAW.1549.ZS':'Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of women age 15-49)',
# 'IE.PPN.ICTI.CD':'Public private partnerships investment in ICT (current US$)',
# 'SE.SEC.NENR':'School enrollment, secondary (% net)',
# 'SE.SEC.NENR.FE':'School enrollment, secondary, female (% net)',
# 'SE.SEC.NENR.MA':'School enrollment, secondary, male (% net)',
# 'SH.MED.SAOP.P5':'Specialist surgical workforce (per 100,000 population)',
# 'IC.FRM.DURS':'Time required to obtain an operating license (days)',
# 'SE.SEC.TCAQ.ZS':'Trained teachers in secondary education (% of total teachers)',
# 'SE.SEC.TCAQ.FE.ZS':'Trained teachers in secondary education, female (% of female teachers)',
# 'SE.SEC.TCAQ.MA.ZS':'Trained teachers in secondary education, male (% of male teachers)',
# 'SE.SEC.TCAQ.UP.ZS':'Trained teachers in upper secondary education (% of total teachers)',
# 'SE.SEC.TCAQ.UP.FE.ZS':'Trained teachers in upper secondary education, female (% of female teachers)',
# 'SE.SEC.TCAQ.UP.MA.ZS':'Trained teachers in upper secondary education, male (% of male teachers)',
# 'SH.UHC.SRVS.CV.XD':'UHC service coverage index',
# 'SH.MLR.NETS.ZS':'Use of insecticide-treated bed nets (% of under-5 population)',
# 'IC.FRM.OUTG.ZS':'Value lost due to electrical outages (% of sales for affected firms)',
# 'SG.DMK.ALLD.FN.ZS':'Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)',
# 'per_lm_alllm.adq_pop_tot':'Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)',
# 'SH.HIV.INCD.TL':'Adults (ages 15+) and children (ages 0-14) newly infected with HIV',
# 'SH.HIV.INCD':'Adults (ages 15+) newly infected with HIV',
# 'SI.SPR.PC40.ZG':'Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)',
# 'SI.SPR.PCAP.ZG':'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
# 'SH.HIV.ARTC.ZS':'Antiretroviral therapy coverage (% of people living with HIV)',
# 'SH.HIV.PMTC.ZS':'Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)',
# 'SL.TLF.0714.SW.TM':'Average working hours of children, study and work, ages 7-14 (hours per week)',
# 'SL.TLF.0714.SW.FE.TM':'Average working hours of children, study and work, female, ages 7-14 (hours per week)',
# 'SL.TLF.0714.SW.MA.TM':'Average working hours of children, study and work, male, ages 7-14 (hours per week)',
# 'SL.TLF.0714.WK.TM':'Average working hours of children, working only, ages 7-14 (hours per week)',
# 'SL.TLF.0714.WK.FE.TM':'Average working hours of children, working only, female, ages 7-14 (hours per week)',
# 'SL.TLF.0714.WK.MA.TM':'Average working hours of children, working only, male, ages 7-14 (hours per week)',
# 'FD.RES.LIQU.AS.ZS':'Bank liquid reserves to bank assets ratio (%)',
# 'per_lm_alllm.ben_q1_tot':'Benefit incidence of unemployment benefits and ALMP to poorest quintile (% of total U/ALMP benefits)',
# 'FB.CBK.BRWR.P3':'Borrowers from commercial banks (per 1,000 adults)',
# 'SH.HIV.0014':'Children (0-14) living with HIV',
# 'SH.HIV.INCD.14':'Children (ages 0-14) newly infected with HIV',
# 'FS.AST.DOMO.GD.ZS':'Claims on other sectors of the domestic economy (% of GDP)',
# 'FM.AST.DOMO.ZG.M3':'Claims on other sectors of the domestic economy (annual growth as % of broad money)',
# 'SP.DTH.INFR.ZS':'Completeness of infant death reporting (% of reported infant deaths to estimated infant deaths)',
# 'SP.DTH.REPT.ZS':'Completeness of total death reporting (% of reported total deaths to estimated total deaths)',
# 'FR.INR.DPST':'Deposit interest rate (%)',
# 'FB.CBK.DPTR.P3':'Depositors with commercial banks (per 1,000 adults)',
# 'SE.TER.CUAT.MS.FE.ZS':'Educational attainment, at least Masters or equivalent, population 25+, female (%) (cumulative)',
# 'SE.TER.CUAT.MS.MA.ZS':'Educational attainment, at least Masters or equivalent, population 25+, male (%) (cumulative)',
# 'SE.TER.CUAT.MS.ZS':'Educational attainment, at least Masters or equivalent, population 25+, total (%) (cumulative)',
# 'SE.TER.CUAT.DO.FE.ZS':'Educational attainment, Doctoral or equivalent, population 25+, female (%) (cumulative)',
# 'SE.TER.CUAT.DO.MA.ZS':'Educational attainment, Doctoral or equivalent, population 25+, male (%) (cumulative)',
# 'SE.TER.CUAT.DO.ZS':'Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)',
# 'SH.STA.FGMS.ZS':'Female genital mutilation prevalence (%)',
# 'NV.FSM.TOTL.KN':'Financial intermediary services indirectly Measured (FISIM) (constant LCU)',
# 'NV.FSM.TOTL.CN':'Financial intermediary services indirectly Measured (FISIM) (current LCU)',
# 'EN.CLC.GHGR.MT.CE':'GHG net emissions/removals by LUCF (Mt of CO2 equivalent)',
# 'SH.HIV.INCD.ZS':'Incidence of HIV (per 1,000 uninfected population ages 15-49)',
# 'FR.INR.LNDP':'Interest rate spread (lending rate minus deposit rate, %)',
# 'IE.PPI.ICTI.CD':'Investment in ICT with private participation (current US$)',
# 'DC.ODA.TLDC.GN.ZS':'Net ODA provided to the least developed countries (% of GNI)',
# 'DC.ODA.TLDC.CD':'Net ODA provided, to the least developed countries (current US$)',
# 'DC.ODA.TOTL.GN.ZS':'Net ODA provided, total (% of GNI)',
# 'DC.ODA.TOTL.KD':'Net ODA provided, total (constant 2015 US$)',
# 'DC.ODA.TOTL.CD':'Net ODA provided, total (current US$)',
# 'DT.ODA.OATL.KD':'Net official aid received (constant 2015 US$)',
# 'DT.ODA.OATL.CD':'Net official aid received (current US$)',
# 'DT.NFL.IAEA.CD':'Net official flows from UN agencies, IAEA (current US$)',
# 'DT.NFL.UNEC.CD':'Net official flows from UN agencies, UNECE (current US$)',
# 'DT.NFL.UNPB.CD':'Net official flows from UN agencies, UNPBF (current US$)',
# 'DT.NFL.UNRW.CD':'Net official flows from UN agencies, UNRWA (current US$)',
# 'DT.NFL.UNWT.CD':'Net official flows from UN agencies, UNWTO (current US$)',
# 'NY.GSR.NFCY.KN':'Net primary income (Net income from abroad) (constant LCU)',
# 'NY.TRF.NCTR.KN':'Net secondary income (Net current transfers from abroad) (constant LCU)',
# 'SH.SGR.PROC.P5':'Number of surgical procedures (per 100,000 population)',
# 'SL.TLF.PART.FE.ZS':'Part time employment, female (% of total female employment)',
# 'SL.TLF.PART.MA.ZS':'Part time employment, male (% of total male employment)',
# 'SL.TLF.PART.ZS':'Part time employment, total (% of total employment)',
# 'SH.H2O.SMDW.ZS':'People using safely managed drinking water services (% of population)',
# 'SH.H2O.SMDW.UR.ZS':'People using safely managed drinking water services, urban (% of urban population)',
# 'SH.STA.SMSS.ZS':'People using safely managed sanitation services (% of population)',
# 'SH.STA.SMSS.UR.ZS':'People using safely managed sanitation services, urban (% of urban population)',
# 'VC.PKP.TOTL.UN':'Presence of peace keepers (number of troops, police, and military observers in mandate)',
# 'SH.HIV.1524.FE.ZS':'Prevalence of HIV, female (% ages 15-24)',
# 'SH.HIV.1524.MA.ZS':'Prevalence of HIV, male (% ages 15-24)',
# 'SH.DYN.AIDS.ZS':'Prevalence of HIV, total (% of population ages 15-49)',
# 'SG.TIM.UWRK.FE':'Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)',
# 'SG.TIM.UWRK.MA':'Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)',
# 'PX.REX.REER':'Real effective exchange rate index (2010 = 100)',
# 'FR.INR.RISK':'Risk premium on lending (lending rate minus treasury bill rate, %)',
# 'SI.SPR.PC40':'Survey mean consumption or income per capita, bottom 40% of population (2011 PPP $ per day)',
# 'SI.SPR.PCAP':'Survey mean consumption or income per capita, total population (2011 PPP $ per day)',
# 'SE.SEC.TCAQ.LO.MA.ZS':'Trained teachers in lower secondary education, male (% of male teachers)',
# 'SE.PRE.TCAQ.ZS':'Trained teachers in preprimary education (% of total teachers)',
# 'SE.PRE.TCAQ.FE.ZS':'Trained teachers in preprimary education, female (% of female teachers)',
# 'SE.PRE.TCAQ.MA.ZS':'Trained teachers in preprimary education, male (% of male teachers)',
# 'SG.DMK.SRCR.FN.ZS':'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care  (% of women age 15-49)',
# 'SH.DYN.AIDS.FE.ZS':'Womens share of population ages 15+ living with HIV (%)',
# }

# %%
shitty = []
for i in indicators.keys():
    try:
        td = {i:indicators[i]}
        print (td)
        df = wb.get_dataframe(td, country='IND', keep_levels=False)
        df.reset_index(inplace=True)
        df.dropna(inplace=True)
        print (df.corr())
    except:
        shitty.append (i)

shitty
# Out:
# {'SP.POP.TOTL': 'Population, total'}
#                    Population, total
# Population, total               1.00
# {'SP.POP.GROW': 'Population growth (annual %)'}
#                               Population growth (annual %)
# Population growth (annual %)                          1.00
# {'AG.SRF.TOTL.K2': 'Surface area (sq. km)'}
#                        Surface area (sq. km)
# Surface area (sq. km)                   1.00
# {'SI.POV.NAHC': 'Poverty headcount ratio at national poverty lines (% of population)'}
#                                                     Poverty headcount ratio at national poverty lines (% of population)
# Poverty headcount ratio at national poverty lin...                                               1.00
# {'NY.GNP.ATLS.CD': 'GNI, Atlas method (current US$)'}
#                                  GNI, Atlas method (current US$)
# GNI, Atlas method (current US$)                             1.00
# {'NY.GNP.PCAP.CD': 'GNI per capita, Atlas method (current US$)'}
#                                             GNI per capita, Atlas method (current US$)
# GNI per capita, Atlas method (current US$)                                        1.00
# {'NY.GNP.MKTP.PP.CD': 'GNI, PPP (current international $)'}
#                                     GNI, PPP (current international $)
# GNI, PPP (current international $)                                1.00
# {'NY.GNP.PCAP.PP.CD': 'GNI per capita, PPP (current international $)'}
#                                                GNI per capita, PPP (current international $)
# GNI per capita, PPP (current international $)                                           1.00
# {'SI.DST.FRST.20': 'Income share held by lowest 20%'}
#                                  Income share held by lowest 20%
# Income share held by lowest 20%                             1.00
# {'SP.DYN.LE00.IN': 'Life expectancy at birth, total (years)'}
#                                          Life expectancy at birth, total (years)
# Life expectancy at birth, total (years)                                     1.00
# {'SP.DYN.TFRT.IN': 'Fertility rate, total (births per woman)'}
#                                           Fertility rate, total (births per woman)
# Fertility rate, total (births per woman)                                      1.00
# {'SP.ADO.TFRT': 'Adolescent fertility rate (births per 1,000 women ages 15-19)'}
#                                                     Adolescent fertility rate (births per 1,000 women ages 15-19)
# Adolescent fertility rate (births per 1,000 wom...                                               1.00
# {'SP.DYN.CONU.ZS': 'Contraceptive prevalence, any methods (% of women ages 15-49)'}
#                                                     Contraceptive prevalence, any methods (% of women ages 15-49)
# Contraceptive prevalence, any methods (% of wom...                                               1.00
# {'SH.STA.BRTC.ZS': 'Births attended by skilled health staff (% of total)'}
#                                                     Births attended by skilled health staff (% of total)
# Births attended by skilled health staff (% of t...                                               1.00
# {'SH.DYN.MORT': 'Mortality rate, under-5 (per 1,000 live births)'}
#                                                  Mortality rate, under-5 (per 1,000 live births)
# Mortality rate, under-5 (per 1,000 live births)                                             1.00
# {'SH.STA.MALN.ZS': 'Prevalence of underweight, weight for age (% of children under 5)'}
#                                                     Prevalence of underweight, weight for age (% of children under 5)
# Prevalence of underweight, weight for age (% of...                                               1.00
# {'SH.IMM.MEAS': 'Immunization, measles (% of children ages 12-23 months)'}
#                                                     Immunization, measles (% of children ages 12-23 months)
# Immunization, measles (% of children ages 12-23...                                               1.00
# {'SE.PRM.CMPT.ZS': 'Primary completion rate, total (% of relevant age group)'}
#                                                     Primary completion rate, total (% of relevant age group)
# Primary completion rate, total (% of relevant a...                                               1.00
# {'SE.SEC.ENRR': 'School enrollment, secondary (% gross)'}
#                                         School enrollment, secondary (% gross)
# School enrollment, secondary (% gross)                                    1.00
# {'SE.ENR.PRSC.FM.ZS': 'School enrollment, primary and secondary (gross), gender parity index (GPI)'}
#                                                     School enrollment, primary and secondary (gross), gender parity index (GPI)
# School enrollment, primary and secondary (gross...                                               1.00
# {'SH.DYN.AIDS.ZS': 'Prevalence of HIV, total (% of population ages 15-49)'}
# Empty DataFrame
# Columns: []
# Index: []
# {'AG.LND.FRST.K2': 'Forest area (sq. km)'}
#                       Forest area (sq. km)
# Forest area (sq. km)                  1.00
# {'ER.GDP.FWTL.M3.KD': 'Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)'}
#                                                     Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)
# Water productivity, total (constant 2010 US$ GD...                                               1.00
# {'SH.H2O.SAFE.ZS': 'Improved water source (% of population with access)'}
# {'SH.STA.ACSN': 'Improved sanitation facilities (% of population with access)'}
# {'EG.USE.PCAP.KG.OE': 'Energy use (kg of oil equivalent per capita)'}
#                                               Energy use (kg of oil equivalent per capita)
# Energy use (kg of oil equivalent per capita)                                          1.00
# {'EN.ATM.CO2E.PC': 'CO2 emissions (metric tons per capita)'}
#                                         CO2 emissions (metric tons per capita)
# CO2 emissions (metric tons per capita)                                    1.00
# {'EG.USE.ELEC.KH.PC': 'Electric power consumption (kWh per capita)'}
#                                              Electric power consumption (kWh per capita)
# Electric power consumption (kWh per capita)                                         1.00
# {'NY.GDP.MKTP.CD': 'GDP (current US$)'}
#                    GDP (current US$)
# GDP (current US$)               1.00
# {'NY.GDP.MKTP.KD.ZG': 'GDP growth (annual %)'}
#                        GDP growth (annual %)
# GDP growth (annual %)                   1.00
# {'NY.GDP.DEFL.KD.ZG': 'Inflation, GDP deflator (annual %)'}
#                                     Inflation, GDP deflator (annual %)
# Inflation, GDP deflator (annual %)                                1.00
# {'NV.AGR.TOTL.ZS': 'Agriculture, value added (% of GDP)'}
#                                      Agriculture, value added (% of GDP)
# Agriculture, value added (% of GDP)                                 1.00
# {'NV.IND.TOTL.ZS': 'Industry, value added (% of GDP)'}
#                                   Industry, value added (% of GDP)
# Industry, value added (% of GDP)                              1.00
# {'NV.SRV.TETC.ZS': 'Services, etc., value added (% of GDP)'}
# {'NE.EXP.GNFS.ZS': 'Exports of goods and services (% of GDP)'}
#                                           Exports of goods and services (% of GDP)
# Exports of goods and services (% of GDP)                                      1.00
# {'NE.IMP.GNFS.ZS': 'Imports of goods and services (% of GDP)'}
#                                           Imports of goods and services (% of GDP)
# Imports of goods and services (% of GDP)                                      1.00
# {'NE.GDI.TOTL.ZS': 'Gross capital formation (% of GDP)'}
#                                     Gross capital formation (% of GDP)
# Gross capital formation (% of GDP)                                1.00
# {'GC.REV.XGRT.GD.ZS': 'Revenue, excluding grants (% of GDP)'}
#                                       Revenue, excluding grants (% of GDP)
# Revenue, excluding grants (% of GDP)                                  1.00
# {'GC.BAL.CASH.GD.ZS': 'Cash surplus/deficit (% of GDP)'}
# {'IC.REG.PROC': 'Start-up procedures to register a business (number)'}
#                                                     Start-up procedures to register a business (number)
# Start-up procedures to register a business (num...                                               1.00
# {'CM.MKT.LCAP.GD.ZS': 'Market capitalization of listed domestic companies (% of GDP)'}
#                                                     Market capitalization of listed domestic companies (% of GDP)
# Market capitalization of listed domestic compan...                                               1.00
# {'MS.MIL.XPND.GD.ZS': 'Military expenditure (% of GDP)'}
#                                  Military expenditure (% of GDP)
# Military expenditure (% of GDP)                             1.00
# {'IT.CEL.SETS.P2': 'Mobile cellular subscriptions (per 100 people)'}
#                                                 Mobile cellular subscriptions (per 100 people)
# Mobile cellular subscriptions (per 100 people)                                            1.00
# {'IT.NET.USER.P2': 'Internet users (per 100 people)'}
# {'IS.ROD.PAVE.ZS': 'Roads, paved (% of total roads)'}
# {'TX.VAL.TECH.MF.ZS': 'High-technology exports (% of manufactured exports)'}
#                                                     High-technology exports (% of manufactured exports)
# High-technology exports (% of manufactured expo...                                               1.00
# {'TG.VAL.TOTL.GD.ZS': 'Merchandise trade (% of GDP)'}
#                               Merchandise trade (% of GDP)
# Merchandise trade (% of GDP)                          1.00
# {'TT.PRI.MRCH.XD.WD': 'Net barter terms of trade index (2000 = 100)'}
#                                               Net barter terms of trade index (2000 = 100)
# Net barter terms of trade index (2000 = 100)                                          1.00
# {'DT.DOD.DECT.CD': 'External debt stocks, total (DOD, current US$)'}
#                                                 External debt stocks, total (DOD, current US$)
# External debt stocks, total (DOD, current US$)                                            1.00
# {'DT.TDS.DECT.GN.ZS': 'Total debt service (% of GNI)'}
#                                Total debt service (% of GNI)
# Total debt service (% of GNI)                           1.00
# {'SM.POP.NETM': 'Net migration'}
#                Net migration
# Net migration           1.00
# {'BM.TRF.PWKR.CD.DT': 'Personal remittances, paid (current US$)'}
#                                           Personal remittances, paid (current US$)
# Personal remittances, paid (current US$)                                      1.00
# {'BX.KLT.DINV.CD.WD': 'Foreign direct investment, net inflows (BoP, current US$)'}
#                                                     Foreign direct investment, net inflows (BoP, current US$)
# Foreign direct investment, net inflows (BoP, cu...                                               1.00
# {'DT.ODA.ODAT.PC.ZS': 'Net ODA received per capita (current US$)'}
#                                            Net ODA received per capita (current US$)
# Net ODA received per capita (current US$)                                       1.00
# {'NY.GDP.PCAP.CD': 'GDP per capita (current US$)'}
#                               GDP per capita (current US$)
# GDP per capita (current US$)                          1.00
# {'BN.KLT.DINV.CD': 'Foreign direct investment, net (BoP, current US$)'}
#                                                    Foreign direct investment, net (BoP, current US$)
# Foreign direct investment, net (BoP, current US$)                                               1.00
# {'FP.CPI.TOTL.ZG': 'Inflation, consumer prices (annual %)'}
#                                        Inflation, consumer prices (annual %)
# Inflation, consumer prices (annual %)                                   1.00
# {'SI.POV.DDAY': 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)'}
#                                                     Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)
# Poverty headcount ratio at $1.90 a day (2011 PP...                                               1.00
# {'SI.POV.LMIC': 'Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)'}
#                                                     Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)
# Poverty headcount ratio at $3.20 a day (2011 PP...                                               1.00
# {'SI.POV.UMIC': 'Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)'}
#                                                     Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)
# Poverty headcount ratio at $5.50 a day (2011 PP...                                               1.00
# ['SH.H2O.SAFE.ZS',
#  'SH.STA.ACSN',
#  'NV.SRV.TETC.ZS',
#  'GC.BAL.CASH.GD.ZS',
#  'IT.NET.USER.P2',
#  'IS.ROD.PAVE.ZS']

# %%
#shitty ones:
#['SH.H2O.SAFE.ZS',
# 'SH.STA.ACSN',
# 'NV.SRV.TETC.ZS',
 #'GC.BAL.CASH.GD.ZS',
 #'IT.NET.USER.P2',
 #'IS.ROD.PAVE.ZS']
    
indicators = {#popular WB indicators
'SP.POP.TOTL':'Population, total',
'SP.POP.GROW':'Population growth (annual %)',
'AG.SRF.TOTL.K2':'Surface area (sq. km)',
'SI.POV.NAHC':'Poverty headcount ratio at national poverty lines (% of population)',
'NY.GNP.ATLS.CD':'GNI, Atlas method (current US$)',
'NY.GNP.PCAP.CD':'GNI per capita, Atlas method (current US$)',
'NY.GNP.MKTP.PP.CD':'GNI, PPP (current international $)',
'NY.GNP.PCAP.PP.CD':'GNI per capita, PPP (current international $)',
'SI.DST.FRST.20':'Income share held by lowest 20%',
'SP.DYN.LE00.IN':'Life expectancy at birth, total (years)',
'SP.DYN.TFRT.IN':'Fertility rate, total (births per woman)',
'SP.ADO.TFRT':'Adolescent fertility rate (births per 1,000 women ages 15-19)',
'SP.DYN.CONU.ZS':'Contraceptive prevalence, any methods (% of women ages 15-49)',
'SH.STA.BRTC.ZS':'Births attended by skilled health staff (% of total)',
'SH.DYN.MORT':'Mortality rate, under-5 (per 1,000 live births)',
'SH.STA.MALN.ZS':'Prevalence of underweight, weight for age (% of children under 5)',
'SH.IMM.MEAS':'Immunization, measles (% of children ages 12-23 months)',
'SE.PRM.CMPT.ZS':'Primary completion rate, total (% of relevant age group)',
'SE.SEC.ENRR':'School enrollment, secondary (% gross)',
'SE.ENR.PRSC.FM.ZS':'School enrollment, primary and secondary (gross), gender parity index (GPI)',
'SH.DYN.AIDS.ZS':'Prevalence of HIV, total (% of population ages 15-49)',
'AG.LND.FRST.K2':'Forest area (sq. km)',
'ER.GDP.FWTL.M3.KD':'Water productivity, total (constant 2010 US$ GDP per cubic meter of total freshwater withdrawal)',
#'SH.H2O.SAFE.ZS':'Improved water source (% of population with access)',
#'SH.STA.ACSN':'Improved sanitation facilities (% of population with access)',
'EG.USE.PCAP.KG.OE':'Energy use (kg of oil equivalent per capita)',
'EN.ATM.CO2E.PC':'CO2 emissions (metric tons per capita)',
'EG.USE.ELEC.KH.PC':'Electric power consumption (kWh per capita)',
'NY.GDP.MKTP.CD':'GDP (current US$)',
'NY.GDP.MKTP.KD.ZG':'GDP growth (annual %)',
'NY.GDP.DEFL.KD.ZG':'Inflation, GDP deflator (annual %)',
'NV.AGR.TOTL.ZS':'Agriculture, value added (% of GDP)',
'NV.IND.TOTL.ZS':'Industry, value added (% of GDP)',
#'NV.SRV.TETC.ZS':'Services, etc., value added (% of GDP)',
'NE.EXP.GNFS.ZS':'Exports of goods and services (% of GDP)',
'NE.IMP.GNFS.ZS':'Imports of goods and services (% of GDP)',
'NE.GDI.TOTL.ZS':'Gross capital formation (% of GDP)',
'GC.REV.XGRT.GD.ZS':'Revenue, excluding grants (% of GDP)',
#'GC.BAL.CASH.GD.ZS':'Cash surplus/deficit (% of GDP)',
'IC.REG.PROC':'Start-up procedures to register a business (number)',
'CM.MKT.LCAP.GD.ZS':'Market capitalization of listed domestic companies (% of GDP)',
'MS.MIL.XPND.GD.ZS':'Military expenditure (% of GDP)',
'IT.CEL.SETS.P2':'Mobile cellular subscriptions (per 100 people)',
#'IT.NET.USER.P2':'Internet users (per 100 people)',
#'IS.ROD.PAVE.ZS':'Roads, paved (% of total roads)',
'TX.VAL.TECH.MF.ZS':'High-technology exports (% of manufactured exports)',
'TG.VAL.TOTL.GD.ZS':'Merchandise trade (% of GDP)',
'TT.PRI.MRCH.XD.WD':'Net barter terms of trade index (2000 = 100)',
'DT.DOD.DECT.CD':'External debt stocks, total (DOD, current US$)',
'DT.TDS.DECT.GN.ZS':'Total debt service (% of GNI)',
'SM.POP.NETM':'Net migration',
'BM.TRF.PWKR.CD.DT':'Personal remittances, paid (current US$)',
'BX.KLT.DINV.CD.WD':'Foreign direct investment, net inflows (BoP, current US$)',
'DT.ODA.ODAT.PC.ZS':'Net ODA received per capita (current US$)',
'NY.GDP.PCAP.CD':'GDP per capita (current US$)',
'BN.KLT.DINV.CD':'Foreign direct investment, net (BoP, current US$)',
'FP.CPI.TOTL.ZG':'Inflation, consumer prices (annual %)',
'SI.POV.DDAY':'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
'SI.POV.LMIC':'Poverty headcount ratio at $3.20 a day (2011 PPP) (% of population)',
'SI.POV.UMIC':'Poverty headcount ratio at $5.50 a day (2011 PPP) (% of population)'   
}

# %%
countries = [
    'AFG',
'AGO',
'ALB',
'ARG',
'ARM',
'ASM',
'AZE',
'BDI',
'BEN',
'BFA',
'BGD',
'BGR',
'BIH',
'BLR',
'BLZ',
'BOL',
'BRA',
'BTN',
'BWA',
'CAF',
'CHN',
'CIV',
'CMR',
'COD',
'COG',
'COL',
'COM',
'CPV',
'CRI',
'CUB',
'DJI',
'DMA',
'DOM',
'DZA',
'ECU',
'EGY',
'ERI',
'ETH',
'FJI',
'FSM',
'GAB',
'GEO',
'GHA',
'GIN',
'GMB',
'GNB',
'GNQ',
'GRD',
'GTM',
'GUY',
'HND',
'HTI',
'IDN',
'IND',
'IRN',
'IRQ',
'JAM',
'JOR',
'KAZ',
'KEN',
'KGZ',
'KHM',
'KIR',
'LAO',
'LBN',
'LBR',
'LBY',
'LCA',
'LKA',
'LSO',
'MAR',
'MDA',
'MDG',
'MDV',
'MEX',
'MHL',
'MKD',
'MLI',
'MMR',
'MNE',
'MNG',
'MOZ',
'MRT',
'MUS',
'MWI',
'MYS',
'NAM',
'NER',
'NGA',
'NIC',
'NPL',
'NRU',
'PAK',
'PER',
'PHL',
'PNG',
'PRK',
'PRY',
'PSE',
'ROU',
'RUS',
'RWA',
'SDN',
'SEN',
'SLB',
'SLE',
'SLV',
'SOM',
'SRB',
'SSD',
'STP',
'SUR',
'SWZ',
'SYR',
'TCD',
'TGO',
'THA',
'TJK',
'TKM',
'TLS',
'TON',
'TUN',
'TUR',
'TUV',
'TZA',
'UGA',
'UKR',
'UZB',
'VCT',
'VEN',
'VNM',
'VUT',
'WSM',
'XKX',
'YEM',
'ZAF',
'ZMB',
'ZWE'
]

# %%
df = wb.get_dataframe({'EG.USE.PCAP.KG.OE':'Energy use (kg of oil equivalent per capita)'}, country='IND')
df.reset_index(inplace=True)
#df.dropna(inplace=True)
#print (df.corr())
df.head()
# Out:
#    date  Energy use (kg of oil equivalent per capita)
# 0  2019                                           nan
# 1  2018                                           nan
# 2  2017                                           nan
# 3  2016                                           nan
# 4  2015                                           nan

# %%
beg = pd.Timestamp(1990,1,1)
end = pd.Timestamp(2015,1,1)

# %%
a = wb.get_data(indicator = 'EG.USE.PCAP.KG.OE', country = 'IND', data_date=(beg,end))
b = wb.get_data(indicator = 'EG.USE.PCAP.KG.OE', country = 'USA', data_date=(beg,end))
c = [a,b]

# %%
ind_test = [
'SP.POP.TOTL',
'SP.POP.GROW']

# %%
sc = []
for i in ind_test:
    x = wb.get_data(indicator = i, country = 'all', data_date=(beg,end))
    sc.append(x)
    
sc
# Out:
# [[{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '396028278',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '387907748',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '379705719',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '371443547',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '363158703',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '354890042',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '346629220',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '338395961',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '330290716',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '322452754',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '314965793',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '307862843',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '301113849',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '294665185',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '288432163',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '282344154',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '276393837',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '270575803',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '264822188',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '259000953',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '253107289',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '245449409',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '239243261',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '232956352',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '228731685',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'value': '222653373',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '7222212',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '7173435',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '7123332',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '7072665',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '7022387',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6973206',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6925452',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6878978',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6833393',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6788123',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6742717',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6696953',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6650971',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6604965',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6559096',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6513485',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6468476',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6423827',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6378552',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6331280',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6281190',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6227335',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6170351',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6112815',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6058308',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'S3', 'value': 'Caribbean small states'},
#    'value': '6009251',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '103257751',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '103496179',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '103713726',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '103935318',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '104174038',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '104421447',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '104800475',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '105001883',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '105378748',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '105772481',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '106041911',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '106331716',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '106624167',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '106959751',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '107660041',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '108447824',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '109060951',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '109238340',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '109422013',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '109626194',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '109864246',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '110021594',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '110041924',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '110111454',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '110469467',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#    'value': '110743128',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '3122841922',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '3080325473',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '3037662926',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2994852889',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2951856336',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2908287643',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2864614907',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2820903724',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2777145806',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2733462527',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2689939785',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2646598382',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2603385880',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2560162782',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2516715617',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2472913805',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2428682278',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2384215228',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2339478706',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2294686411',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2250115643',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2205893669',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2161909784',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2117950211',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2073777602',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#    'value': '2029207305',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2282855831',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2267482299',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2252046977',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2236819053',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2221673110',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2206884624',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2192059415',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2177119142',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2161785573',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2146744075',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2131146832',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2115458616',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2099602439',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2083186112',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2065912076',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2047640119',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2028650274',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '2008705489',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1987315562',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1965146504',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1942431457',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1919359723',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1895897521',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1872480731',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1848222188',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#    'value': '1822193192',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '2038202511',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '2023609315',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '2008932012',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1994401378',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1980045666',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1965964309',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1952027348',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1938067140',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1924028068',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1909901290',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1895285323',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1880258797',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1865142700',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1849617640',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1833433229',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1816466142',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1798649990',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1779799008',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1759761226',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1738960485',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1717912312',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1696474639',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1674590518',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1652538259',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1629641399',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '4E',
#     'value': 'East Asia & Pacific (excluding high income)'},
#    'value': '1605197175',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '2012980531',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1998513398',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1983964453',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1969562739',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1955334267',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1941377349',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1927560609',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1913718210',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1899800530',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1885806859',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1871341375',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1856486252',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1841560579',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1826238744',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1810261141',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1793498351',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1775880231',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1757224494',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1737388752',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1716810429',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1696014016',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1674861279',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1653289954',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1631566815',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1608999005',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'T4',
#     'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#    'value': '1584871832',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '339533474',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '338466255',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '337302113',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '336159194',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '335419643',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '336151479',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '335360890',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '334274725',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '332645165',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '330922789',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '329380417',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '327682505',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '325885964',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '324125336',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '322547874',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '321310791',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '320258898',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '319433981',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '318761762',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '318003015',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '317181448',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '316366779',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '315449099',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '314162058',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '312708137',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'XC', 'value': 'Euro area'},
#    'value': '311262588',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '907498192',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '903129978',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '898766094',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '894486795',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '890862941',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '888627318',
#    'decimal': '0',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '885170595',
#    'decimal': '0',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '881531261',
#    'decimal': '0',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '878004122',
#    'decimal': '0',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '874862170',
#    'decimal': '0',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '872163396',
#    'decimal': '0',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '869516666',
#    'decimal': '0',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '866925884',
#    'decimal': '0',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '864648977',
#    'decimal': '0',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '863083216',
#    'decimal': '0',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '861993393',
#    'decimal': '0',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '861035457',
#    'decimal': '0',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '860015493',
#    'decimal': '0',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '858882872',
#    'decimal': '0',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '857577538',
#    'decimal': '0',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '856212881',
#    'decimal': '0',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '854685450',
#    'decimal': '0',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '852712876',
#    'decimal': '0',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '849757442',
#    'decimal': '0',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '846356322',
#    'decimal': '0',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#    'value': '842570541',
#    'decimal': '0',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'value': '410844329',
#    'decimal': '0',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'value': '408278056',
#    'decimal': '0',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'value': '405778196',
#    'decimal': '0',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'value': '403265869',
#    'decimal': '0',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'value': '401012737',
#    'decimal': '0',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': '7E',
# ...
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.86597473651531',
#    'decimal': '1',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.78832773403472',
#    'decimal': '1',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.79352182158468',
#    'decimal': '1',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.75465474120389',
#    'decimal': '1',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.72304600829793',
#    'decimal': '1',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.75894444281772',
#    'decimal': '1',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.75977660092772',
#    'decimal': '1',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '1.92398255041266',
#    'decimal': '1',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '2.19756099254084',
#    'decimal': '1',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S4', 'value': 'Other small states'},
#    'value': '2.34407361820979',
#    'decimal': '1',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.31329952312467',
#    'decimal': '1',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.26453496601413',
#    'decimal': '1',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.20742731105106',
#    'decimal': '1',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.2003757698062',
#    'decimal': '1',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.23182505997916',
#    'decimal': '1',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.29007086813698',
#    'decimal': '1',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.3376878487328',
#    'decimal': '1',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.35249151580521',
#    'decimal': '1',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.32302394866124',
#    'decimal': '1',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.25753213114849',
#    'decimal': '1',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.18045111315281',
#    'decimal': '1',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.1206965420451',
#    'decimal': '1',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.08510237388577',
#    'decimal': '1',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.08753053672066',
#    'decimal': '1',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.12328862056243',
#    'decimal': '1',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.15773673293498',
#    'decimal': '1',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.19224780727491',
#    'decimal': '1',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.25121207704058',
#    'decimal': '1',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.33963885948189',
#    'decimal': '1',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.45089328134493',
#    'decimal': '1',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.59192733587301',
#    'decimal': '1',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.72345296613024',
#    'decimal': '1',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.78186223136281',
#    'decimal': '1',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.72457366417291',
#    'decimal': '1',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.58794144240917',
#    'decimal': '1',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'S2', 'value': 'Pacific island small states'},
#    'value': '1.39950578923209',
#    'decimal': '1',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.451342379262883',
#    'decimal': '1',
#    'date': '2015'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.457000175459555',
#    'decimal': '1',
#    'date': '2014'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.439528155928798',
#    'decimal': '1',
#    'date': '2013'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.420478622595738',
#    'decimal': '1',
#    'date': '2012'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.27623288710717',
#    'decimal': '1',
#    'date': '2011'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.466510780973508',
#    'decimal': '1',
#    'date': '2010'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.515242958861492',
#    'decimal': '1',
#    'date': '2009'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.606082281976512',
#    'decimal': '1',
#    'date': '2008'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.563385384782094',
#    'decimal': '1',
#    'date': '2007'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.543607718668241',
#    'decimal': '1',
#    'date': '2006'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.508275607256792',
#    'decimal': '1',
#    'date': '2005'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.517849991787628',
#    'decimal': '1',
#    'date': '2004'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.499726986752776',
#    'decimal': '1',
#    'date': '2003'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.501105170458558',
#    'decimal': '1',
#    'date': '2002'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.482017883841209',
#    'decimal': '1',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.500617241591499',
#    'decimal': '1',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.477997073330272',
#    'decimal': '1',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.486285610610921',
#    'decimal': '1',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.509352299441161',
#    'decimal': '1',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.535128352343989',
#    'decimal': '1',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.547574702777439',
#    'decimal': '1',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.586836900294401',
#    'decimal': '1',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.654527764330197',
#    'decimal': '1',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.692923212699341',
#    'decimal': '1',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.697061259667493',
#    'decimal': '1',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#    'value': '0.637158783786873',
#    'decimal': '1',
#    'date': '1990'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.8522320436345',
#    'decimal': '1',
#    'date': '2001'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.77852750395087',
#    'decimal': '1',
#    'date': '2000'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.7138106520524',
#    'decimal': '1',
#    'date': '1999'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.68692173162886',
#    'decimal': '1',
#    'date': '1998'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.72007870553853',
#    'decimal': '1',
#    'date': '1997'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.79974611594606',
#    'decimal': '1',
#    'date': '1996'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.90595150806081',
#    'decimal': '1',
#    'date': '1995'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '3.000016968175',
#    'decimal': '1',
#    'date': '1994'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '3.05448097333337',
#    'decimal': '1',
#    'date': '1993'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '3.04148368921202',
#    'decimal': '1',
#    'date': '1992'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.97335663533265',
#    'decimal': '1',
#    'date': '1991'},
#   {'indicator': {'id': 'SP.POP.GROW', 'value': 'Population growth (annual %)'},
#    'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#    'value': '2.88565906730163',
#    'decimal': '1',
#    'date': '1990'},
#   ...]]

# %%
test = pd.DataFrame (sc[0])
test = pd.concat([test, pd.DataFrame (sc[1])])

# %% [raw]
# ind_all = [
#     'SL.FAM.WORK.FE.ZS',
# 'SL.FAM.WORK.MA.ZS',
# 'SL.FAM.WORK.ZS',
# 'SL.EMP.MPYR.FE.ZS',
# 'SL.EMP.MPYR.MA.ZS',
# 'SL.EMP.MPYR.ZS',
# 'SL.AGR.EMPL.ZS',
# 'SL.AGR.EMPL.FE.ZS',
# 'SL.AGR.EMPL.MA.ZS',
# 'SL.IND.EMPL.ZS',
# 'SL.IND.EMPL.FE.ZS',
# 'SL.IND.EMPL.MA.ZS',
# 'SL.SRV.EMPL.ZS',
# 'SL.SRV.EMPL.FE.ZS',
# 'SL.SRV.EMPL.MA.ZS',
# 'SL.EMP.TOTL.SP.FE.ZS',
# 'SL.EMP.TOTL.SP.MA.ZS',
# 'SL.EMP.TOTL.SP.ZS',
# 'SL.EMP.1524.SP.FE.ZS',
# 'SL.EMP.1524.SP.MA.ZS',
# 'SL.EMP.1524.SP.ZS',
# 'SL.GDP.PCAP.EM.KD',
# 'SL.TLF.ACTI.1524.FE.ZS',
# 'SL.TLF.ACTI.1524.MA.ZS',
# 'SL.TLF.ACTI.1524.ZS',
# 'SL.TLF.CACT.FE.ZS',
# 'SL.TLF.ACTI.FE.ZS',
# 'SL.TLF.CACT.MA.ZS',
# 'SL.TLF.ACTI.MA.ZS',
# 'SL.TLF.CACT.ZS',
# 'SL.TLF.ACTI.ZS',
# 'SL.TLF.TOTL.FE.ZS',
# 'SL.TLF.TOTL.IN',
# 'SE.SEC.AGES',
# 'SE.PRM.DURS',
# 'SE.PRM.AGES',
# 'SL.TLF.CACT.FM.ZS',
# 'SE.SEC.DURS',
# 'SL.EMP.SELF.FE.ZS',
# 'SL.EMP.SELF.MA.ZS',
# 'SL.EMP.SELF.ZS',
# 'SL.UEM.TOTL.FE.ZS',
# 'SL.UEM.TOTL.MA.ZS',
# 'SL.UEM.TOTL.ZS',
# 'SL.UEM.1524.FE.ZS',
# 'SL.UEM.1524.MA.ZS',
# 'SL.UEM.1524.ZS',
# 'SL.EMP.VULN.FE.ZS',
# 'SL.EMP.VULN.MA.ZS',
# 'SL.EMP.VULN.ZS',
# 'SL.EMP.WORK.FE.ZS',
# 'SL.EMP.WORK.MA.ZS',
# 'SL.EMP.WORK.ZS',
# 'SP.POP.DPND',
# 'SP.POP.DPND.OL',
# 'SP.POP.DPND.YG',
# 'TX.VAL.AGRI.ZS.UN',
# 'TM.VAL.AGRI.ZS.UN',
# 'NV.AGR.TOTL.ZS',
# 'NV.AGR.TOTL.KD.ZG',
# 'NV.AGR.TOTL.KD',
# 'NV.AGR.TOTL.KN',
# 'NV.AGR.TOTL.CN',
# 'NV.AGR.TOTL.CD',
# 'NV.AGR.EMPL.KD',
# 'IS.AIR.GOOD.MT.K1',
# 'IS.AIR.PSGR',
# 'IS.AIR.DPRT',
# 'MS.MIL.MPRT.KD',
# 'VC.BTL.DETH',
# 'FM.LBL.BMNY.GD.ZS',
# 'FM.LBL.BMNY.CN',
# 'FM.LBL.BMNY.ZG',
# 'FM.LBL.BMNY.IR.ZS',
# 'NE.GDI.STKB.KN',
# 'NE.GDI.STKB.CN',
# 'NE.GDI.STKB.CD',
# 'BM.GSR.ROYL.CD',
# 'BX.GSR.ROYL.CD',
# 'FM.AST.CGOV.ZG.M3',
# 'FS.AST.CGOV.GD.ZS',
# 'FM.AST.PRVT.ZG.M3',
# 'DT.NFL.PCBO.CD',
# 'TX.VAL.SERV.CD.WT',
# 'TM.VAL.SERV.CD.WT',
# 'BX.GSR.CMCP.ZS',
# 'BM.GSR.CMCP.ZS',
# 'TX.VAL.OTHR.ZS.WT',
# 'TM.VAL.OTHR.ZS.WT',
# 'FP.CPI.TOTL',
# 'BN.CAB.XOKA.GD.ZS',
# 'BN.CAB.XOKA.CD',
# 'DT.TDS.DPPF.XP.ZS',
# 'DT.TDS.DPPG.CD',
# 'DT.TDS.DECT.CD',
# 'PA.NUS.ATLS',
# 'NY.GDP.DISC.KN',
# 'NY.GDP.DISC.CN',
# 'FS.AST.PRVT.GD.ZS',
# 'FD.AST.PRVT.GD.ZS',
# 'TX.UVI.MRCH.XD.WD',
# 'TX.VAL.MRCH.XD.WD',
# 'TX.QTY.MRCH.XD.WD',
# 'NY.EXP.CAPM.KN',
# 'NE.EXP.GNFS.ZS',
# 'NE.EXP.GNFS.KD.ZG',
# 'BX.GSR.GNFS.CD',
# 'NE.EXP.GNFS.KD',
# 'NE.EXP.GNFS.KN',
# 'NE.EXP.GNFS.CN',
# 'NE.EXP.GNFS.CD',
# 'BX.GSR.TOTL.CD',
# 'NE.RSB.GNFS.ZS',
# 'NE.RSB.GNFS.KN',
# 'NE.RSB.GNFS.CN',
# 'NE.RSB.GNFS.CD',
# 'DT.DOD.DECT.GN.ZS',
# 'DT.DOD.DLXF.CD',
# 'DT.DOD.DPNG.CD',
# 'DT.DOD.DPPG.CD',
# 'DT.DOD.DSTC.CD',
# 'DT.DOD.DECT.CD',
# 'NE.CON.TOTL.ZS',
# 'NE.CON.TOTL.KD.ZG',
# 'NE.CON.TOTL.KD',
# 'NE.CON.TOTL.KN',
# 'NE.CON.TOTL.CN',
# 'NE.CON.TOTL.CD',
# 'IT.MLT.MAIN',
# 'IT.MLT.MAIN.P2',
# 'TX.VAL.FOOD.ZS.UN',
# 'TM.VAL.FOOD.ZS.UN',
# 'BN.KLT.DINV.CD',
# 'BX.KLT.DINV.WD.GD.ZS',
# 'BX.KLT.DINV.CD.WD',
# 'BM.KLT.DINV.WD.GD.ZS',
# 'BM.KLT.DINV.CD.WD',
# 'TX.VAL.FUEL.ZS.UN',
# 'TM.VAL.FUEL.ZS.UN',
# 'NY.GDP.MKTP.KD',
# 'NY.GDP.MKTP.KN',
# 'NY.GDP.MKTP.CN',
# 'NY.GDP.MKTP.CD',
# 'NY.GDP.DEFL.ZS',
# 'NY.GDP.DEFL.ZS.AD',
# 'NY.GDP.MKTP.KD.ZG',
# 'NY.GDP.PCAP.KD',
# 'NY.GDP.PCAP.KN',
# 'NY.GDP.PCAP.CN',
# 'NY.GDP.PCAP.CD',
# 'NY.GDP.PCAP.KD.ZG',
# 'NY.GDP.PCAP.PP.KD',
# 'NY.GDP.PCAP.PP.CD',
# 'NY.GDP.MKTP.PP.KD',
# 'NY.GDP.MKTP.PP.CD',
# 'NY.GDP.MKTP.CN.AD',
# 'NE.CON.GOVT.ZS',
# 'NE.CON.GOVT.KD.ZG',
# 'NE.CON.GOVT.KD',
# 'NE.CON.GOVT.KN',
# 'NE.CON.GOVT.CN',
# 'NE.CON.GOVT.CD',
# 'NY.GNP.MKTP.KD',
# 'NY.GNP.MKTP.KN',
# 'NY.GNP.MKTP.CN',
# 'NY.GNP.MKTP.CD',
# 'NY.GNP.MKTP.KD.ZG',
# 'NY.GNP.PCAP.KD',
# 'NY.GNP.PCAP.KN',
# 'NY.GNP.PCAP.CN',
# 'NY.GNP.PCAP.KD.ZG',
# 'NY.GNP.PCAP.CD',
# 'NY.GNP.PCAP.PP.KD',
# 'NY.GNP.PCAP.PP.CD',
# 'NY.GNP.ATLS.CD',
# 'NY.GNP.MKTP.PP.KD',
# 'NY.GNP.MKTP.PP.CD',
# 'BX.GSR.MRCH.CD',
# 'BM.GSR.MRCH.CD',
# 'NE.GDI.TOTL.ZS',
# 'NE.GDI.TOTL.KD.ZG',
# 'NE.GDI.TOTL.KD',
# 'NE.GDI.TOTL.KN',
# 'NE.GDI.TOTL.CN',
# 'NE.GDI.TOTL.CD',
# 'NY.GDY.TOTL.KN',
# 'NY.GDS.TOTL.ZS',
# 'NY.GDS.TOTL.CN',
# 'NY.GDS.TOTL.CD',
# 'NE.GDI.FTOT.ZS',
# 'NE.GDI.FTOT.KD.ZG',
# 'NE.GDI.FTOT.KD',
# 'NE.GDI.FTOT.KN',
# 'NE.GDI.FTOT.CN',
# 'NE.GDI.FTOT.CD',
# 'NE.DAB.TOTL.ZS',
# 'NE.DAB.TOTL.KD',
# 'NE.DAB.TOTL.KN',
# 'NE.DAB.TOTL.CN',
# 'NE.DAB.TOTL.CD',
# 'NE.DAB.DEFL.ZS',
# 'NY.GNS.ICTR.ZS',
# 'NY.GNS.ICTR.GN.ZS',
# 'NY.GNS.ICTR.CN',
# 'NY.GNS.ICTR.CD',
# 'NY.GDP.FCST.KD',
# 'NY.GDP.FCST.KN',
# 'NY.GDP.FCST.CN',
# 'NY.GDP.FCST.CD',
# 'NE.CON.PRVT.ZS',
# 'NE.CON.PRVT.KD.ZG',
# 'NE.CON.PRVT.KD',
# 'NE.CON.PRVT.KN',
# 'NE.CON.PRVT.CN',
# 'NE.CON.PRVT.CD',
# 'NE.CON.PRVT.PC.KD',
# 'NE.CON.PRVT.PC.KD.ZG',
# 'NE.CON.PRVT.PP.KD',
# 'NE.CON.PRVT.PP.CD',
# 'DT.DOD.MWBG.CD',
# 'DT.NFL.NIFC.CD',
# 'DT.TDS.DIMF.CD',
# 'SH.IMM.IDPT',
# 'SH.IMM.MEAS',
# 'TM.UVI.MRCH.XD.WD',
# 'TM.VAL.MRCH.XD.WD',
# 'TM.QTY.MRCH.XD.WD',
# 'NE.IMP.GNFS.ZS',
# 'NE.IMP.GNFS.KD.ZG',
# 'BM.GSR.GNFS.CD',
# 'NE.IMP.GNFS.KD',
# 'NE.IMP.GNFS.KN',
# 'NE.IMP.GNFS.CN',
# 'NE.IMP.GNFS.CD',
# 'BM.GSR.TOTL.CD',
# 'NV.IND.TOTL.ZS',
# 'NV.IND.TOTL.KD.ZG',
# 'NV.IND.TOTL.KD',
# 'NV.IND.TOTL.KN',
# 'NV.IND.TOTL.CN',
# 'NV.IND.TOTL.CD',
# 'NV.IND.EMPL.KD',
# 'FP.CPI.TOTL.ZG',
# 'NY.GDP.DEFL.KD.ZG',
# 'NY.GDP.DEFL.KD.ZG.AD',
# 'TM.VAL.INSF.ZS.WT',
# 'BX.GSR.INSF.ZS',
# 'BM.GSR.INSF.ZS',
# 'IE.PPI.ENGY.CD',
# 'IE.PPI.TRAN.CD',
# 'AG.LND.TOTL.K2',
# 'FR.INR.LEND',
# 'CM.MKT.LDOM.NO',
# 'TX.VAL.MANF.ZS.UN',
# 'TM.VAL.MANF.ZS.UN',
# 'NV.IND.MANF.ZS',
# 'NV.IND.MANF.KD.ZG',
# 'NV.IND.MANF.KD',
# 'NV.IND.MANF.KN',
# 'NV.IND.MANF.CN',
# 'NV.IND.MANF.CD',
# 'TX.VAL.MRCH.CD.WT',
# 'TM.VAL.MRCH.CD.WT',
# 'TG.VAL.TOTL.GD.ZS',
# 'MS.MIL.XPND.GD.ZS',
# 'MS.MIL.XPND.ZS',
# 'MS.MIL.XPND.CN',
# 'MS.MIL.XPND.CD',
# 'IT.CEL.SETS',
# 'IT.CEL.SETS.P2',
# 'SP.DYN.IMRT.IN',
# 'SH.DYN.NMRT',
# 'SH.DYN.MORT',
# 'DT.TDS.MLAT.PG.ZS',
# 'DT.TDS.MLAT.CD',
# 'TT.PRI.MRCH.XD.WD',
# 'BN.KAC.EOMS.CD',
# 'BN.FIN.TOTL.CD',
# 'DT.NFL.BLAT.CD',
# 'DT.NFL.MIBR.CD',
# 'DT.NFL.MIDA.CD',
# 'DT.NFL.IMFC.CD',
# 'DT.NFL.IMFN.CD',
# 'DT.NFL.MLAT.CD',
# 'DT.NFL.MOTH.CD',
# 'DT.NFL.RDBC.CD',
# 'DT.NFL.RDBN.CD',
# 'DT.NFL.DPNG.CD',
# 'BN.GSR.FCTY.CD',
# 'NY.GSR.NFCY.CN',
# 'NY.GSR.NFCY.CD',
# 'BN.TRF.CURR.CD',
# 'NY.TRF.NCTR.CN',
# 'NY.TRF.NCTR.CD',
# 'BN.GSR.MRCH.CD',
# 'BN.GSR.GNFS.CD',
# 'SH.VAC.TTNS.ZS',
# 'SH.DTH.IMRT',
# 'SH.DTH.NMRT',
# 'SH.DTH.MORT',
# 'PA.NUS.FCRF',
# 'TX.VAL.MMTL.ZS.UN',
# 'TM.VAL.MMTL.ZS.UN',
# 'BM.TRF.PWKR.CD.DT',
# 'BX.TRF.PWKR.DT.GD.ZS',
# 'BX.TRF.PWKR.CD.DT',
# 'BX.TRF.PWKR.CD',
# 'DT.NFL.PNGB.CD',
# 'DT.NFL.PNGC.CD',
# 'SP.POP.0004.FE.5Y',
# 'SP.POP.0004.MA.5Y',
# 'SP.POP.0014.TO.ZS',
# 'SP.POP.0014.FE.IN',
# 'SP.POP.0014.FE.ZS',
# 'SP.POP.0014.MA.IN',
# 'SP.POP.0014.MA.ZS',
# 'SP.POP.0014.TO',
# 'SP.POP.0509.FE.5Y',
# 'SP.POP.0509.MA.5Y',
# 'SP.POP.1014.FE.5Y',
# 'SP.POP.1014.MA.5Y',
# 'SP.POP.1519.FE.5Y',
# 'SP.POP.1519.MA.5Y',
# 'SP.POP.1564.TO.ZS',
# 'SP.POP.1564.FE.IN',
# 'SP.POP.1564.FE.ZS',
# 'SP.POP.1564.MA.IN',
# 'SP.POP.1564.MA.ZS',
# 'SP.POP.1564.TO',
# 'SP.POP.2024.FE.5Y',
# 'SP.POP.2024.MA.5Y',
# 'SP.POP.2529.FE.5Y',
# 'SP.POP.2529.MA.5Y',
# 'SP.POP.3034.FE.5Y',
# 'SP.POP.3034.MA.5Y',
# 'SP.POP.3539.FE.5Y',
# 'SP.POP.3539.MA.5Y',
# 'SP.POP.4044.FE.5Y',
# 'SP.POP.4044.MA.5Y',
# 'SP.POP.4549.FE.5Y',
# 'SP.POP.4549.MA.5Y',
# 'SP.POP.5054.FE.5Y',
# 'SP.POP.5054.MA.5Y',
# 'SP.POP.5559.FE.5Y',
# 'SP.POP.5559.MA.5Y',
# 'SP.POP.6064.FE.5Y',
# 'SP.POP.6064.MA.5Y',
# 'SP.POP.65UP.TO.ZS',
# 'SP.POP.65UP.FE.IN',
# 'SP.POP.65UP.FE.ZS',
# 'SP.POP.65UP.MA.IN',
# 'SP.POP.65UP.MA.ZS',
# 'SP.POP.65UP.TO',
# 'SP.POP.6569.FE.5Y',
# 'SP.POP.6569.MA.5Y',
# 'SP.POP.7074.FE.5Y',
# 'SP.POP.7074.MA.5Y',
# 'SP.POP.7579.FE.5Y',
# 'SP.POP.7579.MA.5Y',
# 'SP.POP.80UP.FE.5Y',
# 'SP.POP.80UP.MA.5Y',
# 'EN.POP.DNST',
# 'SP.POP.GROW',
# 'EN.URB.LCTY',
# 'EN.URB.LCTY.UR.ZS',
# 'EN.URB.MCTY',
# 'EN.URB.MCTY.TL.ZS',
# 'SP.POP.TOTL.FE.IN',
# 'SP.POP.TOTL.FE.ZS',
# 'SP.POP.TOTL.MA.IN',
# 'SP.POP.TOTL.MA.ZS',
# 'SP.POP.TOTL',
# 'BX.PEF.TOTL.CD.WD',
# 'DT.NFL.BOND.CD',
# 'BN.KLT.PTXL.CD',
# 'DT.NFL.PBND.CD',
# 'DT.NFL.PCBK.CD',
# 'DT.DOD.MIBR.CD',
# 'DT.DOD.MIDA.CD',
# 'DT.NFL.OFFT.CD',
# 'DT.NFL.PROP.CD',
# 'DT.NFL.PRVT.CD',
# 'PA.NUS.PPP',
# 'PA.NUS.PRVT.PP',
# 'SE.PRE.DURS',
# 'PA.NUS.PPPC.RF',
# 'BM.GSR.FCTY.CD',
# 'BX.GSR.FCTY.CD',
# 'SG.GEN.PARL.ZS',
# 'DT.TDS.DPPG.XP.ZS',
# 'DT.TDS.DPPG.GN.ZS',
# 'IE.PPN.ENGY.CD',
# 'IE.PPN.TRAN.CD',
# 'FR.INR.RINR',
# 'SM.POP.REFG',
# 'SM.POP.REFG.OR',
# 'BN.RES.INCL.CD',
# 'SP.RUR.TOTL',
# 'SP.RUR.TOTL.ZS',
# 'SP.RUR.TOTL.ZG',
# 'CM.MKT.INDX.ZG',
# 'SE.TER.ENRR',
# 'BX.TRF.CURR.CD',
# 'BM.TRF.PRVT.CD',
# 'BX.GSR.NFSV.CD',
# 'BM.GSR.NFSV.CD',
# 'NV.SRV.TOTL.ZS',
# 'NV.SRV.TOTL.KD.ZG',
# 'NV.SRV.TOTL.KD',
# 'NV.SRV.TOTL.KN',
# 'NV.SRV.TOTL.CN',
# 'NV.SRV.EMPL.KD',
# 'DT.DOD.DSTC.XP.ZS',
# 'DT.DOD.DSTC.ZS',
# 'DT.DOD.DSTC.IR.ZS',
# 'AG.SRF.TOTL.K2',
# 'NY.TAX.NIND.KN',
# 'NY.TAX.NIND.CN',
# 'NY.TAX.NIND.CD',
# 'NY.TTF.GNFS.KN',
# 'DT.TDS.DECT.EX.ZS',
# 'DT.TDS.DECT.GN.ZS',
# 'FI.RES.TOTL.DT.ZS',
# 'FI.RES.TOTL.CD',
# 'FI.RES.TOTL.MO',
# 'FI.RES.XGLD.CD',
# 'NE.TRD.GNFS.ZS',
# 'BG.GSR.NFSV.GD.ZS',
# 'TX.VAL.TRAN.ZS.WT',
# 'TM.VAL.TRAN.ZS.WT',
# 'BX.GSR.TRAN.ZS',
# 'BM.GSR.TRAN.ZS',
# 'TX.VAL.TRVL.ZS.WT',
# 'TM.VAL.TRVL.ZS.WT',
# 'BX.GSR.TRVL.ZS',
# 'BM.GSR.TRVL.ZS',
# 'SP.URB.TOTL',
# 'SP.URB.TOTL.IN.ZS',
# 'SP.URB.GROW',
# 'DT.DOD.DIMF.CD',
# 'FP.WPI.TOTL',
# 'EG.ELC.ACCS.ZS',
# 'EG.ELC.ACCS.RU.ZS',
# 'EG.ELC.ACCS.UR.ZS',
# 'NY.ADJ.NNTY.KD.ZG',
# 'NY.ADJ.NNTY.KD',
# 'NY.ADJ.NNTY.CD',
# 'NY.ADJ.NNTY.PC.KD.ZG',
# 'NY.ADJ.NNTY.PC.KD',
# 'NY.ADJ.NNTY.PC.CD',
# 'NY.ADJ.SVNX.GN.ZS',
# 'NY.ADJ.SVNX.CD',
# 'NY.ADJ.SVNG.GN.ZS',
# 'NY.ADJ.SVNG.CD',
# 'NY.ADJ.DCO2.GN.ZS',
# 'NY.ADJ.DCO2.CD',
# 'NY.ADJ.DKAP.GN.ZS',
# 'NY.ADJ.DKAP.CD',
# 'NY.ADJ.AEDU.GN.ZS',
# 'NY.ADJ.AEDU.CD',
# 'NY.ADJ.DNGY.GN.ZS',
# 'NY.ADJ.DNGY.CD',
# 'NY.ADJ.ICTR.GN.ZS',
# 'NY.ADJ.DMIN.GN.ZS',
# 'NY.ADJ.DMIN.CD',
# 'NY.ADJ.DRES.GN.ZS',
# 'NY.ADJ.DFOR.GN.ZS',
# 'NY.ADJ.DFOR.CD',
# 'NY.ADJ.NNAT.GN.ZS',
# 'NY.ADJ.NNAT.CD',
# 'NY.ADJ.DPEM.GN.ZS',
# 'NY.ADJ.DPEM.CD',
# 'SP.ADO.TFRT',
# 'MS.MIL.TOTL.TF.ZS',
# 'MS.MIL.TOTL.P1',
# 'MS.MIL.XPRT.KD',
# 'SP.DYN.CBRT.IN',
# 'AG.PRD.CREL.MT',
# 'AG.YLD.CREL.KG',
# 'NY.GDP.COAL.RT.ZS',
# 'GC.XPN.COMP.ZS',
# 'GC.XPN.COMP.CN',
# 'IS.SHP.GOOD.TU',
# 'GC.TAX.IMPT.ZS',
# 'GC.TAX.IMPT.CN',
# 'SP.DYN.CDRT.IN',
# 'FS.AST.DOMS.GD.ZS',
# 'GC.XPN.TOTL.GD.ZS',
# 'GC.XPN.TOTL.CN',
# 'SP.DYN.TFRT.IN',
# 'IT.NET.BBND',
# 'IT.NET.BBND.P2',
# 'NY.GDP.FRST.RT.ZS',
# 'GC.XPN.GSRV.ZS',
# 'GC.XPN.GSRV.CN',
# 'GC.REV.GOTR.ZS',
# 'GC.REV.GOTR.CN',
# 'BX.GRT.EXTA.CD.WD',
# 'NE.GDI.FPRV.ZS',
# 'NE.GDI.FPRV.CN',
# 'TX.VAL.ICTG.ZS.UN',
# 'TM.VAL.ICTG.ZS.UN',
# 'BX.GSR.CCIS.ZS',
# 'BX.GSR.CCIS.CD',
# 'SH.TBS.INCD',
# 'IT.NET.USER.ZS',
# 'IP.IDS.NRCT',
# 'IP.IDS.RSCT',
# 'TX.VAL.INSF.ZS.WT',
# 'GC.XPN.INTP.ZS',
# 'GC.XPN.INTP.RV.ZS',
# 'GC.XPN.INTP.CN',
# 'ST.INT.XPND.MP.ZS',
# 'ST.INT.XPND.CD',
# 'ST.INT.TVLX.CD',
# 'ST.INT.ARVL',
# 'ST.INT.DPRT',
# 'ST.INT.RCPT.XP.ZS',
# 'ST.INT.RCPT.CD',
# 'ST.INT.TVLR.CD',
# 'AG.LND.CREL.HA',
# 'SP.DYN.LE00.FE.IN',
# 'SP.DYN.LE00.MA.IN',
# 'SP.DYN.LE00.IN',
# 'SH.MMR.RISK.ZS',
# 'SH.MMR.RISK',
# 'SH.STA.MMRT',
# 'TX.MNF.TECH.ZS.UN',
# 'NV.MNF.TECH.ZS.UN',
# 'TX.VAL.MRCH.WL.CD',
# 'TX.VAL.MRCH.RS.ZS',
# 'TX.VAL.MRCH.AL.ZS',
# 'TX.VAL.MRCH.HI.ZS',
# 'TX.VAL.MRCH.R1.ZS',
# 'TX.VAL.MRCH.R2.ZS',
# 'TX.VAL.MRCH.R3.ZS',
# 'TX.VAL.MRCH.R4.ZS',
# 'TX.VAL.MRCH.R5.ZS',
# 'TX.VAL.MRCH.R6.ZS',
# 'TX.VAL.MRCH.OR.ZS',
# 'TX.VAL.MRCH.WR.ZS',
# 'TM.VAL.MRCH.WL.CD',
# 'TM.VAL.MRCH.RS.ZS',
# 'TM.VAL.MRCH.AL.ZS',
# 'TM.VAL.MRCH.HI.ZS',
# 'TM.VAL.MRCH.R1.ZS',
# 'TM.VAL.MRCH.R2.ZS',
# 'TM.VAL.MRCH.R3.ZS',
# 'TM.VAL.MRCH.R4.ZS',
# 'TM.VAL.MRCH.R5.ZS',
# 'TM.VAL.MRCH.R6.ZS',
# 'TM.VAL.MRCH.OR.ZS',
# 'TM.VAL.MRCH.WR.ZS',
# 'NY.GDP.MINR.RT.ZS',
# 'SP.DYN.AMRT.FE',
# 'SP.DYN.AMRT.MA',
# 'NY.GDP.NGAS.RT.ZS',
# 'GC.AST.TOTL.GD.ZS',
# 'GC.AST.TOTL.CN',
# 'DC.DAC.AUSL.CD',
# 'DC.DAC.AUTL.CD',
# 'DC.DAC.BELL.CD',
# 'DC.DAC.CANL.CD',
# 'DC.DAC.DNKL.CD',
# 'DC.DAC.CECL.CD',
# 'DC.DAC.FINL.CD',
# 'DC.DAC.FRAL.CD',
# 'DC.DAC.DEUL.CD',
# 'DC.DAC.GRCL.CD',
# 'DC.DAC.IRLL.CD',
# 'DC.DAC.ITAL.CD',
# 'DC.DAC.JPNL.CD',
# 'DC.DAC.KORL.CD',
# 'DC.DAC.LUXL.CD',
# 'DC.DAC.NLDL.CD',
# 'DC.DAC.NZLL.CD',
# 'DC.DAC.NORL.CD',
# 'DC.DAC.ESPL.CD',
# 'DC.DAC.SWEL.CD',
# 'DC.DAC.CHEL.CD',
# 'DC.DAC.TOTL.CD',
# 'DC.DAC.GBRL.CD',
# 'DC.DAC.USAL.CD',
# 'FM.AST.DOMS.CN',
# 'GC.LBL.TOTL.GD.ZS',
# 'GC.LBL.TOTL.CN',
# 'GC.NLD.TOTL.GD.ZS',
# 'GC.NLD.TOTL.CN',
# 'DT.ODA.ODAT.XP.ZS',
# 'DT.ODA.ODAT.GN.ZS',
# 'DT.ODA.ODAT.GI.ZS',
# 'DT.ODA.ODAT.MP.ZS',
# 'DT.ODA.ODAT.PC.ZS',
# 'DT.ODA.ALLD.KD',
# 'DT.ODA.ALLD.CD',
# 'DT.ODA.ODAT.KD',
# 'DT.ODA.ODAT.CD',
# 'DT.NFL.IFAD.CD',
# 'DT.NFL.UNDP.CD',
# 'DT.NFL.UNFP.CD',
# 'DT.NFL.UNCF.CD',
# 'SH.MMR.DTHS',
# 'NY.GDP.PETR.RT.ZS',
# 'GC.TAX.OTHR.RV.ZS',
# 'GC.TAX.OTHR.CN',
# 'IP.PAT.NRES',
# 'IP.PAT.RESD',
# 'SH.STA.ODFC.ZS',
# 'SH.STA.ODFC.RU.ZS',
# 'SH.STA.ODFC.UR.ZS',
# 'SH.H2O.BASW.ZS',
# 'SH.H2O.BASW.RU.ZS',
# 'SH.H2O.BASW.UR.ZS',
# 'SH.STA.BASS.ZS',
# 'SH.STA.BASS.RU.ZS',
# 'SH.STA.BASS.UR.ZS',
# 'SH.H2O.SMDW.RU.ZS',
# 'SH.STA.SMSS.RU.ZS',
# 'SN.ITK.DEFC.ZS',
# 'IS.RRS.TOTL.KM',
# 'IS.RRS.GOOD.MT.K6',
# 'IS.RRS.PASG.KM',
# 'GC.REV.XGRT.GD.ZS',
# 'GC.REV.XGRT.CN',
# 'SE.SEC.ENRR',
# 'SE.ENR.SECO.FM.ZS',
# 'SE.SEC.ENRR.FE',
# 'SE.SEC.ENRR.MA',
# 'SE.SEC.ENRL',
# 'SE.SEC.ENRL.FE.ZS',
# 'NV.SRV.TOTL.CD',
# 'GC.REV.SOCL.ZS',
# 'GC.REV.SOCL.CN',
# 'SP.DYN.TO65.FE.ZS',
# 'SP.DYN.TO65.MA.ZS',
# 'GC.TAX.TOTL.GD.ZS',
# 'GC.TAX.TOTL.CN',
# 'GC.TAX.GSRV.RV.ZS',
# 'GC.TAX.GSRV.VA.ZS',
# 'GC.TAX.GSRV.CN',
# 'GC.TAX.YPKG.RV.ZS',
# 'GC.TAX.YPKG.ZS',
# 'GC.TAX.YPKG.CN',
# 'GC.TAX.INTT.RV.ZS',
# 'GC.TAX.INTT.CN',
# 'BX.GRT.TECH.CD.WD',
# 'NY.GDP.TOTL.RT.ZS',
# 'IP.TMK.NRES',
# 'IP.TMK.RESD',
# 'IP.TMK.TOTL',
# 'SH.TBS.DTEC.ZS',
# 'EG.CFT.ACCS.ZS',
# 'AG.LND.AGRI.ZS',
# 'AG.LND.AGRI.K2',
# 'ER.FSH.AQUA.MT',
# 'AG.LND.ARBL.ZS',
# 'AG.LND.ARBL.HA.PC',
# 'AG.LND.ARBL.HA',
# 'TM.TAX.MRCH.BC.ZS',
# 'ER.FSH.CAPT.MT',
# 'NV.MNF.CHEM.ZS.UN',
# 'IC.REG.COST.PC.ZS',
# 'AG.PRD.CROP.XD',
# 'SH.XPD.CHEX.GD.ZS',
# 'SH.XPD.CHEX.PC.CD',
# 'SH.XPD.CHEX.PP.CD',
# 'SH.XPD.GHED.CH.ZS',
# 'SH.XPD.GHED.GD.ZS',
# 'SH.XPD.GHED.GE.ZS',
# 'SH.XPD.GHED.PC.CD',
# 'SH.XPD.GHED.PP.CD',
# 'SH.XPD.PVTD.CH.ZS',
# 'SH.XPD.PVTD.PC.CD',
# 'SH.XPD.PVTD.PP.CD',
# 'SH.XPD.EHEX.CH.ZS',
# 'SH.XPD.EHEX.PC.CD',
# 'SH.XPD.EHEX.PP.CD',
# 'AG.PRD.FOOD.XD',
# 'NV.MNF.FBTO.ZS.UN',
# 'AG.LND.FRST.ZS',
# 'AG.LND.FRST.K2',
# 'SE.PRM.GINT.FE.ZS',
# 'SE.PRM.GINT.MA.ZS',
# 'SE.PRM.GINT.ZS',
# 'VC.IHR.PSRC.P5',
# 'VC.IHR.PSRC.FE.P5',
# 'VC.IHR.PSRC.MA.P5',
# 'AG.PRD.LVSK.XD',
# 'NV.MNF.MTRN.ZS.UN',
# 'DC.DAC.PRTL.CD',
# 'NV.MNF.OTHR.ZS.UN',
# 'SH.XPD.OOPC.CH.ZS',
# 'SH.XPD.OOPC.PC.CD',
# 'SH.XPD.OOPC.PP.CD',
# 'AG.LND.CROP.ZS',
# 'SH.MED.PHYS.ZS',
# 'SH.ANM.CHLD.ZS',
# 'SH.ANM.NPRG.ZS',
# 'SH.PRG.ANEM',
# 'SH.ANM.ALLW.ZS',
# 'SE.PRE.ENRR',
# 'SE.PRE.ENRR.FE',
# 'SE.PRE.ENRR.MA',
# 'SE.ENR.TERT.FM.ZS',
# 'SE.TER.ENRR.FE',
# 'SE.TER.ENRR.MA',
# 'TM.TAX.MRCH.IP.ZS',
# 'TM.TAX.MRCH.SR.ZS',
# 'TM.TAX.MRCH.SM.AR.ZS',
# 'TM.TAX.MRCH.WM.AR.ZS',
# 'TM.TAX.MRCH.SM.FN.ZS',
# 'TM.TAX.MRCH.WM.FN.ZS',
# 'NV.MNF.TXTL.ZS.UN',
# 'ER.FSH.PROD.MT',
# 'SH.TBS.CURE.ZS',
# 'SN.ITK.VITA.ZS',
# 'TM.TAX.MANF.BC.ZS',
# 'TM.TAX.TCOM.BC.ZS',
# 'TM.TAX.MRCH.BR.ZS',
# 'TM.TAX.MANF.BR.ZS',
# 'TM.TAX.TCOM.BR.ZS',
# 'EG.ELC.COAL.ZS',
# 'EG.ELC.HYRO.ZS',
# 'EG.ELC.NGAS.ZS',
# 'EG.ELC.PETR.ZS',
# 'EG.ELC.FOSL.ZS',
# 'EG.ELC.RNWX.ZS',
# 'EG.ELC.RNWX.KH',
# 'EG.EGY.PRIM.PP.KD',
# 'CM.MKT.LCAP.GD.ZS',
# 'CM.MKT.LCAP.CD',
# 'FM.AST.NFRG.CN',
# 'DT.NFL.WFPG.CD',
# 'GC.XPN.OTHR.ZS',
# 'GC.XPN.OTHR.CN',
# 'EG.ELC.RNEW.ZS',
# 'EG.FEC.RNEW.ZS',
# 'TM.TAX.MANF.IP.ZS',
# 'TM.TAX.TCOM.IP.ZS',
# 'TM.TAX.MANF.SR.ZS',
# 'TM.TAX.TCOM.SR.ZS',
# 'CM.MKT.TRAD.GD.ZS',
# 'CM.MKT.TRAD.CD',
# 'CM.MKT.TRNR',
# 'GC.XPN.TRFT.ZS',
# 'GC.XPN.TRFT.CN',
# 'TM.TAX.MANF.SM.AR.ZS',
# 'TM.TAX.TCOM.SM.AR.ZS',
# 'TM.TAX.MANF.WM.AR.ZS',
# 'TM.TAX.TCOM.WM.AR.ZS',
# 'TM.TAX.MANF.SM.FN.ZS',
# 'TM.TAX.TCOM.SM.FN.ZS',
# 'TM.TAX.MANF.WM.FN.ZS',
# 'TM.TAX.TCOM.WM.FN.ZS',
# 'GC.TAX.EXPT.ZS',
# 'GC.TAX.EXPT.CN',
# 'EG.USE.COMM.CL.ZS',
# 'IC.BUS.DISC.XQ',
# 'EN.ATM.CO2E.KD.GD',
# 'EN.ATM.CO2E.PP.GD.KD',
# 'EN.ATM.CO2E.PP.GD',
# 'EN.ATM.CO2E.KT',
# 'EN.ATM.CO2E.PC',
# 'EN.CO2.ETOT.ZS',
# 'EN.ATM.CO2E.GF.ZS',
# 'EN.ATM.CO2E.GF.KT',
# 'EN.ATM.CO2E.LF.ZS',
# 'EN.ATM.CO2E.LF.KT',
# 'EN.CO2.MANF.ZS',
# 'EN.CO2.OTHX.ZS',
# 'EN.CO2.BLDG.ZS',
# 'EN.ATM.CO2E.SF.ZS',
# 'EN.ATM.CO2E.SF.KT',
# 'EN.CO2.TRAN.ZS',
# 'EN.ATM.CO2E.EG.ZS',
# 'EG.USE.CRNW.ZS',
# 'FB.CBK.BRCH.P5',
# 'EG.USE.ELEC.KH.PC',
# 'EG.ELC.LOSS.ZS',
# 'EG.ELC.NUCL.ZS',
# 'EG.IMP.CONS.ZS',
# 'EG.USE.PCAP.KG.OE',
# 'EG.USE.COMM.GD.PP.KD',
# 'AG.CON.FERT.PT.ZS',
# 'AG.CON.FERT.ZS',
# 'EG.USE.COMM.FO.ZS',
# 'EG.GDP.PUSE.KO.PP.KD',
# 'EG.GDP.PUSE.KO.PP',
# 'SH.IMM.HEPB',
# 'ST.INT.TRNX.CD',
# 'ST.INT.TRNR.CD',
# 'IS.SHP.GCNW.XQ',
# 'IQ.SCI.MTHD',
# 'SH.MED.NUMW.P3',
# 'IQ.SCI.PRDC',
# 'SE.PRM.ENRL',
# 'SE.PRM.ENRL.FE.ZS',
# 'SE.PRM.ENRR',
# 'SE.ENR.PRIM.FM.ZS',
# 'SE.ENR.PRSC.FM.ZS',
# 'SE.PRM.ENRR.FE',
# 'SE.PRM.ENRR.MA',
# 'IQ.SCI.SRCE',
# 'IQ.SCI.OVRL',
# 'FB.ATM.TOTL.P5',
# 'GC.DOD.TOTL.GD.ZS',
# 'GC.DOD.TOTL.CN',
# 'GC.NFN.TOTL.GD.ZS',
# 'GC.NFN.TOTL.CN',
# 'DT.NFL.UNCR.CD',
# 'IP.JRN.ARTC.SC',
# 'SE.SEC.ENRL.GC',
# 'SE.SEC.ENRL.GC.FE.ZS',
# 'SE.SEC.ENRL.VO',
# 'SE.SEC.ENRL.VO.FE.ZS',
# 'IP.TMK.NRCT',
# 'IP.TMK.RSCT',
# 'AG.LND.IRIG.AG.ZS',
# 'EN.ATM.METH.ZG',
# 'EN.ATM.METH.KT.CE',
# 'DC.DAC.CZEL.CD',
# 'DC.DAC.POLL.CD',
# 'DT.NFL.UNAI.CD',
# 'EN.ATM.NOXE.ZG',
# 'EN.ATM.NOXE.KT.CE',
# 'EN.ATM.GHGO.ZG',
# 'EN.ATM.GHGO.KT.CE',
# 'SE.SEC.ENRL.TC.ZS',
# 'SE.PRM.REPT.FE.ZS',
# 'SE.PRM.REPT.MA.ZS',
# 'SE.PRM.REPT.ZS',
# 'GB.XPD.RSDV.GD.ZS',
# 'SE.SEC.TCHR',
# 'SE.SEC.TCHR.FE.ZS',
# 'SE.SEC.TCHR.FE',
# 'EN.ATM.GHGT.ZG',
# 'EN.ATM.GHGT.KT.CE',
# 'SE.PRM.CMPT.FE.ZS',
# 'SE.PRM.CMPT.MA.ZS',
# 'SE.PRM.CMPT.ZS',
# 'SE.SEC.ENRL.LO.TC.ZS',
# 'SE.SEC.ENRL.UP.TC.ZS',
# 'SP.POP.BRTH.MF',
# 'SE.PRM.TENR',
# 'SE.PRM.TENR.FE',
# 'SE.PRM.TENR.MA',
# 'IQ.WEF.CUST.XQ',
# 'SE.PRM.UNER.ZS',
# 'SE.PRM.UNER.FE.ZS',
# 'SE.PRM.UNER.MA.ZS',
# 'SE.PRM.UNER',
# 'SE.PRM.UNER.FE',
# 'SE.PRM.UNER.MA',
# 'SE.XPD.SECO.PC.ZS',
# 'VC.IDP.NWDS',
# 'IC.BUS.NDNS.ZS',
# 'IC.BUS.NREG',
# 'SE.PRM.OENR.ZS',
# 'SE.PRM.OENR.FE.ZS',
# 'SE.PRM.OENR.MA.ZS',
# 'SE.TER.ENRL.TC.ZS',
# 'IQ.WEF.PORT.XQ',
# 'SE.PRM.NENR',
# 'SE.PRM.NENR.FE',
# 'SE.PRM.NENR.MA',
# 'SE.TER.TCHR.FE.ZS',
# 'SH.MED.CMHW.P3',
# 'SE.COM.DURS',
# 'SE.XPD.PRIM.ZS',
# 'SE.XPD.SECO.ZS',
# 'SE.XPD.TERT.ZS',
# 'SE.XPD.TOTL.GD.ZS',
# 'SE.XPD.TOTL.GB.ZS',
# 'SE.XPD.TERT.PC.ZS',
# 'TX.VAL.TECH.MF.ZS',
# 'TX.VAL.TECH.CD',
# 'VC.IDP.NWCV',
# 'VC.IDP.TOCV',
# 'IE.PPI.WATR.CD',
# 'SG.LAW.EQRM.WK',
# 'SG.LEG.DVAW',
# 'SE.SEC.CMPT.LO.FE.ZS',
# 'SE.SEC.CMPT.LO.MA.ZS',
# 'SE.SEC.CMPT.LO.ZS',
# 'BN.TRF.KOGT.CD',
# 'EN.ATM.PM25.MC.M3',
# 'EN.ATM.PM25.MC.ZS',
# 'EN.ATM.PM25.MC.T1.ZS',
# 'EN.ATM.PM25.MC.T2.ZS',
# 'EN.ATM.PM25.MC.T3.ZS',
# 'SE.PRM.TCHR',
# 'GF.XPD.BUDG.ZS',
# 'IE.PPN.WATR.CD',
# 'SE.PRM.ENRL.TC.ZS',
# 'EN.ATM.METH.AG.ZS',
# 'EN.ATM.METH.AG.KT.CE',
# 'EN.ATM.NOXE.AG.ZS',
# 'EN.ATM.NOXE.AG.KT.CE',
# 'IQ.CPA.HRES.XQ',
# 'IQ.CPA.BREG.XQ',
# 'IQ.CPA.DEBT.XQ',
# 'IQ.CPA.ECON.XQ',
# 'IQ.CPA.REVN.XQ',
# 'IQ.CPA.PRES.XQ',
# 'IQ.CPA.FINS.XQ',
# 'IQ.CPA.FISP.XQ',
# 'IQ.CPA.GNDR.XQ',
# 'IQ.CPA.MACR.XQ',
# 'IQ.CPA.SOCI.XQ',
# 'IQ.CPA.ENVR.XQ',
# 'IQ.CPA.PROP.XQ',
# 'IQ.CPA.PUBS.XQ',
# 'IQ.CPA.FINQ.XQ',
# 'IQ.CPA.PADM.XQ',
# 'IQ.CPA.PROT.XQ',
# 'IQ.CPA.STRC.XQ',
# 'IQ.CPA.TRAD.XQ',
# 'IQ.CPA.TRAN.XQ',
# 'EN.ATM.METH.EG.ZS',
# 'IQ.CPA.IRAI.XQ',
# 'SH.MLR.INCD.P3',
# 'EN.ATM.METH.EG.KT.CE',
# 'DT.NFL.UNTA.CD',
# 'EN.ATM.NOXE.EG.ZS',
# 'EN.ATM.NOXE.EG.KT.CE',
# 'SE.PRM.TCHR.FE.ZS',
# 'EP.PMP.DESL.CD',
# 'EP.PMP.SGAS.CD',
# 'IT.NET.SECR',
# 'IT.NET.SECR.P6',
# 'SH.PRV.SMOK.FE',
# 'SH.PRV.SMOK.MA',
# 'SH.PRV.SMOK',
# 'FB.AST.NPER.ZS',
# 'SE.XPD.PRIM.PC.ZS',
# 'SE.SEC.PROG.ZS',
# 'SE.SEC.PROG.FE.ZS',
# 'SE.SEC.PROG.MA.ZS',
# 'SE.PRM.PRIV.ZS',
# 'SE.SEC.PRIV.ZS',
# 'SI.RMT.COST.IB.ZS',
# 'FB.BNK.CAPA.ZS',
# 'SP.DYN.CONU.ZS',
# 'IC.REG.COST.PC.FE.ZS',
# 'IC.REG.COST.PC.MA.ZS',
# 'IC.CRD.INFO.XQ',
# 'IC.TAX.LABR.CP.ZS',
# 'DT.NFL.WHOL.CD',
# 'IC.TAX.OTHR.CP.ZS',
# 'IC.CRD.PRVT.ZS',
# 'IC.WRH.PROC',
# 'IC.PRP.PROC',
# 'IC.TAX.PRFT.CP.ZS',
# 'IC.CRD.PUBL.ZS',
# 'SH.SGR.CRSK.ZS',
# 'SH.SGR.IRSK.ZS',
# 'IC.REG.PROC',
# 'IC.REG.PROC.FE',
# 'IC.REG.PROC.MA',
# 'IC.LGL.CRED.XQ',
# 'IC.TAX.PAYM',
# 'IC.WRH.DURS',
# 'IC.LGL.DURS',
# 'IC.ELC.TIME',
# 'IC.PRP.DURS',
# 'IC.REG.DURS',
# 'IC.REG.DURS.FE',
# 'IC.REG.DURS.MA',
# 'IC.TAX.DURS',
# 'IC.ISV.DURS',
# 'IC.TAX.TOTL.CP.ZS',
# 'SP.DYN.CONM.ZS',
# 'IC.EXP.CSBC.CD',
# 'IC.EXP.CSDC.CD',
# 'IC.IMP.CSBC.CD',
# 'IC.IMP.CSDC.CD',
# 'SL.TLF.ACTI.1524.FE.NE.ZS',
# 'SL.TLF.ACTI.1524.MA.NE.ZS',
# 'SL.TLF.ACTI.1524.NE.ZS',
# 'SL.TLF.CACT.FE.NE.ZS',
# 'SL.TLF.CACT.MA.NE.ZS',
# 'SL.TLF.CACT.NE.ZS',
# 'DC.DAC.SVKL.CD',
# 'DC.DAC.SVNL.CD',
# 'DT.NFL.ILOG.CD',
# 'SE.PRM.PRS5.ZS',
# 'SE.PRM.PRSL.ZS',
# 'SE.PRE.ENRL.TC.ZS',
# 'SL.TLF.CACT.FM.NE.ZS',
# 'SL.UEM.NEET.FE.ZS',
# 'SL.UEM.NEET.MA.ZS',
# 'SL.UEM.NEET.ZS',
# 'IC.EXP.TMBC',
# 'IC.EXP.TMDC',
# 'IC.IMP.TMBC',
# 'IC.IMP.TMDC',
# 'SH.STA.BRTC.ZS',
# 'SL.TLF.0714.FE.ZS',
# 'SL.TLF.0714.MA.ZS',
# 'SL.TLF.0714.SW.ZS',
# 'SL.TLF.0714.ZS',
# 'SL.TLF.0714.WK.ZS',
# 'SH.FPL.SATM.ZS',
# 'IC.BUS.DFRN.XQ',
# 'SL.EMP.TOTL.SP.FE.NE.ZS',
# 'SL.EMP.TOTL.SP.MA.NE.ZS',
# 'SL.EMP.TOTL.SP.NE.ZS',
# 'SL.EMP.1524.SP.FE.NE.ZS',
# 'SL.EMP.1524.SP.MA.NE.ZS',
# 'SL.EMP.1524.SP.NE.ZS',
# 'SL.TLF.ADVN.ZS',
# 'SL.TLF.ADVN.FE.ZS',
# 'SL.TLF.ADVN.MA.ZS',
# 'SL.TLF.BASC.ZS',
# 'SL.TLF.BASC.FE.ZS',
# 'SL.TLF.BASC.MA.ZS',
# 'SL.TLF.INTM.ZS',
# 'SL.TLF.INTM.FE.ZS',
# 'SL.TLF.INTM.MA.ZS',
# 'SG.LAW.NODC.HR',
# 'SG.LAW.LEVE.PU',
# 'LP.EXP.DURS.MD',
# 'LP.IMP.DURS.MD',
# 'LP.LPI.TRAC.XQ',
# 'LP.LPI.LOGS.XQ',
# 'LP.LPI.ITRN.XQ',
# 'LP.LPI.CUST.XQ',
# 'LP.LPI.TIME.XQ',
# 'LP.LPI.OVRL.XQ',
# 'LP.LPI.INFR.XQ',
# 'SH.STA.MMRT.NE',
# 'SH.DYN.NCOM.ZS',
# 'SH.DYN.NCOM.FE.ZS',
# 'SH.DYN.NCOM.MA.ZS',
# 'SH.STA.POIS.P5',
# 'SH.STA.POIS.P5.FE',
# 'SH.STA.POIS.P5.MA',
# 'SG.MMR.LEVE.EP',
# 'SG.NOD.CONS',
# 'SG.JOB.NOPN.EQ',
# 'SE.PRM.PRS5.FE.ZS',
# 'SE.PRM.PRS5.MA.ZS',
# 'SE.PRM.PRSL.FE.ZS',
# 'SE.PRM.PRSL.MA.ZS',
# 'EN.POP.SLUM.UR.ZS',
# 'SH.STA.SUIC.P5',
# 'SH.STA.SUIC.FE.P5',
# 'SH.STA.SUIC.MA.P5',
# 'SL.UEM.ADVN.ZS',
# 'SL.UEM.ADVN.FE.ZS',
# 'SL.UEM.ADVN.MA.ZS',
# 'SL.UEM.BASC.ZS',
# 'SL.UEM.BASC.FE.ZS',
# 'SL.UEM.BASC.MA.ZS',
# 'SL.UEM.INTM.ZS',
# 'SL.UEM.INTM.FE.ZS',
# 'SL.UEM.INTM.MA.ZS',
# 'SL.UEM.TOTL.FE.NE.ZS',
# 'SL.UEM.TOTL.MA.NE.ZS',
# 'SL.UEM.TOTL.NE.ZS',
# 'SL.UEM.1524.FE.NE.ZS',
# 'SL.UEM.1524.MA.NE.ZS',
# 'SL.UEM.1524.NE.ZS',
# 'AG.LND.PRCP.MM',
# 'SH.DTH.COMM.ZS',
# 'SH.DTH.INJR.ZS',
# 'SH.DTH.NCOM.ZS',
# 'SL.AGR.0714.ZS',
# 'SL.AGR.0714.FE.ZS',
# 'SL.AGR.0714.MA.ZS',
# 'SL.MNF.0714.ZS',
# 'SL.MNF.0714.FE.ZS',
# 'SL.MNF.0714.MA.ZS',
# 'SL.SRV.0714.ZS',
# 'SL.SRV.0714.FE.ZS',
# 'SL.SRV.0714.MA.ZS',
# 'SP.REG.BRTH.ZS',
# 'SE.XPD.CPRM.ZS',
# 'SE.XPD.CSEC.ZS',
# 'SE.XPD.CTER.ZS',
# 'SE.XPD.CTOT.ZS',
# 'EN.ATM.HFCG.KT.CE',
# 'SH.MED.BEDS.ZS',
# 'SM.POP.TOTL.ZS',
# 'SM.POP.TOTL',
# 'SE.ADT.LITR.FE.ZS',
# 'SE.ADT.LITR.MA.ZS',
# 'SE.ADT.LITR.ZS',
# 'SE.ADT.1524.LT.FM.ZS',
# 'SE.ADT.1524.LT.FE.ZS',
# 'SE.ADT.1524.LT.MA.ZS',
# 'SE.ADT.1524.LT.ZS',
# 'SP.DYN.IMRT.FE.IN',
# 'SP.DYN.IMRT.MA.IN',
# 'SH.DYN.MORT.FE',
# 'SH.DYN.MORT.MA',
# 'SM.POP.NETM',
# 'SH.DTH.0514',
# 'SH.STA.HYGN.ZS',
# 'SH.STA.HYGN.RU.ZS',
# 'SH.STA.HYGN.UR.ZS',
# 'EN.ATM.PFCG.KT.CE',
# 'SH.STA.ANVC.ZS',
# 'SH.DYN.0514',
# 'ER.H2O.INTR.PC',
# 'ER.H2O.INTR.K3',
# 'SP.POP.SCIE.RD.P6',
# 'EN.ATM.SF6G.KT.CE',
# 'SP.POP.TECH.RD.P6',
# 'SP.UWT.TFRT',
# 'FX.OWN.TOTL.ZS',
# 'FX.OWN.TOTL.FE.ZS',
# 'FX.OWN.TOTL.MA.ZS',
# 'FX.OWN.TOTL.OL.ZS',
# 'FX.OWN.TOTL.40.ZS',
# 'FX.OWN.TOTL.PL.ZS',
# 'FX.OWN.TOTL.60.ZS',
# 'FX.OWN.TOTL.SO.ZS',
# 'FX.OWN.TOTL.YG.ZS',
# 'ER.H2O.FWTL.ZS',
# 'SH.STA.ARIC.ZS',
# 'SH.MLR.TRET.ZS',
# 'SP.REG.BRTH.FE.ZS',
# 'SP.REG.BRTH.MA.ZS',
# 'SP.REG.BRTH.RU.ZS',
# 'SP.REG.BRTH.UR.ZS',
# 'per_allsp.cov_pop_tot',
# 'per_sa_allsa.cov_pop_tot',
# 'per_sa_allsa.cov_q2_tot',
# 'per_sa_allsa.cov_q3_tot',
# 'per_sa_allsa.cov_q4_tot',
# 'per_sa_allsa.cov_q1_tot',
# 'per_sa_allsa.cov_q5_tot',
# 'SH.STA.ORTH',
# 'SH.STA.BFED.ZS',
# 'SL.EMP.SMGT.FE.ZS',
# 'SI.POV.GINI',
# 'SI.DST.04TH.20',
# 'SI.DST.10TH.10',
# 'SI.DST.05TH.20',
# 'SI.DST.FRST.10',
# 'SI.DST.FRST.20',
# 'SI.DST.02ND.20',
# 'SI.DST.03RD.20',
# 'SH.UHC.NOP1.ZG',
# 'SH.UHC.NOP1.CG',
# 'SH.UHC.NOP2.ZG',
# 'SH.UHC.NOP2.CG',
# 'SL.ISV.IFRM.ZS',
# 'SL.ISV.IFRM.FE.ZS',
# 'SL.ISV.IFRM.MA.ZS',
# 'ER.MRN.PTMR.ZS',
# 'SH.UHC.NOP1.TO',
# 'SH.UHC.NOP2.TO',
# 'SH.UHC.OOPC.10.TO',
# 'SH.UHC.OOPC.25.TO',
# 'SI.POV.GAPS',
# 'SI.POV.LMIC.GP',
# 'SI.POV.UMIC.GP',
# 'SI.POV.NAGP',
# 'SI.POV.DDAY',
# 'SI.POV.LMIC',
# 'SI.POV.UMIC',
# 'SI.POV.NAHC',
# 'SH.SVR.WAST.ZS',
# 'SH.STA.STNT.ZS',
# 'SH.STA.MALN.ZS',
# 'SH.STA.WAST.ZS',
# 'SH.UHC.NOP1.ZS',
# 'SH.UHC.NOP2.ZS',
# 'SH.UHC.OOPC.10.ZS',
# 'SH.UHC.OOPC.25.ZS',
# 'SI.POV.RUGP',
# 'SI.POV.RUHC',
# 'ER.PTD.TOTL.ZS',
# 'ER.LND.PTLD.ZS',
# 'SI.POV.URGP',
# 'SI.POV.URHC',
# 'ER.H2O.FWAG.ZS',
# 'ER.H2O.FWDM.ZS',
# 'ER.H2O.FWIN.ZS',
# 'ER.H2O.FWTL.K3',
# 'IC.CUS.DURS.EX',
# 'SI.RMT.COST.OB.ZS',
# 'SL.SLF.0714.ZS',
# 'SL.SLF.0714.FE.ZS',
# 'SL.SLF.0714.MA.ZS',
# 'SL.TLF.0714.SW.FE.ZS',
# 'SL.TLF.0714.SW.MA.ZS',
# 'SL.FAM.0714.ZS',
# 'SL.FAM.0714.FE.ZS',
# 'SL.FAM.0714.MA.ZS',
# 'SL.WAG.0714.ZS',
# 'SL.WAG.0714.FE.ZS',
# 'SL.WAG.0714.MA.ZS',
# 'SL.TLF.0714.WK.FE.ZS',
# 'SL.TLF.0714.WK.MA.ZS',
# 'SN.ITK.SALT.ZS',
# 'per_lm_alllm.cov_pop_tot',
# 'per_lm_alllm.cov_q2_tot',
# 'per_lm_alllm.cov_q3_tot',
# 'per_lm_alllm.cov_q4_tot',
# 'per_lm_alllm.cov_q1_tot',
# 'per_lm_alllm.cov_q5_tot',
# 'SH.STA.ORCF.ZS',
# 'IC.TAX.GIFT.ZS',
# 'IC.FRM.TRNG.ZS',
# 'IC.FRM.BNKS.ZS',
# 'IC.FRM.BKWC.ZS',
# 'IC.FRM.FEMO.ZS',
# 'IC.FRM.CORR.ZS',
# 'AG.LND.EL5M.ZS',
# 'SG.LAW.CHMR',
# 'SH.STA.TRAF.P5',
# 'DC.DAC.ISLL.CD',
# 'SE.PRM.NINT.ZS',
# 'SE.PRM.NINT.FE.ZS',
# 'SE.PRM.NINT.MA.ZS',
# 'EN.POP.EL5M.ZS',
# 'SH.STA.OWGH.ZS',
# 'SH.SVR.WAST.FE.ZS',
# 'SH.SVR.WAST.MA.ZS',
# 'SH.STA.STNT.FE.ZS',
# 'SH.STA.STNT.MA.ZS',
# 'SH.STA.MALN.FE.ZS',
# 'SH.STA.MALN.MA.ZS',
# 'SH.STA.WAST.FE.ZS',
# 'SH.STA.WAST.MA.ZS',
# 'AG.LND.TOTL.RU.K2',
# 'AG.LND.EL5M.RU.ZS',
# 'AG.LND.EL5M.RU.K2',
# 'EN.POP.EL5M.RU.ZS',
# 'SP.MTR.1519.ZS',
# 'IC.GOV.DURS.ZS',
# 'IC.ELC.DURS',
# 'SH.ALC.PCAP.LI',
# 'SH.ALC.PCAP.FE.LI',
# 'SH.ALC.PCAP.MA.LI',
# 'SE.SEC.TCAQ.LO.ZS',
# 'SE.SEC.TCAQ.LO.FE.ZS',
# 'SE.PRM.TCAQ.ZS',
# 'SE.PRM.TCAQ.FE.ZS',
# 'SE.PRM.TCAQ.MA.ZS',
# 'AG.LND.TOTL.UR.K2',
# 'AG.LND.EL5M.UR.ZS',
# 'AG.LND.EL5M.UR.K2',
# 'EN.POP.EL5M.UR.ZS',
# 'SP.DYN.WFRT',
# 'ER.GDP.FWTL.M3.KD',
# 'SG.VAW.REAS.ZS',
# 'SG.VAW.ARGU.ZS',
# 'SG.VAW.BURN.ZS',
# 'SG.VAW.GOES.ZS',
# 'SG.VAW.NEGL.ZS',
# 'SG.VAW.REFU.ZS',
# 'SP.M15.2024.FE.ZS',
# 'SP.M18.2024.FE.ZS',
# 'PA.NUS.PPP.05',
# 'PA.NUS.PRVT.PP.05',
# 'per_si_allsi.adq_pop_tot',
# 'per_allsp.adq_pop_tot',
# 'per_sa_allsa.adq_pop_tot',
# 'SE.SEC.UNER.LO.ZS',
# 'SE.SEC.UNER.LO.FE.ZS',
# 'SE.SEC.UNER.LO.MA.ZS',
# 'AG.AGR.TRAC.NO',
# 'AG.LND.TRAC.ZS',
# 'IC.TAX.METG',
# 'per_si_allsi.ben_q1_tot',
# 'per_allsp.ben_q1_tot',
# 'per_sa_allsa.ben_q1_tot',
# 'EN.BIR.THRD.NO',
# 'IC.FRM.BRIB.ZS',
# 'SP.REG.DTHS.ZS',
# 'SH.CON.1524.FE.ZS',
# 'SH.CON.1524.MA.ZS',
# 'per_si_allsi.cov_pop_tot',
# 'per_si_allsi.cov_q2_tot',
# 'per_si_allsi.cov_q3_tot',
# 'per_si_allsi.cov_q4_tot',
# 'per_si_allsi.cov_q1_tot',
# 'per_si_allsi.cov_q5_tot',
# 'SH.STA.DIAB.ZS',
# 'EN.CLC.DRSK.XQ',
# 'EN.CLC.MDAT.ZS',
# 'IC.BUS.EASE.XQ',
# 'SE.TER.CUAT.BA.FE.ZS',
# 'SE.TER.CUAT.BA.MA.ZS',
# 'SE.TER.CUAT.BA.ZS',
# 'SE.SEC.CUAT.LO.FE.ZS',
# 'SE.SEC.CUAT.LO.MA.ZS',
# 'SE.SEC.CUAT.LO.ZS',
# 'SE.SEC.CUAT.PO.FE.ZS',
# 'SE.SEC.CUAT.PO.MA.ZS',
# 'SE.SEC.CUAT.PO.ZS',
# 'SE.PRM.CUAT.FE.ZS',
# 'SE.PRM.CUAT.MA.ZS',
# 'SE.PRM.CUAT.ZS',
# 'SE.TER.CUAT.ST.FE.ZS',
# 'SE.TER.CUAT.ST.MA.ZS',
# 'SE.TER.CUAT.ST.ZS',
# 'SE.SEC.CUAT.UP.FE.ZS',
# 'SE.SEC.CUAT.UP.MA.ZS',
# 'SE.SEC.CUAT.UP.ZS',
# 'SP.HOU.FEMA.ZS',
# 'IC.FRM.CMPU.ZS',
# 'IC.ELC.OUTG.ZS',
# 'IC.FRM.THEV.ZS',
# 'IC.FRM.FREG.ZS',
# 'IC.FRM.INFM.ZS',
# 'IC.FRM.RSDV.ZS',
# 'IC.FRM.METG.ZS',
# 'IC.FRM.FEMM.ZS',
# 'EN.FSH.THRD.NO',
# 'HD.HCI.OVRL',
# 'HD.HCI.OVRL.FE',
# 'HD.HCI.OVRL.LB.FE',
# 'HD.HCI.OVRL.UB.FE',
# 'HD.HCI.OVRL.LB',
# 'HD.HCI.OVRL.MA',
# 'HD.HCI.OVRL.LB.MA',
# 'HD.HCI.OVRL.UB.MA',
# 'HD.HCI.OVRL.UB',
# 'ER.H2O.FWST.ZS',
# 'IC.FRM.CRIM.ZS',
# 'SH.STA.BRTW.ZS',
# 'EN.MAM.THRD.NO',
# 'SH.STA.AIRP.P5',
# 'SH.STA.AIRP.FE.P5',
# 'SH.STA.AIRP.MA.P5',
# 'SH.STA.WASH.P5',
# 'DT.NFL.FAOG.CD',
# 'EN.HPT.THRD.NO',
# 'IC.ELC.OUTG',
# 'DT.DOD.PVLX.EX.ZS',
# 'DT.DOD.PVLX.GN.ZS',
# 'DT.DOD.PVLX.CD',
# 'SH.STA.OWGH.FE.ZS',
# 'SH.STA.OWGH.MA.ZS',
# 'SG.VAW.1549.ZS',
# 'IE.PPN.ICTI.CD',
# 'SE.SEC.NENR',
# 'SE.SEC.NENR.FE',
# 'SE.SEC.NENR.MA',
# 'SH.MED.SAOP.P5',
# 'IC.FRM.DURS',
# 'SE.SEC.TCAQ.ZS',
# 'SE.SEC.TCAQ.FE.ZS',
# 'SE.SEC.TCAQ.MA.ZS',
# 'SE.SEC.TCAQ.UP.ZS',
# 'SE.SEC.TCAQ.UP.FE.ZS',
# 'SE.SEC.TCAQ.UP.MA.ZS',
# 'SH.UHC.SRVS.CV.XD',
# 'SH.MLR.NETS.ZS',
# 'IC.FRM.OUTG.ZS',
# 'SG.DMK.ALLD.FN.ZS',
# 'per_lm_alllm.adq_pop_tot',
# 'SH.HIV.INCD.TL',
# 'SH.HIV.INCD',
# 'SI.SPR.PC40.ZG',
# 'SI.SPR.PCAP.ZG',
# 'SH.HIV.ARTC.ZS',
# 'SH.HIV.PMTC.ZS',
# 'SL.TLF.0714.SW.TM',
# 'SL.TLF.0714.SW.FE.TM',
# 'SL.TLF.0714.SW.MA.TM',
# 'SL.TLF.0714.WK.TM',
# 'SL.TLF.0714.WK.FE.TM',
# 'SL.TLF.0714.WK.MA.TM',
# 'FD.RES.LIQU.AS.ZS',
# 'per_lm_alllm.ben_q1_tot',
# 'FB.CBK.BRWR.P3',
# 'SH.HIV.0014',
# 'SH.HIV.INCD.14',
# 'FS.AST.DOMO.GD.ZS',
# 'FM.AST.DOMO.ZG.M3',
# 'SP.DTH.INFR.ZS',
# 'SP.DTH.REPT.ZS',
# 'FR.INR.DPST',
# 'FB.CBK.DPTR.P3',
# 'SE.TER.CUAT.MS.FE.ZS',
# 'SE.TER.CUAT.MS.MA.ZS',
# 'SE.TER.CUAT.MS.ZS',
# 'SE.TER.CUAT.DO.FE.ZS',
# 'SE.TER.CUAT.DO.MA.ZS',
# 'SE.TER.CUAT.DO.ZS',
# 'SH.STA.FGMS.ZS',
# 'NV.FSM.TOTL.KN',
# 'NV.FSM.TOTL.CN',
# 'EN.CLC.GHGR.MT.CE',
# 'SH.HIV.INCD.ZS',
# 'FR.INR.LNDP',
# 'IE.PPI.ICTI.CD',
# 'DC.ODA.TLDC.GN.ZS',
# 'DC.ODA.TLDC.CD',
# 'DC.ODA.TOTL.GN.ZS',
# 'DC.ODA.TOTL.KD',
# 'DC.ODA.TOTL.CD',
# 'DT.ODA.OATL.KD',
# 'DT.ODA.OATL.CD',
# 'DT.NFL.IAEA.CD',
# 'DT.NFL.UNEC.CD',
# 'DT.NFL.UNPB.CD',
# 'DT.NFL.UNRW.CD',
# 'DT.NFL.UNWT.CD',
# 'NY.GSR.NFCY.KN',
# 'NY.TRF.NCTR.KN',
# 'SH.SGR.PROC.P5',
# 'SL.TLF.PART.FE.ZS',
# 'SL.TLF.PART.MA.ZS',
# 'SL.TLF.PART.ZS',
# 'SH.H2O.SMDW.ZS',
# 'SH.H2O.SMDW.UR.ZS',
# 'SH.STA.SMSS.ZS',
# 'SH.STA.SMSS.UR.ZS',
# 'VC.PKP.TOTL.UN',
# 'SH.HIV.1524.FE.ZS',
# 'SH.HIV.1524.MA.ZS',
# 'SH.DYN.AIDS.ZS',
# 'SG.TIM.UWRK.FE',
# 'SG.TIM.UWRK.MA',
# 'PX.REX.REER',
# 'FR.INR.RISK',
# 'SI.SPR.PC40',
# 'SI.SPR.PCAP',
# 'SE.SEC.TCAQ.LO.MA.ZS',
# 'SE.PRE.TCAQ.ZS',
# 'SE.PRE.TCAQ.FE.ZS',
# 'SE.PRE.TCAQ.MA.ZS',
# 'SG.DMK.SRCR.FN.ZS',
# 'SH.DYN.AIDS.FE.ZS'
# ]

# %%
ind_selected = [#selected indicators
    'SL.FAM.WORK.FE.ZS',
'SL.FAM.WORK.MA.ZS',
'SL.FAM.WORK.ZS',
'SL.EMP.MPYR.FE.ZS',
'SL.EMP.MPYR.MA.ZS',
'SL.EMP.MPYR.ZS',
'SL.AGR.EMPL.ZS',
'SL.AGR.EMPL.FE.ZS',
'SL.AGR.EMPL.MA.ZS',
'SL.IND.EMPL.ZS',
'SL.IND.EMPL.FE.ZS',
'SL.IND.EMPL.MA.ZS',
'SL.SRV.EMPL.ZS',
'SL.SRV.EMPL.FE.ZS',
'SL.SRV.EMPL.MA.ZS',
'SL.EMP.TOTL.SP.FE.ZS',
'SL.EMP.TOTL.SP.MA.ZS',
'SL.EMP.TOTL.SP.ZS',
'SL.EMP.1524.SP.FE.ZS',
'SL.EMP.1524.SP.MA.ZS',
'SL.EMP.1524.SP.ZS',
'SL.GDP.PCAP.EM.KD',
'SL.TLF.ACTI.1524.FE.ZS',
'SL.TLF.ACTI.1524.MA.ZS',
'SL.TLF.ACTI.1524.ZS',
'SL.TLF.CACT.FE.ZS',
'SL.TLF.ACTI.FE.ZS',
'SL.TLF.CACT.MA.ZS',
'SL.TLF.ACTI.MA.ZS',
'SL.TLF.CACT.ZS',
'SL.TLF.ACTI.ZS',
'SL.TLF.TOTL.FE.ZS',
'SL.TLF.TOTL.IN',
'SE.SEC.AGES',
'SE.PRM.DURS',
'SE.PRM.AGES',
'SL.TLF.CACT.FM.ZS',
'SE.SEC.DURS',
'SL.EMP.SELF.FE.ZS',
'SL.EMP.SELF.MA.ZS',
'SL.EMP.SELF.ZS',
'SL.UEM.TOTL.FE.ZS',
'SL.UEM.TOTL.MA.ZS',
'SL.UEM.TOTL.ZS',
'SL.UEM.1524.FE.ZS',
'SL.UEM.1524.MA.ZS',
'SL.UEM.1524.ZS',
'SL.EMP.VULN.FE.ZS',
'SL.EMP.VULN.MA.ZS',
'SL.EMP.VULN.ZS',
'SL.EMP.WORK.FE.ZS',
'SL.EMP.WORK.MA.ZS',
'SL.EMP.WORK.ZS',
'SP.POP.DPND',
'SP.POP.DPND.OL',
'SP.POP.DPND.YG',
'TX.VAL.AGRI.ZS.UN',
'TM.VAL.AGRI.ZS.UN',
'NV.AGR.TOTL.ZS',
'NV.AGR.TOTL.KD.ZG',
'NV.AGR.TOTL.KD',
'NV.AGR.TOTL.KN',
'NV.AGR.TOTL.CN',
'NV.AGR.TOTL.CD',
'NV.AGR.EMPL.KD',
'IS.AIR.GOOD.MT.K1',
'IS.AIR.PSGR',
'IS.AIR.DPRT',
'MS.MIL.MPRT.KD',
'VC.BTL.DETH',
'FM.LBL.BMNY.GD.ZS',
'FM.LBL.BMNY.CN',
'FM.LBL.BMNY.ZG',
'FM.LBL.BMNY.IR.ZS',
'NE.GDI.STKB.KN',
'NE.GDI.STKB.CN',
'NE.GDI.STKB.CD',
'BM.GSR.ROYL.CD',
'BX.GSR.ROYL.CD',
'FM.AST.CGOV.ZG.M3',
'FS.AST.CGOV.GD.ZS',
'FM.AST.PRVT.ZG.M3',
'DT.NFL.PCBO.CD',
'TX.VAL.SERV.CD.WT',
'TM.VAL.SERV.CD.WT',
'BX.GSR.CMCP.ZS',
'BM.GSR.CMCP.ZS',
'TX.VAL.OTHR.ZS.WT',
'TM.VAL.OTHR.ZS.WT',
'FP.CPI.TOTL',
'BN.CAB.XOKA.GD.ZS',
'BN.CAB.XOKA.CD',
'DT.TDS.DPPF.XP.ZS',
'DT.TDS.DPPG.CD',
'DT.TDS.DECT.CD',
'PA.NUS.ATLS',
'NY.GDP.DISC.KN',
'NY.GDP.DISC.CN',
'FS.AST.PRVT.GD.ZS',
'FD.AST.PRVT.GD.ZS',
'TX.UVI.MRCH.XD.WD',
'TX.VAL.MRCH.XD.WD',
'TX.QTY.MRCH.XD.WD',
'NY.EXP.CAPM.KN',
'NE.EXP.GNFS.ZS',
'NE.EXP.GNFS.KD.ZG',
'BX.GSR.GNFS.CD',
'NE.EXP.GNFS.KD',
'NE.EXP.GNFS.KN',
'NE.EXP.GNFS.CN',
'NE.EXP.GNFS.CD',
'BX.GSR.TOTL.CD',
'NE.RSB.GNFS.ZS',
'NE.RSB.GNFS.KN',
'NE.RSB.GNFS.CN',
'NE.RSB.GNFS.CD',
'DT.DOD.DECT.GN.ZS',
'DT.DOD.DLXF.CD',
'DT.DOD.DPNG.CD',
'DT.DOD.DPPG.CD',
'DT.DOD.DSTC.CD',
'DT.DOD.DECT.CD',
'NE.CON.TOTL.ZS',
'NE.CON.TOTL.KD.ZG',
'NE.CON.TOTL.KD',
'NE.CON.TOTL.KN',
'NE.CON.TOTL.CN',
'NE.CON.TOTL.CD',
'IT.MLT.MAIN',
'IT.MLT.MAIN.P2',
'TX.VAL.FOOD.ZS.UN',
'TM.VAL.FOOD.ZS.UN',
'BN.KLT.DINV.CD',
'BX.KLT.DINV.WD.GD.ZS',
'BX.KLT.DINV.CD.WD',
'BM.KLT.DINV.WD.GD.ZS',
'BM.KLT.DINV.CD.WD',
'TX.VAL.FUEL.ZS.UN',
'TM.VAL.FUEL.ZS.UN',
'NY.GDP.MKTP.KD',
'NY.GDP.MKTP.KN',
'NY.GDP.MKTP.CN',
'NY.GDP.MKTP.CD',
'NY.GDP.DEFL.ZS',
'NY.GDP.DEFL.ZS.AD',
'NY.GDP.MKTP.KD.ZG',
'NY.GDP.PCAP.KD',
'NY.GDP.PCAP.KN',
'NY.GDP.PCAP.CN',
'NY.GDP.PCAP.CD',
'NY.GDP.PCAP.KD.ZG',
'NY.GDP.PCAP.PP.KD',
'NY.GDP.PCAP.PP.CD',
'NY.GDP.MKTP.PP.KD',
'NY.GDP.MKTP.PP.CD',
'NY.GDP.MKTP.CN.AD',
'NE.CON.GOVT.ZS',
'NE.CON.GOVT.KD.ZG',
'NE.CON.GOVT.KD',
'NE.CON.GOVT.KN',
'NE.CON.GOVT.CN',
'NE.CON.GOVT.CD',
'NY.GNP.MKTP.KD',
'NY.GNP.MKTP.KN',
'NY.GNP.MKTP.CN',
'NY.GNP.MKTP.CD',
'NY.GNP.MKTP.KD.ZG',
'NY.GNP.PCAP.KD',
'NY.GNP.PCAP.KN',
'NY.GNP.PCAP.CN',
'NY.GNP.PCAP.KD.ZG',
'NY.GNP.PCAP.CD',
'NY.GNP.PCAP.PP.KD',
'NY.GNP.PCAP.PP.CD',
'NY.GNP.ATLS.CD',
'NY.GNP.MKTP.PP.KD',
'NY.GNP.MKTP.PP.CD',
'BX.GSR.MRCH.CD',
'BM.GSR.MRCH.CD',
'NE.GDI.TOTL.ZS',
'NE.GDI.TOTL.KD.ZG',
'NE.GDI.TOTL.KD',
'NE.GDI.TOTL.KN',
'NE.GDI.TOTL.CN',
'NE.GDI.TOTL.CD',
'NY.GDY.TOTL.KN',
'NY.GDS.TOTL.ZS',
'NY.GDS.TOTL.CN',
'NY.GDS.TOTL.CD',
'NE.GDI.FTOT.ZS',
'NE.GDI.FTOT.KD.ZG',
'NE.GDI.FTOT.KD',
'NE.GDI.FTOT.KN',
'NE.GDI.FTOT.CN',
'NE.GDI.FTOT.CD',
'NE.DAB.TOTL.ZS',
'NE.DAB.TOTL.KD',
'NE.DAB.TOTL.KN',
'NE.DAB.TOTL.CN',
'NE.DAB.TOTL.CD',
'NE.DAB.DEFL.ZS',
'NY.GNS.ICTR.ZS',
'NY.GNS.ICTR.GN.ZS',
'NY.GNS.ICTR.CN',
'NY.GNS.ICTR.CD',
'NY.GDP.FCST.KD',
'NY.GDP.FCST.KN',
'NY.GDP.FCST.CN',
'NY.GDP.FCST.CD',
'NE.CON.PRVT.ZS',
'NE.CON.PRVT.KD.ZG',
'NE.CON.PRVT.KD',
'NE.CON.PRVT.KN',
'NE.CON.PRVT.CN',
'NE.CON.PRVT.CD',
'NE.CON.PRVT.PC.KD',
'NE.CON.PRVT.PC.KD.ZG',
'NE.CON.PRVT.PP.KD',
'NE.CON.PRVT.PP.CD',
'DT.DOD.MWBG.CD',
'DT.NFL.NIFC.CD',
'DT.TDS.DIMF.CD',
'SH.IMM.IDPT',
'SH.IMM.MEAS',
'TM.UVI.MRCH.XD.WD',
'TM.VAL.MRCH.XD.WD',
'TM.QTY.MRCH.XD.WD',
'NE.IMP.GNFS.ZS',
'NE.IMP.GNFS.KD.ZG',
'BM.GSR.GNFS.CD',
'NE.IMP.GNFS.KD',
'NE.IMP.GNFS.KN',
'NE.IMP.GNFS.CN',
'NE.IMP.GNFS.CD',
'BM.GSR.TOTL.CD',
'NV.IND.TOTL.ZS',
'NV.IND.TOTL.KD.ZG',
'NV.IND.TOTL.KD',
'NV.IND.TOTL.KN',
'NV.IND.TOTL.CN',
'NV.IND.TOTL.CD',
'NV.IND.EMPL.KD',
'FP.CPI.TOTL.ZG',
'NY.GDP.DEFL.KD.ZG',
'NY.GDP.DEFL.KD.ZG.AD',
'TM.VAL.INSF.ZS.WT',
'BX.GSR.INSF.ZS',
'BM.GSR.INSF.ZS',
'IE.PPI.ENGY.CD',
'IE.PPI.TRAN.CD',
'AG.LND.TOTL.K2',
'FR.INR.LEND',
'CM.MKT.LDOM.NO',
'TX.VAL.MANF.ZS.UN',
'TM.VAL.MANF.ZS.UN',
'NV.IND.MANF.ZS',
'NV.IND.MANF.KD.ZG',
'NV.IND.MANF.KD',
'NV.IND.MANF.KN',
'NV.IND.MANF.CN',
'NV.IND.MANF.CD',
'TX.VAL.MRCH.CD.WT',
'TM.VAL.MRCH.CD.WT',
'TG.VAL.TOTL.GD.ZS',
'MS.MIL.XPND.GD.ZS',
'MS.MIL.XPND.ZS',
'MS.MIL.XPND.CN',
'MS.MIL.XPND.CD',
'IT.CEL.SETS',
'IT.CEL.SETS.P2',
'SP.DYN.IMRT.IN',
'SH.DYN.NMRT',
'SH.DYN.MORT',
'DT.TDS.MLAT.PG.ZS',
'DT.TDS.MLAT.CD',
'TT.PRI.MRCH.XD.WD',
'BN.KAC.EOMS.CD',
'BN.FIN.TOTL.CD',
'DT.NFL.BLAT.CD',
'DT.NFL.MIBR.CD',
'DT.NFL.MIDA.CD',
'DT.NFL.IMFC.CD',
'DT.NFL.IMFN.CD',
'DT.NFL.MLAT.CD',
'DT.NFL.MOTH.CD',
'DT.NFL.RDBC.CD',
'DT.NFL.RDBN.CD',
'DT.NFL.DPNG.CD',
'BN.GSR.FCTY.CD',
'NY.GSR.NFCY.CN',
'NY.GSR.NFCY.CD',
'BN.TRF.CURR.CD',
'NY.TRF.NCTR.CN',
'NY.TRF.NCTR.CD',
'BN.GSR.MRCH.CD',
'BN.GSR.GNFS.CD',
'SH.VAC.TTNS.ZS',
'SH.DTH.IMRT',
'SH.DTH.NMRT',
'SH.DTH.MORT',
'PA.NUS.FCRF',
'TX.VAL.MMTL.ZS.UN',
'TM.VAL.MMTL.ZS.UN',
'BM.TRF.PWKR.CD.DT',
'BX.TRF.PWKR.DT.GD.ZS',
'BX.TRF.PWKR.CD.DT',
'BX.TRF.PWKR.CD',
'DT.NFL.PNGB.CD',
'DT.NFL.PNGC.CD',
'SP.POP.0004.FE.5Y',
'SP.POP.0004.MA.5Y',
'SP.POP.0014.TO.ZS',
'SP.POP.0014.FE.IN',
'SP.POP.0014.FE.ZS',
'SP.POP.0014.MA.IN',
'SP.POP.0014.MA.ZS',
'SP.POP.0014.TO',
'SP.POP.0509.FE.5Y',
'SP.POP.0509.MA.5Y',
'SP.POP.1014.FE.5Y',
'SP.POP.1014.MA.5Y',
'SP.POP.1519.FE.5Y',
'SP.POP.1519.MA.5Y',
'SP.POP.1564.TO.ZS',
'SP.POP.1564.FE.IN',
'SP.POP.1564.FE.ZS',
'SP.POP.1564.MA.IN',
'SP.POP.1564.MA.ZS',
'SP.POP.1564.TO',
'SP.POP.2024.FE.5Y',
'SP.POP.2024.MA.5Y',
'SP.POP.2529.FE.5Y',
'SP.POP.2529.MA.5Y',
'SP.POP.3034.FE.5Y',
'SP.POP.3034.MA.5Y',
'SP.POP.3539.FE.5Y',
'SP.POP.3539.MA.5Y',
'SP.POP.4044.FE.5Y',
'SP.POP.4044.MA.5Y',
'SP.POP.4549.FE.5Y',
'SP.POP.4549.MA.5Y',
'SP.POP.5054.FE.5Y',
'SP.POP.5054.MA.5Y',
'SP.POP.5559.FE.5Y',
'SP.POP.5559.MA.5Y',
'SP.POP.6064.FE.5Y',
'SP.POP.6064.MA.5Y',
'SP.POP.65UP.TO.ZS',
'SP.POP.65UP.FE.IN',
'SP.POP.65UP.FE.ZS',
'SP.POP.65UP.MA.IN',
'SP.POP.65UP.MA.ZS',
'SP.POP.65UP.TO',
'SP.POP.6569.FE.5Y',
'SP.POP.6569.MA.5Y',
'SP.POP.7074.FE.5Y',
'SP.POP.7074.MA.5Y',
'SP.POP.7579.FE.5Y',
'SP.POP.7579.MA.5Y',
'SP.POP.80UP.FE.5Y',
'SP.POP.80UP.MA.5Y',
'EN.POP.DNST',
'SP.POP.GROW',
'EN.URB.LCTY',
'EN.URB.LCTY.UR.ZS',
'EN.URB.MCTY',
'EN.URB.MCTY.TL.ZS',
'SP.POP.TOTL.FE.IN',
'SP.POP.TOTL.FE.ZS',
'SP.POP.TOTL.MA.IN',
'SP.POP.TOTL.MA.ZS',
'SP.POP.TOTL',
'BX.PEF.TOTL.CD.WD',
'DT.NFL.BOND.CD',
'BN.KLT.PTXL.CD',
'DT.NFL.PBND.CD',
'DT.NFL.PCBK.CD',
'DT.DOD.MIBR.CD',
'DT.DOD.MIDA.CD',
'DT.NFL.OFFT.CD',
'DT.NFL.PROP.CD',
'DT.NFL.PRVT.CD',
'PA.NUS.PPP',
'PA.NUS.PRVT.PP',
'SE.PRE.DURS',
'PA.NUS.PPPC.RF',
'BM.GSR.FCTY.CD',
'BX.GSR.FCTY.CD',
'SG.GEN.PARL.ZS',
'DT.TDS.DPPG.XP.ZS',
'DT.TDS.DPPG.GN.ZS',
'IE.PPN.ENGY.CD',
'IE.PPN.TRAN.CD',
'FR.INR.RINR',
'SM.POP.REFG',
'SM.POP.REFG.OR',
'BN.RES.INCL.CD',
'SP.RUR.TOTL',
'SP.RUR.TOTL.ZS',
'SP.RUR.TOTL.ZG',
'CM.MKT.INDX.ZG',
'SE.TER.ENRR',
'BX.TRF.CURR.CD',
'BM.TRF.PRVT.CD',
'BX.GSR.NFSV.CD',
'BM.GSR.NFSV.CD',
'NV.SRV.TOTL.ZS',
'NV.SRV.TOTL.KD.ZG',
'NV.SRV.TOTL.KD',
'NV.SRV.TOTL.KN',
'NV.SRV.TOTL.CN',
'NV.SRV.EMPL.KD',
'DT.DOD.DSTC.XP.ZS',
'DT.DOD.DSTC.ZS',
'DT.DOD.DSTC.IR.ZS',
'AG.SRF.TOTL.K2',
'NY.TAX.NIND.KN',
'NY.TAX.NIND.CN',
'NY.TAX.NIND.CD',
'NY.TTF.GNFS.KN',
'DT.TDS.DECT.EX.ZS',
'DT.TDS.DECT.GN.ZS',
'FI.RES.TOTL.DT.ZS',
'FI.RES.TOTL.CD',
'FI.RES.TOTL.MO',
'FI.RES.XGLD.CD',
'NE.TRD.GNFS.ZS',
'BG.GSR.NFSV.GD.ZS',
'TX.VAL.TRAN.ZS.WT',
'TM.VAL.TRAN.ZS.WT',
'BX.GSR.TRAN.ZS',
'BM.GSR.TRAN.ZS',
'TX.VAL.TRVL.ZS.WT',
'TM.VAL.TRVL.ZS.WT',
'BX.GSR.TRVL.ZS',
'BM.GSR.TRVL.ZS',
'SP.URB.TOTL',
'SP.URB.TOTL.IN.ZS',
'SP.URB.GROW',
'DT.DOD.DIMF.CD',
'FP.WPI.TOTL',
'EG.CFT.ACCS.ZS',
'AG.LND.AGRI.ZS',
'AG.LND.AGRI.K2',
'ER.FSH.AQUA.MT',
'AG.LND.ARBL.ZS',
'AG.LND.ARBL.HA.PC',
'AG.LND.ARBL.HA',
'TM.TAX.MRCH.BC.ZS',
'ER.FSH.CAPT.MT',
'NV.MNF.CHEM.ZS.UN',
'IC.REG.COST.PC.ZS',
'AG.PRD.CROP.XD',
'SH.XPD.CHEX.GD.ZS',
'SH.XPD.CHEX.PC.CD',
'SH.XPD.CHEX.PP.CD',
'SH.XPD.GHED.CH.ZS',
'SH.XPD.GHED.GD.ZS',
'SH.XPD.GHED.GE.ZS',
'SH.XPD.GHED.PC.CD',
'SH.XPD.GHED.PP.CD',
'SH.XPD.PVTD.CH.ZS',
'SH.XPD.PVTD.PC.CD',
'SH.XPD.PVTD.PP.CD',
'SH.XPD.EHEX.CH.ZS',
'SH.XPD.EHEX.PC.CD',
'SH.XPD.EHEX.PP.CD',
'AG.PRD.FOOD.XD',
'NV.MNF.FBTO.ZS.UN',
'AG.LND.FRST.ZS',
'AG.LND.FRST.K2',
'SE.PRM.GINT.FE.ZS',
'SE.PRM.GINT.MA.ZS',
'SE.PRM.GINT.ZS',
'VC.IHR.PSRC.P5',
'VC.IHR.PSRC.FE.P5',
'VC.IHR.PSRC.MA.P5',
'AG.PRD.LVSK.XD',
'NV.MNF.MTRN.ZS.UN',
'DC.DAC.PRTL.CD',
'NV.MNF.OTHR.ZS.UN',
'SH.XPD.OOPC.CH.ZS',
'SH.XPD.OOPC.PC.CD',
'SH.XPD.OOPC.PP.CD',
'AG.LND.CROP.ZS',
'SH.MED.PHYS.ZS',
'SH.ANM.CHLD.ZS',
'SH.ANM.NPRG.ZS',
'SH.PRG.ANEM',
'SH.ANM.ALLW.ZS',
'SE.PRE.ENRR',
'SE.PRE.ENRR.FE',
'SE.PRE.ENRR.MA',
'SE.ENR.TERT.FM.ZS',
'SE.TER.ENRR.FE',
'SE.TER.ENRR.MA',
'TM.TAX.MRCH.IP.ZS',
'TM.TAX.MRCH.SR.ZS',
'TM.TAX.MRCH.SM.AR.ZS',
'TM.TAX.MRCH.WM.AR.ZS',
'TM.TAX.MRCH.SM.FN.ZS',
'TM.TAX.MRCH.WM.FN.ZS',
'NV.MNF.TXTL.ZS.UN',
'ER.FSH.PROD.MT',
'SH.TBS.CURE.ZS',
'SN.ITK.VITA.ZS',
'TM.TAX.MANF.BC.ZS',
'TM.TAX.TCOM.BC.ZS',
'TM.TAX.MRCH.BR.ZS',
'TM.TAX.MANF.BR.ZS',
'TM.TAX.TCOM.BR.ZS',
'EG.ELC.COAL.ZS',
'EG.ELC.HYRO.ZS',
'EG.ELC.NGAS.ZS',
'EG.ELC.PETR.ZS',
'EG.ELC.FOSL.ZS',
'EG.ELC.RNWX.ZS',
'EG.ELC.RNWX.KH',
'EG.EGY.PRIM.PP.KD',
'CM.MKT.LCAP.GD.ZS',
'CM.MKT.LCAP.CD',
'FM.AST.NFRG.CN',
'DT.NFL.WFPG.CD',
'GC.XPN.OTHR.ZS',
'GC.XPN.OTHR.CN',
'EG.ELC.RNEW.ZS',
'EG.FEC.RNEW.ZS',
'TM.TAX.MANF.IP.ZS',
'TM.TAX.TCOM.IP.ZS',
'TM.TAX.MANF.SR.ZS',
'TM.TAX.TCOM.SR.ZS',
'CM.MKT.TRAD.GD.ZS',
'CM.MKT.TRAD.CD',
'CM.MKT.TRNR',
'GC.XPN.TRFT.ZS',
'GC.XPN.TRFT.CN',
'TM.TAX.MANF.SM.AR.ZS',
'TM.TAX.TCOM.SM.AR.ZS',
'TM.TAX.MANF.WM.AR.ZS',
'TM.TAX.TCOM.WM.AR.ZS',
'TM.TAX.MANF.SM.FN.ZS',
'TM.TAX.TCOM.SM.FN.ZS',
'TM.TAX.MANF.WM.FN.ZS',
'TM.TAX.TCOM.WM.FN.ZS',
'GC.TAX.EXPT.ZS',
'GC.TAX.EXPT.CN',
'EG.USE.COMM.CL.ZS',
'IC.BUS.DISC.XQ',
'EN.ATM.CO2E.KD.GD',
'EN.ATM.CO2E.PP.GD.KD',
'EN.ATM.CO2E.PP.GD',
'EN.ATM.CO2E.KT',
'EN.ATM.CO2E.PC',
'EN.CO2.ETOT.ZS',
'EN.ATM.CO2E.GF.ZS',
'EN.ATM.CO2E.GF.KT',
'EN.ATM.CO2E.LF.ZS',
'EN.ATM.CO2E.LF.KT',
'EN.CO2.MANF.ZS',
'EN.CO2.OTHX.ZS',
'EN.CO2.BLDG.ZS',
'EN.ATM.CO2E.SF.ZS',
'EN.ATM.CO2E.SF.KT',
'EN.CO2.TRAN.ZS',
'EN.ATM.CO2E.EG.ZS',
'EG.USE.CRNW.ZS',
'FB.CBK.BRCH.P5',
'EG.USE.ELEC.KH.PC',
'EG.ELC.LOSS.ZS',
'EG.ELC.NUCL.ZS',
'EG.IMP.CONS.ZS',
'EG.USE.PCAP.KG.OE',
'EG.USE.COMM.GD.PP.KD',
'AG.CON.FERT.PT.ZS',
'AG.CON.FERT.ZS',
'EG.USE.COMM.FO.ZS',
'EG.GDP.PUSE.KO.PP.KD',
'EG.GDP.PUSE.KO.PP',
'SH.IMM.HEPB',
'ST.INT.TRNX.CD',
'ST.INT.TRNR.CD',
'IS.SHP.GCNW.XQ',
'IQ.SCI.MTHD',
'SH.MED.NUMW.P3',
'IQ.SCI.PRDC',
'SE.PRM.ENRL',
'SE.PRM.ENRL.FE.ZS',
'SE.PRM.ENRR',
'SE.ENR.PRIM.FM.ZS',
'SE.ENR.PRSC.FM.ZS',
'SE.PRM.ENRR.FE',
'SE.PRM.ENRR.MA',
'IQ.SCI.SRCE',
'IQ.SCI.OVRL',
'FB.ATM.TOTL.P5',
'GC.DOD.TOTL.GD.ZS',
'GC.DOD.TOTL.CN',
'GC.NFN.TOTL.GD.ZS',
'GC.NFN.TOTL.CN',
'DT.NFL.UNCR.CD',
'IP.JRN.ARTC.SC',
'SE.SEC.ENRL.GC',
'SE.SEC.ENRL.GC.FE.ZS',
'SE.SEC.ENRL.VO',
'SE.SEC.ENRL.VO.FE.ZS',
'IP.TMK.NRCT',
'IP.TMK.RSCT',
'AG.LND.IRIG.AG.ZS',
'EN.ATM.METH.ZG',
'EN.ATM.METH.KT.CE',
'DC.DAC.CZEL.CD',
'DC.DAC.POLL.CD',
'DT.NFL.UNAI.CD',
'EN.ATM.NOXE.ZG',
'EN.ATM.NOXE.KT.CE',
'EN.ATM.GHGO.ZG',
'EN.ATM.GHGO.KT.CE',
'SE.SEC.ENRL.TC.ZS',
'SE.PRM.REPT.FE.ZS',
'SE.PRM.REPT.MA.ZS',
'SE.PRM.REPT.ZS',
'GB.XPD.RSDV.GD.ZS',
'SE.SEC.TCHR',
'SE.SEC.TCHR.FE.ZS',
'SE.SEC.TCHR.FE',
'EN.ATM.GHGT.ZG',
'EN.ATM.GHGT.KT.CE',
'SE.PRM.CMPT.FE.ZS',
'SE.PRM.CMPT.MA.ZS',
'SE.PRM.CMPT.ZS',
'SE.SEC.ENRL.LO.TC.ZS',
'SE.SEC.ENRL.UP.TC.ZS',
'SP.POP.BRTH.MF',
'SE.PRM.TENR',
'SE.PRM.TENR.FE',
'SE.PRM.TENR.MA',
'IQ.WEF.CUST.XQ',
'SE.PRM.UNER.ZS',
'SE.PRM.UNER.FE.ZS',
'SE.PRM.UNER.MA.ZS',
'SE.PRM.UNER',
'SE.PRM.UNER.FE',
'SE.PRM.UNER.MA',
'SE.XPD.SECO.PC.ZS',
'VC.IDP.NWDS',
'IC.BUS.NDNS.ZS',
'IC.BUS.NREG',
'SE.PRM.OENR.ZS',
'SE.PRM.OENR.FE.ZS',
'SE.PRM.OENR.MA.ZS',
'SE.TER.ENRL.TC.ZS',
'IQ.WEF.PORT.XQ',
'SE.PRM.NENR',
'SE.PRM.NENR.FE',
'SE.PRM.NENR.MA',
'SE.TER.TCHR.FE.ZS',
'SH.MED.CMHW.P3',
'SE.COM.DURS',
'SE.XPD.PRIM.ZS',
'SE.XPD.SECO.ZS',
'SE.XPD.TERT.ZS',
'SE.XPD.TOTL.GD.ZS',
'SE.XPD.TOTL.GB.ZS',
'SE.XPD.TERT.PC.ZS',
'TX.VAL.TECH.MF.ZS',
'TX.VAL.TECH.CD',
'VC.IDP.NWCV',
'VC.IDP.TOCV',
'IE.PPI.WATR.CD',
'SG.LAW.EQRM.WK',
'SG.LEG.DVAW',
'SE.SEC.CMPT.LO.FE.ZS',
'SE.SEC.CMPT.LO.MA.ZS',
'SE.SEC.CMPT.LO.ZS',
'BN.TRF.KOGT.CD',
'EN.ATM.PM25.MC.M3',
'EN.ATM.PM25.MC.ZS',
'EN.ATM.PM25.MC.T1.ZS',
'EN.ATM.PM25.MC.T2.ZS',
'EN.ATM.PM25.MC.T3.ZS',
'SE.PRM.TCHR',
'GF.XPD.BUDG.ZS',
'IE.PPN.WATR.CD',
'SE.PRM.ENRL.TC.ZS',
'SI.POV.NAHC',
'SI.DST.FRST.20',
'SP.DYN.LE00.IN',
'SP.DYN.TFRT.IN',
'SP.ADO.TFRT',
'SP.DYN.CONU.ZS',
'SH.STA.BRTC.ZS',
'SH.STA.MALN.ZS',
'SE.SEC.ENRR',
'SH.DYN.AIDS.ZS',
'ER.GDP.FWTL.M3.KD',
'GC.REV.XGRT.GD.ZS',
'IC.REG.PROC',
'SM.POP.NETM',
'DT.ODA.ODAT.PC.ZS',
'SI.POV.DDAY',
'SI.POV.LMIC',
'SI.POV.UMIC'
]

# %%
cc = {
'Aruba':'ABW',
'Afghanistan':'AFG',
'Africa':'AFR',
'Angola':'AGO',
'Albania':'ALB',
'Andorra':'AND',
'Andean Region':'ANR',
'Arab World':'ARB',
'United Arab Emirates':'ARE',
'Argentina':'ARG',
'Armenia':'ARM',
'American Samoa':'ASM',
'Antigua and Barbuda':'ATG',
'Australia':'AUS',
'Austria':'AUT',
'Azerbaijan':'AZE',
'Burundi':'BDI',
'East Asia & Pacific (IBRD-only countries)':'BEA',
'Europe & Central Asia (IBRD-only countries)':'BEC',
'Belgium':'BEL',
'Benin':'BEN',
'Burkina Faso':'BFA',
'Bangladesh':'BGD',
'Bulgaria':'BGR',
'IBRD countries classified as high income':'BHI',
'Bahrain':'BHR',
'Bahamas, The':'BHS',
'Bosnia and Herzegovina':'BIH',
'Latin America & the Caribbean (IBRD-only countries)':'BLA',
'Belarus':'BLR',
'Belize':'BLZ',
'Middle East & North Africa (IBRD-only countries)':'BMN',
'Bermuda':'BMU',
'Bolivia':'BOL',
'Brazil':'BRA',
'Barbados':'BRB',
'Brunei Darussalam':'BRN',
'Sub-Saharan Africa (IBRD-only countries)':'BSS',
'Bhutan':'BTN',
'Botswana':'BWA',
'Sub-Saharan Africa (IFC classification)':'CAA',
'Central African Republic':'CAF',
'Canada':'CAN',
'East Asia and the Pacific (IFC classification)':'CEA',
'Central Europe and the Baltics':'CEB',
'Europe and Central Asia (IFC classification)':'CEU',
'Switzerland':'CHE',
'Channel Islands':'CHI',
'Chile':'CHL',
'China':'CHN',
'Cote d\'Ivoire':'CIV',
'Latin America and the Caribbean (IFC classification)':'CLA',
'Middle East and North Africa (IFC classification)':'CME',
'Cameroon':'CMR',
'Congo, Dem. Rep.':'COD',
'Congo, Rep.':'COG',
'Colombia':'COL',
'Comoros':'COM',
'Cabo Verde':'CPV',
'Costa Rica':'CRI',
'South Asia (IFC classification)':'CSA',
'Caribbean small states':'CSS',
'Cuba':'CUB',
'Curacao':'CUW',
'Cayman Islands':'CYM',
'Cyprus':'CYP',
'Czech Republic':'CZE',
'East Asia & Pacific (IDA-eligible countries)':'DEA',
'Europe & Central Asia (IDA-eligible countries)':'DEC',
'Germany':'DEU',
'IDA countries classified as Fragile Situations':'DFS',
'Djibouti':'DJI',
'Latin America & the Caribbean (IDA-eligible countries)':'DLA',
'Dominica':'DMA',
'Middle East & North Africa (IDA-eligible countries)':'DMN',
'IDA countries not classified as Fragile Situations':'DNF',
'Denmark':'DNK',
'IDA countries in Sub-Saharan Africa not classified as fragile situations ':'DNS',
'Dominican Republic':'DOM',
'South Asia (IDA-eligible countries)':'DSA',
'IDA countries in Sub-Saharan Africa classified as fragile situations ':'DSF',
'Sub-Saharan Africa (IDA-eligible countries)':'DSS',
'IDA total, excluding Sub-Saharan Africa':'DXS',
'Algeria':'DZA',
'East Asia & Pacific (excluding high income)':'EAP',
'Early-demographic dividend':'EAR',
'East Asia & Pacific':'EAS',
'Europe & Central Asia (excluding high income)':'ECA',
'Europe & Central Asia':'ECS',
'Ecuador':'ECU',
'Egypt, Arab Rep.':'EGY',
'Euro area':'EMU',
'Eritrea':'ERI',
'Spain':'ESP',
'Estonia':'EST',
'Ethiopia':'ETH',
'European Union':'EUU',
'Fragile and conflict affected situations':'FCS',
'Finland':'FIN',
'Fiji':'FJI',
'France':'FRA',
'Faroe Islands':'FRO',
'Micronesia, Fed. Sts.':'FSM',
'IDA countries classified as fragile situations, excluding Sub-Saharan Africa':'FXS',
'Gabon':'GAB',
'United Kingdom':'GBR',
'Georgia':'GEO',
'Ghana':'GHA',
'Gibraltar':'GIB',
'Guinea':'GIN',
'Gambia, The':'GMB',
'Guinea-Bissau':'GNB',
'Equatorial Guinea':'GNQ',
'Greece':'GRC',
'Grenada':'GRD',
'Greenland':'GRL',
'Guatemala':'GTM',
'Guam':'GUM',
'Guyana':'GUY',
'High income':'HIC',
'Hong Kong SAR, China':'HKG',
'Honduras':'HND',
'Heavily indebted poor countries (HIPC)':'HPC',
'Croatia':'HRV',
'Haiti':'HTI',
'Hungary':'HUN',
'IBRD, including blend':'IBB',
'IBRD only':'IBD',
'IDA & IBRD total':'IBT',
'IDA total':'IDA',
'IDA blend':'IDB',
'Indonesia':'IDN',
'IDA only':'IDX',
'Isle of Man':'IMN',
'India':'IND',
'Not classified':'INX',
'Ireland':'IRL',
'Iran, Islamic Rep.':'IRN',
'Iraq':'IRQ',
'Iceland':'ISL',
'Israel':'ISR',
'Italy':'ITA',
'Jamaica':'JAM',
'Jordan':'JOR',
'Japan':'JPN',
'Kazakhstan':'KAZ',
'Kenya':'KEN',
'Kyrgyz Republic':'KGZ',
'Cambodia':'KHM',
'Kiribati':'KIR',
'St. Kitts and Nevis':'KNA',
'Korea, Rep.':'KOR',
'Kuwait':'KWT',
'Latin America & Caribbean (excluding high income)':'LAC',
'Lao PDR':'LAO',
'Lebanon':'LBN',
'Liberia':'LBR',
'Libya':'LBY',
'St. Lucia':'LCA',
'Latin America & Caribbean ':'LCN',
'Latin America and the Caribbean':'LCR',
'Least developed countries: UN classification':'LDC',
'Low income':'LIC',
'Liechtenstein':'LIE',
'Sri Lanka':'LKA',
'Lower middle income':'LMC',
'Low & middle income':'LMY',
'Lesotho':'LSO',
'Late-demographic dividend':'LTE',
'Lithuania':'LTU',
'Luxembourg':'LUX',
'Latvia':'LVA',
'Macao SAR, China':'MAC',
'St. Martin (French part)':'MAF',
'Morocco':'MAR',
'Central America':'MCA',
'Monaco':'MCO',
'Moldova':'MDA',
'Middle East (developing only)':'MDE',
'Madagascar':'MDG',
'Maldives':'MDV',
'Middle East & North Africa':'MEA',
'Mexico':'MEX',
'Marshall Islands':'MHL',
'Middle income':'MIC',
'North Macedonia':'MKD',
'Mali':'MLI',
'Malta':'MLT',
'Myanmar':'MMR',
'Middle East & North Africa (excluding high income)':'MNA',
'Montenegro':'MNE',
'Mongolia':'MNG',
'Northern Mariana Islands':'MNP',
'Mozambique':'MOZ',
'Mauritania':'MRT',
'Mauritius':'MUS',
'Malawi':'MWI',
'Malaysia':'MYS',
'North America':'NAC',
'North Africa':'NAF',
'Namibia':'NAM',
'New Caledonia':'NCL',
'Niger':'NER',
'Nigeria':'NGA',
'Nicaragua':'NIC',
'Netherlands':'NLD',
'Non-resource rich Sub-Saharan Africa countries, of which landlocked':'NLS',
'Norway':'NOR',
'Nepal':'NPL',
'Non-resource rich Sub-Saharan Africa countries':'NRS',
'Nauru':'NRU',
'IDA countries not classified as fragile situations, excluding Sub-Saharan Africa':'NXS',
'New Zealand':'NZL',
'OECD members':'OED',
'Oman':'OMN',
'Other small states':'OSS',
'Pakistan':'PAK',
'Panama':'PAN',
'Peru':'PER',
'Philippines':'PHL',
'Palau':'PLW',
'Papua New Guinea':'PNG',
'Poland':'POL',
'Pre-demographic dividend':'PRE',
'Puerto Rico':'PRI',
'Korea, Dem. People???s Rep.':'PRK',
'Portugal':'PRT',
'Paraguay':'PRY',
'West Bank and Gaza':'PSE',
'Pacific island small states':'PSS',
'Post-demographic dividend':'PST',
'French Polynesia':'PYF',
'Qatar':'QAT',
'Romania':'ROU',
'Resource rich Sub-Saharan Africa countries':'RRS',
'Resource rich Sub-Saharan Africa countries, of which oil exporters':'RSO',
'Russian Federation':'RUS',
'Rwanda':'RWA',
'South Asia':'SAS',
'Saudi Arabia':'SAU',
'Southern Cone':'SCE',
'Sudan':'SDN',
'Senegal':'SEN',
'Singapore':'SGP',
'Solomon Islands':'SLB',
'Sierra Leone':'SLE',
'El Salvador':'SLV',
'San Marino':'SMR',
'Somalia':'SOM',
'Serbia':'SRB',
'Sub-Saharan Africa (excluding high income)':'SSA',
'South Sudan':'SSD',
'Sub-Saharan Africa ':'SSF',
'Small states':'SST',
'Sao Tome and Principe':'STP',
'Suriname':'SUR',
'Slovak Republic':'SVK',
'Slovenia':'SVN',
'Sweden':'SWE',
'Eswatini':'SWZ',
'Sint Maarten (Dutch part)':'SXM',
'Sub-Saharan Africa excluding South Africa':'SXZ',
'Seychelles':'SYC',
'Syrian Arab Republic':'SYR',
'Turks and Caicos Islands':'TCA',
'Chad':'TCD',
'East Asia & Pacific (IDA & IBRD countries)':'TEA',
'Europe & Central Asia (IDA & IBRD countries)':'TEC',
'Togo':'TGO',
'Thailand':'THA',
'Tajikistan':'TJK',
'Turkmenistan':'TKM',
'Latin America & the Caribbean (IDA & IBRD countries)':'TLA',
'Timor-Leste':'TLS',
'Middle East & North Africa (IDA & IBRD countries)':'TMN',
'Tonga':'TON',
'South Asia (IDA & IBRD)':'TSA',
'Sub-Saharan Africa (IDA & IBRD countries)':'TSS',
'Trinidad and Tobago':'TTO',
'Tunisia':'TUN',
'Turkey':'TUR',
'Tuvalu':'TUV',
'Taiwan, China':'TWN',
'Tanzania':'TZA',
'Uganda':'UGA',
'Ukraine':'UKR',
'Upper middle income':'UMC',
'Uruguay':'URY',
'United States':'USA',
'Uzbekistan':'UZB',
'St. Vincent and the Grenadines':'VCT',
'Venezuela, RB':'VEN',
'British Virgin Islands':'VGB',
'Virgin Islands (U.S.)':'VIR',
'Vietnam':'VNM',
'Vanuatu':'VUT',
'World':'WLD',
'Samoa':'WSM',
'Kosovo':'XKX',
'Sub-Saharan Africa excluding South Africa and Nigeria':'XZN',
'Yemen, Rep.':'YEM',
'South Africa':'ZAF',
'Zambia':'ZMB',
'Zimbabwe':'ZWE',
}

# %%
ind_selected[:5]
# Out:
# ['SL.FAM.WORK.FE.ZS',
#  'SL.FAM.WORK.MA.ZS',
#  'SL.FAM.WORK.ZS',
#  'SL.EMP.MPYR.FE.ZS',
#  'SL.EMP.MPYR.MA.ZS']

# %%
from tqdm import tqdm_notebook
beg = pd.Timestamp(1990,1,1)
end = pd.Timestamp(2019,1,1)
sc = []
for i in tqdm_notebook(ind_selected):
    x = wb.get_data(indicator = i, country = 'all', data_date=(beg,end))
    sc.append(x)
# Out:
# HBox(children=(IntProgress(value=0, max=702), HTML(value='')))

# %%
sc

# %%
sc[0][0]['value']

# %%
test = pd.DataFrame (sc[0])
for i in range (1, len (sc)):
    test = pd.concat([test, pd.DataFrame (sc[i])])

test

# %%
test.country = test.country.apply (lambda x: x['value'])
test.indicator = test.indicator.apply (lambda x: x['value'])
test.drop (columns=['decimal'], inplace=True)
test.head()

# %%
test['country_code'] = test.country.replace(cc)
test.head()

# %%
worldbank = pd.pivot_table (test, index = ['country','country_code','date'], columns=['indicator'], values = 'value', aggfunc=np.sum)
worldbank.reset_index(inplace=True)
worldbank.head()

# %%
worldbank.to_csv ('wb_output.csv', index=False)
