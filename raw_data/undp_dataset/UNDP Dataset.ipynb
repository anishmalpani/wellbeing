# %%
# Doing all major library imports
import matplotlib.pyplot as plt
import scikitplot as skplt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import re

from sklearn import datasets, metrics
from sklearn.linear_model import LinearRegression, LogisticRegression,LogisticRegressionCV 
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from matplotlib.colors import ListedColormap
from sklearn.pipeline import Pipeline, make_pipeline

plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import scikitplot as skplt
from matplotlib.colors import ListedColormap
from sklearn.metrics import classification_report, confusion_matrix

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.options.display.float_format = '{:.2f}'.format

import wbdata as wb
import requests

# %%
#docs http://ec2-54-174-131-205.compute-1.amazonaws.com/API/Information.php
url = 'http://ec2-54-174-131-205.compute-1.amazonaws.com/API/hdro_api_all.json' 
r = requests.get(url=url)

# %%
json = r.json()

# %%
json[2000]
# Out:
# {'indicator_id': '132706',
#  'indicator_name': 'Population ages 65 and older (millions)',
#  'country_code': 'CHE',
#  'country_name': 'Switzerland',
#  'year': '2017',
#  'value': '1.562631'}

# %%
df = pd.DataFrame (json)
df.columns = ['country_code', 'country', 'indicator_id', 'indicator_name', 'value', 'date']
df.head()
# Out:
#   country_code      country indicator_id  \
# 0          AFG  Afghanistan        21806
# 1          AFG  Afghanistan        23806
# 2          AFG  Afghanistan        23906
# 3          AFG  Afghanistan        24006
# 4          AFG  Afghanistan        24106
#
#                                       indicator_name     value  date
# 0          Refugees by country of origin (thousands)  2621.091  2017
# 1  Population with at least some secondary educat...     25.12  2017
# 2  Population with at least some secondary educat...     11.36  2017
# 3  Population with at least some secondary educat...     36.86  2017
# 4            Mean years of schooling, female (years)     1.948  2017

# %%
# flipping the dataset
#df['indicator'] = df.indicator_id +" : "+ df.indicator_name
df['indicator'] = df.indicator_name
df.drop (columns=['indicator_id','indicator_name'], inplace = True)
undp = df.pivot_table(values='value', index=['country_code', 'country', 'date'], columns='indicator', aggfunc='first').reset_index()
undp.head()
# Out:
# indicator country_code      country  date Adjusted net savings (% of GNI)  \
# 0                  AFG  Afghanistan  1990                             NaN
# 1                  AFG  Afghanistan  1991                             NaN
# 2                  AFG  Afghanistan  1992                             NaN
# 3                  AFG  Afghanistan  1993                             NaN
# 4                  AFG  Afghanistan  1994                             NaN
#
# indicator Adolescent birth rate (births per 1,000 women ages 15-19)  \
# 0                                                    161.195
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
# indicator Antenatal care coverage, at least one visit (%)  \
# 0                                                     NaN
# ...

# %%
undp.to_csv ('undp_output.csv', index=False)
